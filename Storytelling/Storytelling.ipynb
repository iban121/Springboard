# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('starbucks_drinkMenu_expanded.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['Beverage', 'Beverage_prep', 'Calories', ' Total Fat (g)',
#        'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)'],
#       dtype='object')

# %%
df.head()
# Out:
#                               Beverage      Beverage_prep  Calories  \
# Beverage_category
# Coffee                   Brewed Coffee              Short         3
# Coffee                   Brewed Coffee               Tall         4
# Coffee                   Brewed Coffee             Grande         5
# Coffee                   Brewed Coffee              Venti         5
# Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk        70
#
#                          Total Fat (g)  Trans Fat (g)   Saturated Fat (g)  \
# Beverage_category
# Coffee                             0.1             0.0                0.0
# Coffee                             0.1             0.0                0.0
# Coffee                             0.1             0.0                0.0
# Coffee                             0.1             0.0                0.0
# Classic Espresso Drinks            0.1             0.1                0.0
#
#                           Sodium (mg)   Total Carbohydrates (g)   \
# ...

# %%
df.describe()
# Out:
#          Calories  Trans Fat (g)   Saturated Fat (g)   Sodium (mg)  \
# count  242.000000      242.000000         242.000000    242.000000
# mean   193.871901        1.307025           0.037603      6.363636
# std    102.863303        1.640259           0.071377      8.630257
# min      0.000000        0.000000           0.000000      0.000000
# 25%    120.000000        0.100000           0.000000      0.000000
# 50%    185.000000        0.500000           0.000000      5.000000
# 75%    260.000000        2.000000           0.100000     10.000000
# max    510.000000        9.000000           0.300000     40.000000
#
#         Total Carbohydrates (g)   Cholesterol (mg)   Dietary Fibre (g)  \
# count                 242.000000        242.000000          242.000000
# mean                  128.884298         35.991736            0.805785
# std                    82.303223         20.795186            1.445944
# min                     0.000000          0.000000            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 242 entries, Coffee to Frappuccino® Blended Crème
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage                   242 non-null    object
#  1   Beverage_prep              242 non-null    object
#  2   Calories                   242 non-null    int64
#  3    Total Fat (g)             242 non-null    object
#  4   Trans Fat (g)              242 non-null    float64
#  5   Saturated Fat (g)          242 non-null    float64
#  6    Sodium (mg)               242 non-null    int64
#  7    Total Carbohydrates (g)   242 non-null    int64
#  8   Cholesterol (mg)           242 non-null    int64
#  9    Dietary Fibre (g)         242 non-null    int64
#  10   Sugars (g)                242 non-null    int64
#  11   Protein (g)               242 non-null    float64
#  12  Vitamin A (% DV)           242 non-null    object
# ...

# %%
df.shape
# Out:
# (242, 17)

# %%
## Missing Data

# %%
df_expanded.isnull().sum()

# %% [markdown]
# ## 3. Data Types

# %% [markdown]
# ### Categorical Data

# %%
df.select_dtypes(include=object).head()
# Out:
#                               Beverage      Beverage_prep  Total Fat (g)  \
# Beverage_category
# Coffee                   Brewed Coffee              Short            0.1
# Coffee                   Brewed Coffee               Tall            0.1
# Coffee                   Brewed Coffee             Grande            0.1
# Coffee                   Brewed Coffee              Venti            0.1
# Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk            0.1
#
#                         Vitamin A (% DV)  Vitamin C (% DV)  Calcium (% DV)   \
# Beverage_category
# Coffee                                 0%               0%               0%
# Coffee                                 0%               0%               0%
# Coffee                                 0%               0%               0%
# Coffee                                 0%               0%               2%
# Classic Espresso Drinks               10%               0%              20%
#
# ...

# %%
df[[' Total Fat (g)'].as
# Out:
# pandas.core.frame.DataFrame

# %%
df = df_expanded.select_dtypes(include=object)

# %%
df.replace({'%',''}, regex=True)
df
# Out:
#                                                                 Beverage  \
# Beverage_category
# Coffee                                                     Brewed Coffee
# Coffee                                                     Brewed Coffee
# Coffee                                                     Brewed Coffee
# Coffee                                                     Brewed Coffee
# Classic Espresso Drinks                                      Caffè Latte
# ...                                                                  ...
# Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
#                                  Beverage_prep  Total Fat (g)  \
# ...

# %% [markdown]
# We want to do two things here: <br>
# > 1. remove the percentage signs <br>
# > 2. Change data type to float for everything barring the index, beverage, and beverage_prep columns.

# %%
df.replace)

# %%
df_expanded.index.unique()
# Out:
# Index(['Coffee', 'Classic Espresso Drinks', 'Signature Espresso Drinks',
#        'Tazo® Tea Drinks', 'Shaken Iced Beverages', 'Smoothies',
#        'Frappuccino® Blended Coffee', 'Frappuccino® Light Blended Coffee',
#        'Frappuccino® Blended Crème'],
#       dtype='object', name='Beverage_category')

# %%
_ = plt.figure(figsize=(10,6))
_ = sns.countplot(x=df_expanded.index, data = df_expanded)
_ = plt.xticks(rotation=90)
_ = plt.title('Distribution of Beverages by Category')
_ = plt.xlabel('Categories')

# %%
df_expanded.Beverage.unique()
# Out:
# array(['Brewed Coffee', 'Caffè Latte',
#        'Caffè Mocha (Without Whipped Cream)',
#        'Vanilla Latte (Or Other Flavoured Latte)', 'Caffè Americano',
#        'Cappuccino', 'Espresso', 'Skinny Latte (Any Flavour)',
#        'Caramel Macchiato',
#        'White Chocolate Mocha (Without Whipped Cream)',
#        'Hot Chocolate (Without Whipped Cream)',
#        'Caramel Apple Spice (Without Whipped Cream)', 'Tazo® Tea',
#        'Tazo® Chai Tea Latte', 'Tazo® Green Tea Latte',
#        'Tazo® Full-Leaf Tea Latte',
#        'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)',
#        'Iced Brewed Coffee (With Classic Syrup)',
#        'Iced Brewed Coffee (With Milk & Classic Syrup)',
#        'Shaken Iced Tazo® Tea (With Classic Syrup)',
#        'Shaken Iced Tazo® Tea Lemonade (With Classic Syrup)',
#        'Banana Chocolate Smoothie', 'Orange Mango Banana Smoothie',
#        'Strawberry Banana Smoothie', 'Coffee',
# ...

# %%
df_expanded.Beverage_prep.unique()
# Out:
# array(['Short', 'Tall', 'Grande', 'Venti', 'Short Nonfat Milk', '2% Milk',
#        'Soymilk', 'Tall Nonfat Milk', 'Grande Nonfat Milk',
#        'Venti Nonfat Milk', 'Solo', 'Doppio', 'Whole Milk'], dtype=object)

# %%
# Out:
# Beverage                     0
# Beverage_prep                0
# Calories                     0
#  Total Fat (g)               0
# Trans Fat (g)                0
# Saturated Fat (g)            0
#  Sodium (mg)                 0
#  Total Carbohydrates (g)     0
# Cholesterol (mg)             0
#  Dietary Fibre (g)           0
#  Sugars (g)                  0
#  Protein (g)                 0
# Vitamin A (% DV)             0
# Vitamin C (% DV)             0
#  Calcium (% DV)              0
# Iron (% DV)                  0
# Caffeine (mg)                1
# dtype: int64

# %%
df_expanded[df_expanded['Caffeine (mg)'].isna()]
# Out:
#                                                              Beverage  \
# Beverage_category
# Shaken Iced Beverages  Iced Brewed Coffee (With Milk & Classic Syrup)
#
#                       Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   \
# Beverage_category
# Shaken Iced Beverages       2% Milk        90              1             0.5
#
#                        Saturated Fat (g)   Sodium (mg)  \
# Beverage_category
# Shaken Iced Beverages                0.0             5
#
#                         Total Carbohydrates (g)   Cholesterol (mg)  \
# Beverage_category
# Shaken Iced Beverages                         25                18
#
#                         Dietary Fibre (g)   Sugars (g)   Protein (g)   \
# Beverage_category
# Shaken Iced Beverages                   0           18            2.0
#
#                       Vitamin A (% DV)  Vitamin C (% DV)  Calcium (% DV)   \
# Beverage_category
# Shaken Iced Beverages                2%               0%               6%
#
# ...

# %% [markdown]
# The only missing data refers to a Shaken Iced Beverage, where the beverage is an iced brewed coffee with milk and classic syrup. Let's have a look at other Shaken Iced Beverages and how their caffeine content varies. If they are similar enough, we can impute the missing value with the mean.

# %%
df_expanded[df_expanded['Beverage_prep']=='2% Milk'].head()
# Out:
#                                                     Beverage Beverage_prep  \
# Beverage_category
# Classic Espresso Drinks                          Caffè Latte       2% Milk
# Classic Espresso Drinks                          Caffè Latte       2% Milk
# Classic Espresso Drinks                          Caffè Latte       2% Milk
# Classic Espresso Drinks                          Caffè Latte       2% Milk
# Classic Espresso Drinks  Caffè Mocha (Without Whipped Cream)       2% Milk
#
#                          Calories  Total Fat (g)  Trans Fat (g)   \
# Beverage_category
# Classic Espresso Drinks       100            3.5             2.0
# Classic Espresso Drinks       150              6             3.0
# Classic Espresso Drinks       190              7             3.5
# Classic Espresso Drinks       240              9             4.5
# Classic Espresso Drinks       130              4             2.0
#
#                          Saturated Fat (g)   Sodium (mg)  \
# Beverage_category
# ...

# %%
df_expanded = df_expanded.fillna(df_expanded.mean())

# %% [markdown]
# ## EDA

# %%
sns.pairplot(df_expanded)

# %% [markdown]
# ### Observations

# %%
calories = df_expanded[['Beverage', 'Beverage_prep', 'Calories']]
calories.head()
# Out:
#                               Beverage      Beverage_prep  Calories
# Beverage_category
# Coffee                   Brewed Coffee              Short         3
# Coffee                   Brewed Coffee               Tall         4
# Coffee                   Brewed Coffee             Grande         5
# Coffee                   Brewed Coffee              Venti         5
# Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk        70

# %%
calories.sort_values('Calories')

# %%
_ = plt.figure(figsize=(10,6))
_ = sns.barplot(x='Beverage_prep', y= 'Calories' , data= calories, ci=None)
_ = plt.xticks(rotation = 90)

# %% [markdown]
# ## How does Nutrition vary based on Drink Catagories?

# %%
two_perc = df_expanded[df_expanded['Beverage_prep']=='2% Milk']
two_perc.head()
# Out:
#                                                     Beverage Beverage_prep  \
# Beverage_category
# Classic Espresso Drinks                          Caffè Latte       2% Milk
# Classic Espresso Drinks                          Caffè Latte       2% Milk
# Classic Espresso Drinks                          Caffè Latte       2% Milk
# Classic Espresso Drinks                          Caffè Latte       2% Milk
# Classic Espresso Drinks  Caffè Mocha (Without Whipped Cream)       2% Milk
#
#                          Calories  Total Fat (g)  Trans Fat (g)   \
# Beverage_category
# Classic Espresso Drinks       100            3.5             2.0
# Classic Espresso Drinks       150              6             3.0
# Classic Espresso Drinks       190              7             3.5
# Classic Espresso Drinks       240              9             4.5
# Classic Espresso Drinks       130              4             2.0
#
#                          Saturated Fat (g)   Sodium (mg)  \
# Beverage_category
# ...

# %%
# Out:
# pandas.core.indexes.base.Index

# %%
_ = plt.figure(figsize=(10,6))
two_perc.plot.bar()
# Out:
# <AxesSubplot:xlabel='Beverage_category'>
