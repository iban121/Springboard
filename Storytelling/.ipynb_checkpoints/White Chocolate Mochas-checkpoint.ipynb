# %% [markdown]
# # White Chocolate Mochas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import PercentFormatter
sns.set(font_scale=1.2)
# %matplotlib inline

# %%
df = pd.read_csv('starbucks_drinkMenu_expanded.csv', index_col=0)

# %%
df.head()
# Out:
#                               Beverage      Beverage_prep  Calories  \
# Beverage_category
# Coffee                   Brewed Coffee              Short         3
# Coffee                   Brewed Coffee               Tall         4
# Coffee                   Brewed Coffee             Grande         5
# Coffee                   Brewed Coffee              Venti         5
# Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk        70
#
#                          Total Fat (g)  Trans Fat (g)   Saturated Fat (g)  \
# Beverage_category
# Coffee                             0.1             0.0                0.0
# Coffee                             0.1             0.0                0.0
# Coffee                             0.1             0.0                0.0
# Coffee                             0.1             0.0                0.0
# Classic Espresso Drinks            0.1             0.1                0.0
#
#                           Sodium (mg)   Total Carbohydrates (g)   \
# Beverage_category
# Coffee                              0                          5
# Coffee                              0                         10
# Coffee                              0                         10
# Coffee                              0                         10
# Classic Espresso Drinks             5                         75
#
#                          Cholesterol (mg)   Dietary Fibre (g)   Sugars (g)  \
# Beverage_category
# Coffee                                  0                   0            0
# Coffee                                  0                   0            0
# Coffee                                  0                   0            0
# Coffee                                  0                   0            0
# Classic Espresso Drinks                10                   0            9
#
#                           Protein (g)  Vitamin A (% DV)  Vitamin C (% DV)  \
# Beverage_category
# Coffee                             0.3                0%               0%
# Coffee                             0.5                0%               0%
# Coffee                             1.0                0%               0%
# Coffee                             1.0                0%               0%
# Classic Espresso Drinks            6.0               10%               0%
#
#                          Calcium (% DV)  Iron (% DV)  Caffeine (mg)
# Beverage_category
# Coffee                                0%           0%           175
# Coffee                                0%           0%           260
# Coffee                                0%           0%           330
# Coffee                                2%           0%           410
# Classic Espresso Drinks              20%           0%            75

# %%
df.describe()
# Out:
#          Calories  Trans Fat (g)   Saturated Fat (g)   Sodium (mg)  \
# count  242.000000      242.000000         242.000000    242.000000
# mean   193.871901        1.307025           0.037603      6.363636
# std    102.863303        1.640259           0.071377      8.630257
# min      0.000000        0.000000           0.000000      0.000000
# 25%    120.000000        0.100000           0.000000      0.000000
# 50%    185.000000        0.500000           0.000000      5.000000
# 75%    260.000000        2.000000           0.100000     10.000000
# max    510.000000        9.000000           0.300000     40.000000
#
#         Total Carbohydrates (g)   Cholesterol (mg)   Dietary Fibre (g)  \
# count                 242.000000        242.000000          242.000000
# mean                  128.884298         35.991736            0.805785
# std                    82.303223         20.795186            1.445944
# min                     0.000000          0.000000            0.000000
# 25%                    70.000000         21.000000            0.000000
# 50%                   125.000000         34.000000            0.000000
# 75%                   170.000000         50.750000            1.000000
# max                   340.000000         90.000000            8.000000
#
#         Sugars (g)   Protein (g)
# count   242.000000     242.000000
# mean     32.962810       6.978512
# std      19.730199       4.871659
# min       0.000000       0.000000
# 25%      18.000000       3.000000
# 50%      32.000000       6.000000
# 75%      43.750000      10.000000
# max      84.000000      20.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 242 entries, Coffee to Frappuccino® Blended Crème
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage                   242 non-null    object
#  1   Beverage_prep              242 non-null    object
#  2   Calories                   242 non-null    int64
#  3    Total Fat (g)             242 non-null    object
#  4   Trans Fat (g)              242 non-null    float64
#  5   Saturated Fat (g)          242 non-null    float64
#  6    Sodium (mg)               242 non-null    int64
#  7    Total Carbohydrates (g)   242 non-null    int64
#  8   Cholesterol (mg)           242 non-null    int64
#  9    Dietary Fibre (g)         242 non-null    int64
#  10   Sugars (g)                242 non-null    int64
#  11   Protein (g)               242 non-null    float64
#  12  Vitamin A (% DV)           242 non-null    object
#  13  Vitamin C (% DV)           242 non-null    object
#  14   Calcium (% DV)            242 non-null    object
#  15  Iron (% DV)                242 non-null    object
#  16  Caffeine (mg)              241 non-null    object
# dtypes: float64(3), int64(6), object(8)
# memory usage: 34.0+ KB

# %%
df.shape
# Out:
# (242, 17)

# %% [markdown]
# ## Data Wrangling
# We want to do two things here: <br>
# > 1. Remove the percentage signs <br>
# > 2. Change data type to float for everything barring the index and beverage and beverage_prep columns.

# %% [markdown]
# ### Data Cleaning

# %%
percent_columns = ['Vitamin A (% DV) ', 'Vitamin C (% DV)', ' Calcium (% DV) ', 'Iron (% DV) ']
df[percent_columns] = df[percent_columns].replace({'%':''}, regex = True)

# %%
df['Vitamin A (% DV) '] = df['Vitamin A (% DV) '].astype(float)
df['Vitamin C (% DV)'] = df['Vitamin C (% DV)'].astype(float)
df[' Calcium (% DV) '] = df[' Calcium (% DV) '].astype(float)
df['Iron (% DV) '] = df['Iron (% DV) '].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 242 entries, Coffee to Frappuccino® Blended Crème
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage                   242 non-null    object
#  1   Beverage_prep              242 non-null    object
#  2   Calories                   242 non-null    int64
#  3    Total Fat (g)             242 non-null    object
#  4   Trans Fat (g)              242 non-null    float64
#  5   Saturated Fat (g)          242 non-null    float64
#  6    Sodium (mg)               242 non-null    int64
#  7    Total Carbohydrates (g)   242 non-null    int64
#  8   Cholesterol (mg)           242 non-null    int64
#  9    Dietary Fibre (g)         242 non-null    int64
#  10   Sugars (g)                242 non-null    int64
#  11   Protein (g)               242 non-null    float64
#  12  Vitamin A (% DV)           242 non-null    float64
#  13  Vitamin C (% DV)           242 non-null    float64
#  14   Calcium (% DV)            242 non-null    float64
#  15  Iron (% DV)                242 non-null    float64
#  16  Caffeine (mg)              241 non-null    object
# dtypes: float64(7), int64(6), object(4)
# memory usage: 34.0+ KB

# %% [markdown]
# ### Data Imputations

# %%
df = df.replace('Varies', np.nan)
df = df.replace('varies', np.nan)
df['Caffeine (mg)'] = df['Caffeine (mg)'].astype(float)

# %% [markdown]
# For the Total Fat (g) column, there happens to be an entry with 3 2 which looks like should be 3.2, so we'll go ahead and replace this value.

# %%
df[df[' Total Fat (g)']== '3 2'] = df[df[' Total Fat (g)']== '3.2']
df[' Total Fat (g)'] = df[' Total Fat (g)'].astype(float)

# %%
df = df.fillna(df.mean())

# %%
df.isnull().sum()
# Out:
# Beverage                     1
# Beverage_prep                1
# Calories                     0
#  Total Fat (g)               0
# Trans Fat (g)                0
# Saturated Fat (g)            0
#  Sodium (mg)                 0
#  Total Carbohydrates (g)     0
# Cholesterol (mg)             0
#  Dietary Fibre (g)           0
#  Sugars (g)                  0
#  Protein (g)                 0
# Vitamin A (% DV)             0
# Vitamin C (% DV)             0
#  Calcium (% DV)              0
# Iron (% DV)                  0
# Caffeine (mg)                0
# dtype: int64

# %%
df[df['Beverage'].isnull()]
# Out:
#                            Beverage Beverage_prep    Calories   Total Fat (g)  \
# Beverage_category
# Frappuccino® Blended Crème      NaN           NaN  193.348548        2.903734
#
#                             Trans Fat (g)   Saturated Fat (g)   Sodium (mg)  \
# Beverage_category
# Frappuccino® Blended Crème        1.310788           0.037759      6.390041
#
#                              Total Carbohydrates (g)   Cholesterol (mg)  \
# Beverage_category
# Frappuccino® Blended Crème                 128.381743         35.863071
#
#                              Dietary Fibre (g)   Sugars (g)   Protein (g)   \
# Beverage_category
# Frappuccino® Blended Crème            0.804979    32.834025       6.986722
#
#                             Vitamin A (% DV)   Vitamin C (% DV)  \
# Beverage_category
# Frappuccino® Blended Crème           9.846473          3.630705
#
#                              Calcium (% DV)   Iron (% DV)   Caffeine (mg)
# Beverage_category
# Frappuccino® Blended Crème         20.759336      7.435685      89.931193

# %%
df = df.dropna(axis = 0)

# %% [markdown]
# ### Units

# %%
df[['Trans Fat (g) ','Saturated Fat (g)',' Total Carbohydrates (g) ',' Dietary Fibre (g)',' Sugars (g)', ' Protein (g) ']] = df[['Trans Fat (g) ','Saturated Fat (g)',' Total Carbohydrates (g) ',' Dietary Fibre (g)',' Sugars (g)', ' Protein (g) ']]* 1000

# %%
df = df.rename({'Beverage':'Beverage' , 'Beverage_prep': 'Beverage_prep', 'Calories':'Calories', ' Total Fat (g)':'Total_Fat(mg)',
                  'Trans Fat (g) ': 'Trans_Fat (mg)', 'Saturated Fat (g)': 'Saturated_Fat(mg)', ' Sodium (mg)':'Sodium(mg)',
                  ' Total Carbohydrates (g) ':'Total_Carbohydrates(mg)', 'Cholesterol (mg)':'Cholesterol(mg)', ' Dietary Fibre (g)':'Dietary_Fibre(mg)',
                  ' Sugars (g)':'Sugars(mg)', ' Protein (g) ':'Protein(mg)', 'Vitamin A (% DV) ':'VitaminA(% DV)', 'Vitamin C (% DV)':'VitaminC(% DV)',
                  ' Calcium (% DV) ':'Calcium(% DV)', 'Iron (% DV) ':'Iron(% DV)', 'Caffeine(mg)':'Caffeine(mg)'}, axis=1)

# %% [markdown]
# ### Clean Datasets

# %%
clean_data = df
clean_data.shape
# Out:
# (241, 17)

# %%
signature_espresso = clean_data[clean_data.index == 'Signature Espresso Drinks']

# %%
white_chocolate = df[df['Beverage'].str.contains('White Chocolate')]

# %%
white_chocolate
# Out:
#                                                                 Beverage  \
# Beverage_category
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
# Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
#
#                                 Beverage_prep  Calories  Total_Fat(mg)  \
# Beverage_category
# Signature Espresso Drinks   Short Nonfat Milk     180.0            3.0
# Signature Espresso Drinks             2% Milk     200.0            6.0
# Signature Espresso Drinks             Soymilk     180.0            5.0
# Signature Espresso Drinks    Tall Nonfat Milk     270.0            4.5
# Signature Espresso Drinks             2% Milk     310.0            9.0
# Signature Espresso Drinks             Soymilk     280.0            8.0
# Signature Espresso Drinks  Grande Nonfat Milk     350.0            6.0
# Signature Espresso Drinks             2% Milk     400.0           11.0
# Signature Espresso Drinks             Soymilk     370.0           10.0
# Signature Espresso Drinks   Venti Nonfat Milk     450.0            7.0
# Signature Espresso Drinks             2% Milk     510.0           15.0
# Signature Espresso Drinks             Soymilk     460.0           13.0
#
#                            Trans_Fat (mg)  Saturated_Fat(mg)  Sodium(mg)  \
# Beverage_category
# Signature Espresso Drinks          2000.0                0.0         5.0
# Signature Espresso Drinks          3500.0              100.0        15.0
# Signature Espresso Drinks          2500.0                0.0         0.0
# Signature Espresso Drinks          3500.0                0.0         5.0
# Signature Espresso Drinks          6000.0              100.0        20.0
# Signature Espresso Drinks          3500.0                0.0         0.0
# Signature Espresso Drinks          4500.0                0.0        10.0
# Signature Espresso Drinks          7000.0              200.0        25.0
# Signature Espresso Drinks          5000.0                0.0         0.0
# Signature Espresso Drinks          6000.0                0.0        10.0
# Signature Espresso Drinks          9000.0              200.0        35.0
# Signature Espresso Drinks          6000.0                0.0         5.0
#
#                            Total_Carbohydrates(mg)  Cholesterol(mg)  \
# Beverage_category
# Signature Espresso Drinks                 120000.0             31.0
# Signature Espresso Drinks                 125000.0             31.0
# Signature Espresso Drinks                 110000.0             28.0
# Signature Espresso Drinks                 190000.0             47.0
# Signature Espresso Drinks                 200000.0             46.0
# Signature Espresso Drinks                 170000.0             42.0
# Signature Espresso Drinks                 240000.0             61.0
# Signature Espresso Drinks                 250000.0             61.0
# Signature Espresso Drinks                 220000.0             56.0
# Signature Espresso Drinks                 310000.0             78.0
# Signature Espresso Drinks                 330000.0             77.0
# Signature Espresso Drinks                 290000.0             70.0
#
#                            Dietary_Fibre(mg)  Sugars(mg)  Protein(mg)  \
# Beverage_category
# Signature Espresso Drinks                0.0     29000.0       7000.0
# Signature Espresso Drinks                0.0     29000.0       7000.0
# Signature Espresso Drinks             1000.0     25000.0       6000.0
# Signature Espresso Drinks                0.0     45000.0      12000.0
# Signature Espresso Drinks                0.0     44000.0      11000.0
# Signature Espresso Drinks             1000.0     39000.0      10000.0
# Signature Espresso Drinks                0.0     58000.0      15000.0
# Signature Espresso Drinks                0.0     58000.0      15000.0
# Signature Espresso Drinks             1000.0     51000.0      13000.0
# Signature Espresso Drinks                0.0     74000.0      19000.0
# Signature Espresso Drinks                0.0     74000.0      19000.0
# Signature Espresso Drinks             1000.0     64000.0      16000.0
#
#                            VitaminA(% DV)  VitaminC(% DV)  Calcium(% DV)  \
# Beverage_category
# Signature Espresso Drinks            10.0             0.0           25.0
# Signature Espresso Drinks             8.0             2.0           25.0
# Signature Espresso Drinks             6.0             0.0           25.0
# Signature Espresso Drinks            15.0             2.0           35.0
# Signature Espresso Drinks            15.0             2.0           35.0
# Signature Espresso Drinks            10.0             2.0           35.0
# Signature Espresso Drinks            20.0             2.0           45.0
# Signature Espresso Drinks            15.0             2.0           45.0
# Signature Espresso Drinks            10.0             2.0           45.0
# Signature Espresso Drinks            25.0             2.0           60.0
# Signature Espresso Drinks            20.0             4.0           60.0
# Signature Espresso Drinks            15.0             2.0           60.0
#
#                            Iron(% DV)  Caffeine (mg)
# Beverage_category
# Signature Espresso Drinks         0.0           75.0
# Signature Espresso Drinks         0.0           75.0
# Signature Espresso Drinks         8.0           75.0
# Signature Espresso Drinks         0.0           75.0
# Signature Espresso Drinks         0.0           75.0
# Signature Espresso Drinks        10.0           75.0
# Signature Espresso Drinks         2.0          150.0
# Signature Espresso Drinks         0.0          150.0
# Signature Espresso Drinks        15.0          150.0
# Signature Espresso Drinks         2.0          150.0
# Signature Espresso Drinks         2.0          150.0
# Signature Espresso Drinks        20.0          150.0

# %%
white_chocolate.shape
# Out:
# (12, 17)

# %%
white_chocolate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, Signature Espresso Drinks to Signature Espresso Drinks
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Beverage                 12 non-null     object
#  1   Beverage_prep            12 non-null     object
#  2   Calories                 12 non-null     float64
#  3   Total_Fat(mg)            12 non-null     float64
#  4   Trans_Fat (mg)           12 non-null     float64
#  5   Saturated_Fat(mg)        12 non-null     float64
#  6   Sodium(mg)               12 non-null     float64
#  7   Total_Carbohydrates(mg)  12 non-null     float64
#  8   Cholesterol(mg)          12 non-null     float64
#  9   Dietary_Fibre(mg)        12 non-null     float64
#  10  Sugars(mg)               12 non-null     float64
#  11  Protein(mg)              12 non-null     float64
#  12  VitaminA(% DV)           12 non-null     float64
#  13  VitaminC(% DV)           12 non-null     float64
#  14  Calcium(% DV)            12 non-null     float64
#  15  Iron(% DV)               12 non-null     float64
#  16  Caffeine (mg)            12 non-null     float64
# dtypes: float64(15), object(2)
# memory usage: 1.7+ KB

# %%
white_chocolate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, Signature Espresso Drinks to Signature Espresso Drinks
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Beverage                 12 non-null     object
#  1   Beverage_prep            12 non-null     object
#  2   Calories                 12 non-null     float64
#  3   Total_Fat(mg)            12 non-null     float64
#  4   Trans_Fat (mg)           12 non-null     float64
#  5   Saturated_Fat(mg)        12 non-null     float64
#  6   Sodium(mg)               12 non-null     float64
#  7   Total_Carbohydrates(mg)  12 non-null     float64
#  8   Cholesterol(mg)          12 non-null     float64
#  9   Dietary_Fibre(mg)        12 non-null     float64
#  10  Sugars(mg)               12 non-null     float64
#  11  Protein(mg)              12 non-null     float64
#  12  VitaminA(% DV)           12 non-null     float64
#  13  VitaminC(% DV)           12 non-null     float64
#  14  Calcium(% DV)            12 non-null     float64
#  15  Iron(% DV)               12 non-null     float64
#  16  Caffeine (mg)            12 non-null     float64
# dtypes: float64(15), object(2)
# memory usage: 1.7+ KB

# %% [markdown]
# ## EDA
# ### The White Chocolate Mocha
# Let's first look and see how the different white chocolate mochas compare to other Signature Espresso Drinks. We expect the smaller the sizes of the drinks the lower their nutritional values. We can also see that there are two other variants: 2% Milk and Soymilk. It'll be interesting to see how these two variants compare to the non-fat milk variants.

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Calories'].hist()
_ = plt.axvline(x=signature_espresso['Calories'].median(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Calories'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Calories'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Calories'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Calories'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Calories'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Calories'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)', bbox_to_anchor=[1,1])
_ = plt.title('Distribution of Calories')
_ = plt.xlabel('Calories')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Total_Fat(mg)'].hist()
_ = plt.axvline(x=signature_espresso['Total_Fat(mg)'].median(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Total_Fat(mg)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Total_Fat(mg)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Total_Fat(mg)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Total_Fat(mg)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Total_Fat(mg)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Total_Fat(mg)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Total Fat')
_ = plt.xlabel('Total Fat')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Trans_Fat (mg)'].hist()
_ = plt.axvline(x=signature_espresso['Trans_Fat (mg)'].median(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Trans_Fat (mg)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Trans_Fat (mg)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Trans_Fat (mg)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Trans_Fat (mg)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Trans_Fat (mg)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Trans_Fat (mg)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Trans Fats')
_ = plt.xlabel('Trans Fat')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Saturated_Fat(mg)'].hist(bins=10)
_ = plt.axvline(x=signature_espresso['Saturated_Fat(mg)'].mean(), c='black', label='Mean')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Saturated_Fat(mg)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Saturated_Fat(mg)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Saturated_Fat(mg)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Saturated_Fat(mg)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Saturated_Fat(mg)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Saturated_Fat(mg)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Saturated Fats')
_ = plt.xlabel('Saturated Fat(mg)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Sodium(mg)'].hist()
_ = plt.axvline(x=signature_espresso['Sodium(mg)'].mean(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Sodium(mg)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Sodium(mg)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Sodium(mg)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Sodium(mg)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Sodium(mg)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Sodium(mg)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Sodium(mg)')
_ = plt.xlabel('Sodium(mg)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Total_Carbohydrates(mg)'].hist()
_ = plt.axvline(x=signature_espresso['Total_Carbohydrates(mg)'].median(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Total_Carbohydrates(mg)'].median(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Total_Carbohydrates(mg)'].median(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Total_Carbohydrates(mg)'].median(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Total_Carbohydrates(mg)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Total_Carbohydrates(mg)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Total_Carbohydrates(mg)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Total Carbohydrates(mg)')
_ = plt.xlabel('Total Carbohydrates(mg)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Cholesterol(mg)'].hist()
_ = plt.axvline(x=signature_espresso['Cholesterol(mg)'].median(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Cholesterol(mg)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Cholesterol(mg)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Cholesterol(mg)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Cholesterol(mg)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Cholesterol(mg)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Cholesterol(mg)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Cholesterol(mg)')
_ = plt.xlabel('Cholesterol(mg)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Dietary_Fibre(mg)'].hist()
_ = plt.axvline(x=signature_espresso['Dietary_Fibre(mg)'].median(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Dietary_Fibre(mg)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Dietary_Fibre(mg)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Dietary_Fibre(mg)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Dietary_Fibre(mg)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Dietary_Fibre(mg)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Dietary_Fibre(mg)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Dietary Fibre(mg)')
_ = plt.xlabel('Dietary Fibre(mg)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Sugars(mg)'].hist()
_ = plt.axvline(x=signature_espresso['Sugars(mg)'].median(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Sugars(mg)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Sugars(mg)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Sugars(mg)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Sugars(mg)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Sugars(mg)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Sugars(mg)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Sugars(mg)')
_ = plt.xlabel('Sugars(mg)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Protein(mg)'].hist()
_ = plt.axvline(x=signature_espresso['Protein(mg)'].median(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Protein(mg)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Protein(mg)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Protein(mg)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Protein(mg)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Protein(mg)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Protein(mg)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Protein(mg)')
_ = plt.xlabel('Protein(mg)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['VitaminA(% DV)'].hist()
_ = plt.axvline(x=signature_espresso['VitaminA(% DV)'].mean(), c='black', label='Mean')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['VitaminA(% DV)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['VitaminA(% DV)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['VitaminA(% DV)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['VitaminA(% DV)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['VitaminA(% DV)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['VitaminA(% DV)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Vitamin A (% DV)')
_ = plt.xlabel('Vitamin A (% DV)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['VitaminC(% DV)'].hist()
_ = plt.axvline(x=signature_espresso['VitaminC(% DV)'].mean(), c='black', label='Mean')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['VitaminC(% DV)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['VitaminC(% DV)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['VitaminC(% DV)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['VitaminC(% DV)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['VitaminC(% DV)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['VitaminC(% DV)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Vitamin C (% DV)')
_ = plt.xlabel('Vitamin C (% DV)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Calcium(% DV)'].hist()
_ = plt.axvline(x=signature_espresso['Calcium(% DV)'].median(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Calcium(% DV)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Calcium(% DV)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Calcium(% DV)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Calcium(% DV)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Calcium(% DV)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Calcium(% DV)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Calcium (% DV)')
_ = plt.xlabel('Calcium (% DV)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Iron(% DV)'].hist()
_ = plt.axvline(x=signature_espresso['Iron(% DV)'].median(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Iron(% DV)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Iron(% DV)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Iron(% DV)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Iron(% DV)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Iron(% DV)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Iron(% DV)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Iron (% DV)')
_ = plt.xlabel('Iron (% DV)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = signature_espresso['Caffeine (mg)'].hist(bins=10)
_ = plt.axvline(x=signature_espresso['Caffeine (mg)'].median(), c='black', label='Median')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Short Nonfat Milk']['Caffeine (mg)'].mean(), c='orange', ls = '--', label='Short Non-Fat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='2% Milk']['Caffeine (mg)'].mean(), c='blue', ls = '--', label='2% Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Soymilk']['Caffeine (mg)'].mean(), c='red', ls = '--', label='Soymilk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Tall Nonfat Milk']['Caffeine (mg)'].mean(), c='green', ls = '--', label='Tall Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Grande Nonfat Milk']['Caffeine (mg)'].mean(), c='orange', label='Grande Nonfat Milk')
_ = plt.axvline(x=white_chocolate[white_chocolate['Beverage_prep']=='Venti Nonfat Milk']['Caffeine (mg)'].mean(), c='green', label='Venti Nonfat Milk')
_ = plt.legend(title = 'White Chocolate Mocha (Without Whipped Cream)',bbox_to_anchor=[1.62,1])
_ = plt.title('Distribution of Caffeine (mg)')
_ = plt.xlabel('Caffeine (mg)')
_ = plt.ylabel('Count')
_ = plt.show()

# %%
white_chocolate.columns
# Out:
# Index(['Beverage', 'Beverage_prep', 'Calories', 'Total_Fat(mg)',
#        'Trans_Fat (mg)', 'Saturated_Fat(mg)', 'Sodium(mg)',
#        'Total_Carbohydrates(mg)', 'Cholesterol(mg)', 'Dietary_Fibre(mg)',
#        'Sugars(mg)', 'Protein(mg)', 'VitaminA(% DV)', 'VitaminC(% DV)',
#        'Calcium(% DV)', 'Iron(% DV)', 'Caffeine (mg)'],
#       dtype='object')

# %%
white_chocolate['Beverage_prep'].unique()
# Out:
# array(['Short Nonfat Milk', '2% Milk', 'Soymilk', 'Tall Nonfat Milk',
#        'Grande Nonfat Milk', 'Venti Nonfat Milk'], dtype=object)

# %% [markdown]
# ### Summary Findings
# > __Calories__ <br>
# As expected we see Short, Tall, Grande and Venti appear in ascending order. It's interesting to note that 2% Milk has higher calorie content than short and tall non fat variants, and the soymilk mochas has higher calorie content that grande but less than venti variants. Other than the short non-fat variants, all white chocolate mochas have higher calorie counts than the median espresso drinks. <br>
# > __Total Fat__ <br>
# The short and tall variants have lower total fat values than the median trans fat count of Signature Espresso Drinks. It's noteworthy, the 2% milk white chocolate mochas have the highest total fat content followed by the soymilk variant.<br>
# > __Trans Fat__ <br>
# The trans fat disribution is very similar to the distribution of calories where the only difference is that the 2% Milk has the highest trans fat count. It's noteworthy that short nonfat milk variant has the same transfat content as the median frans fat content of signature espresso drinks.  <br>
# > __Saturated Fat__ <br>
# The highest amount of saturated fat seems to be in 2% Milk variant of drinks, otherwsie all the other drinks have low saturated fats. <br>
# > __Sodium__ <br>
# The 2% Milk ranks the highest in sodium content for white chocolate mochas, and the venti non-fat variants stand just above the median sodium count for signature espresso drinks. <br>
# > __Total Carbohydrates__ <br>
# Other than short chite chocolate mochas, the remaining white chocolate variants place on the higher end of the total carbohydrates distributions for signature espresso drinks. 2% milk and soymilk variants of the white chocolate mocha fall between the tall and grande nonfat milk variants. <br>
# > __Cholesterol__ <br>
# We observe the exact same pattern for Cholesterol as total carbohydrates.
# <br>
# > __Dietary Fibre__ <br>
# Soymilk white chocolate mochas have a signficantly more dietary fibre present than any white chocolate mochas, and it's noteworthy how wide the range of dietary fibre values are for signature espresso drinks. <br>
# > __Sugars__ <br>
# The sugar content, surprisingly, is the same soymilk and tall non fat milk variants for white chocolate mochas. The short non-fat have lower than the median sugar content of signature espresso drinks. Whilst the venti white chocolate mocha doesn't have the highest sugar content, it places relatively high in the distribution. The 2% milk variant is also surpirsingly higher than the median sugar content.  <br>
# > __Protein__ <br>
# As expected, The protein content for the non fat milk vaiants increases as the volumes increase. The shor non-fat variant has a lower protein content than the median count for signature espresso drinks. Furthermore, the venti non-fat milk ranks as one of the protein richest drinks in this category.<br>
# > __Vitamen A__ <br>
# Soymilk and the short non-fat milk white chcolate mocha have very similar vitamin A content, and both fall lower than the median vitamin a counts for signature espresso drinks. Perhaps due to volume, the grande and vonti nonfat milk variants are very high in vitamin content. It's worth noting that the 2% milk variant has lower vitamin a content than the tall nonfat milk variant. <br>
# > __Vitamin C__ <br>
# The highest Vitamin C concetrations are in 2% milk, soymilk, and venti drinks. By considering the mean Vitamin C concetration in signature espresso drinks, it's interesting how the short variant has lower than the mean Vitamin C concentrations. It might be suitable to infer that for the nonfat variants there might be a threshold volume required before any meanigful amount of Vitamin C is present. <br>
# > __Calcium__<br>
# The 2% Milk and Soymilk variants have the same calcium content for white chocolate mochas and they place higher than the medain calcium content for signature espresso drinks. The Venti has the highest calcium content which isn't surprising as it has the largest volume of milk.<br>
# > __Iron__ <br>
# Soymilk seems to be richest in iron, whilst the 2% Milk white chocolate mocha has a significantly lower iron content than the median iron content of signature espresso drinks. <br>
# > __Caffeine__ <br>
# There seems to be clear division in the sizes of the drinks which is in line with what we'd expect- as the sizes increase so does their caffein content.

# %% [markdown]
# ### Signature Espresso Drinks
# We cna see when it comes to the White Chocolate Mocha

# %%
sig_espresso = clean_data[clean_data.index =='Signature Espresso Drinks'].groupby('Beverage').median()

# %%
sig_espresso[['Total_Fat(mg)','Trans_Fat (mg)', 'Saturated_Fat(mg)', 'Sodium(mg)',
              'Total_Carbohydrates(mg)', 'Cholesterol(mg)', 'Dietary_Fibre(mg)',
              'Sugars(mg)', 'Protein(mg)', 'Caffeine (mg)']] = sig_espresso[['Total_Fat(mg)','Trans_Fat (mg)', 'Saturated_Fat(mg)', 'Sodium(mg)',
              'Total_Carbohydrates(mg)', 'Cholesterol(mg)', 'Dietary_Fibre(mg)',
              'Sugars(mg)', 'Protein(mg)','Caffeine (mg)']]/1000

# %%
sig_espresso.columns = ['Calories', 'Total_Fat(g)', 'Trans_Fat (g)', 'Saturated_Fat(g)','Sodium(g)',
                               'Total_Carbohydrates(g)', 'Cholesterol(g)','Dietary_Fibre(g)', 'Sugars(g)', 
                               'Protein(g)', 'VitaminA(% DV)','VitaminC(% DV)', 'Calcium(% DV)', 
                               'Iron(% DV)', 'Caffeine (g)']

# %%
sig_espresso
# Out:
#                                                Calories  Total_Fat(g)  \
# Beverage
# Caramel Apple Spice (Without Whipped Cream)       245.0       0.00000
# Caramel Macchiato                                 185.0       0.00425
# Hot Chocolate (Without Whipped Cream)             235.0       0.00525
# White Chocolate Mocha (Without Whipped Cream)     330.0       0.00750
#
#                                                Trans_Fat (g)  \
# Beverage
# Caramel Apple Spice (Without Whipped Cream)             0.00
# Caramel Macchiato                                       1.00
# Hot Chocolate (Without Whipped Cream)                   2.00
# White Chocolate Mocha (Without Whipped Cream)           4.75
#
#                                                Saturated_Fat(g)  Sodium(g)  \
# Beverage
# Caramel Apple Spice (Without Whipped Cream)                 0.0     0.0000
# Caramel Macchiato                                           0.0     0.0075
# Hot Chocolate (Without Whipped Cream)                       0.0     0.0050
# White Chocolate Mocha (Without Whipped Cream)               0.0     0.0075
#
#                                                Total_Carbohydrates(g)  \
# Beverage
# Caramel Apple Spice (Without Whipped Cream)                      17.5
# Caramel Macchiato                                               115.0
# Hot Chocolate (Without Whipped Cream)                           122.5
# White Chocolate Mocha (Without Whipped Cream)                   210.0
#
#                                                Cholesterol(g)  \
# Beverage
# Caramel Apple Spice (Without Whipped Cream)            0.0615
# Caramel Macchiato                                      0.0270
# Hot Chocolate (Without Whipped Cream)                  0.0390
# White Chocolate Mocha (Without Whipped Cream)          0.0515
#
#                                                Dietary_Fibre(g)  Sugars(g)  \
# Beverage
# Caramel Apple Spice (Without Whipped Cream)                 0.0       57.0
# Caramel Macchiato                                           0.0       24.0
# Hot Chocolate (Without Whipped Cream)                       2.0       32.0
# White Chocolate Mocha (Without Whipped Cream)               0.0       48.0
#
#                                                Protein(g)  VitaminA(% DV)  \
# Beverage
# Caramel Apple Spice (Without Whipped Cream)           0.0             0.0
# Caramel Macchiato                                     8.5            15.0
# Hot Chocolate (Without Whipped Cream)                11.5            15.0
# White Chocolate Mocha (Without Whipped Cream)        12.5            15.0
#
#                                                VitaminC(% DV)  Calcium(% DV)  \
# Beverage
# Caramel Apple Spice (Without Whipped Cream)               0.0            0.0
# Caramel Macchiato                                         0.0           27.5
# Hot Chocolate (Without Whipped Cream)                     0.0           35.0
# White Chocolate Mocha (Without Whipped Cream)             2.0           40.0
#
#                                                Iron(% DV)  Caffeine (g)
# Beverage
# Caramel Apple Spice (Without Whipped Cream)           0.0        0.0000
# Caramel Macchiato                                     0.0        0.1125
# Hot Chocolate (Without Whipped Cream)                25.0        0.0225
# White Chocolate Mocha (Without Whipped Cream)         2.0        0.1125

# %%
sig_espresso.T
# Out:
# Beverage                Caramel Apple Spice (Without Whipped Cream)  \
# Calories                                                   245.0000
# Total_Fat(g)                                                 0.0000
# Trans_Fat (g)                                                0.0000
# Saturated_Fat(g)                                             0.0000
# Sodium(g)                                                    0.0000
# Total_Carbohydrates(g)                                      17.5000
# Cholesterol(g)                                               0.0615
# Dietary_Fibre(g)                                             0.0000
# Sugars(g)                                                   57.0000
# Protein(g)                                                   0.0000
# VitaminA(% DV)                                               0.0000
# VitaminC(% DV)                                               0.0000
# Calcium(% DV)                                                0.0000
# Iron(% DV)                                                   0.0000
# Caffeine (g)                                                 0.0000
#
# Beverage                Caramel Macchiato  \
# Calories                        185.00000
# Total_Fat(g)                      0.00425
# Trans_Fat (g)                     1.00000
# Saturated_Fat(g)                  0.00000
# Sodium(g)                         0.00750
# Total_Carbohydrates(g)          115.00000
# Cholesterol(g)                    0.02700
# Dietary_Fibre(g)                  0.00000
# Sugars(g)                        24.00000
# Protein(g)                        8.50000
# VitaminA(% DV)                   15.00000
# VitaminC(% DV)                    0.00000
# Calcium(% DV)                    27.50000
# Iron(% DV)                        0.00000
# Caffeine (g)                      0.11250
#
# Beverage                Hot Chocolate (Without Whipped Cream)  \
# Calories                                            235.00000
# Total_Fat(g)                                          0.00525
# Trans_Fat (g)                                         2.00000
# Saturated_Fat(g)                                      0.00000
# Sodium(g)                                             0.00500
# Total_Carbohydrates(g)                              122.50000
# Cholesterol(g)                                        0.03900
# Dietary_Fibre(g)                                      2.00000
# Sugars(g)                                            32.00000
# Protein(g)                                           11.50000
# VitaminA(% DV)                                       15.00000
# VitaminC(% DV)                                        0.00000
# Calcium(% DV)                                        35.00000
# Iron(% DV)                                           25.00000
# Caffeine (g)                                          0.02250
#
# Beverage                White Chocolate Mocha (Without Whipped Cream)
# Calories                                                     330.0000
# Total_Fat(g)                                                   0.0075
# Trans_Fat (g)                                                  4.7500
# Saturated_Fat(g)                                               0.0000
# Sodium(g)                                                      0.0075
# Total_Carbohydrates(g)                                       210.0000
# Cholesterol(g)                                                 0.0515
# Dietary_Fibre(g)                                               0.0000
# Sugars(g)                                                     48.0000
# Protein(g)                                                    12.5000
# VitaminA(% DV)                                                15.0000
# VitaminC(% DV)                                                 2.0000
# Calcium(% DV)                                                 40.0000
# Iron(% DV)                                                     2.0000
# Caffeine (g)                                                   0.1125

# %%
_ = sig_espresso[['Trans_Fat (g)', 'Dietary_Fibre(g)', 'Protein(g)', 
                  'VitaminA(% DV)','VitaminC(% DV)', 'Calcium(% DV)', 'Iron(% DV)']].T.plot(kind='barh', stacked= True, color=['red', 'blue', 'green', 'orange'])
_ = plt.gcf().set_size_inches(20,10)
_ = plt.legend(bbox_to_anchor=[0.3,-0.1])
_ = plt.title('')
_ = plt.show()

# %%
_ = plt.figure(figsize=(10,6))
_ = sig_espresso[['Calories', 'Total_Carbohydrates(g)', 'Sugars(g)']].T.plot(kind='barh', stacked= True, color=['red', 'blue', 'green', 'orange'])
_ = plt.legend(bbox_to_anchor=[1,1])
_ = plt.show()

# %%
_ = plt.figure(figsize=(20,6))
_ = sig_espresso[['Total_Fat(g)', 'Saturated_Fat(g)','Cholesterol(g)','Sodium(g)', 'Caffeine (g)']].T.plot(kind='barh', stacked= True, color=['red', 'blue', 'green', 'orange'])
_ = plt.legend(bbox_to_anchor=[1,1])
_ = plt.show()

# %% [markdown]
# ### Shop by size!

# %%
test = clean_data

# %%
# Out:
# Index(['Coffee', 'Coffee', 'Coffee', 'Coffee', 'Classic Espresso Drinks',
#        'Classic Espresso Drinks', 'Classic Espresso Drinks',
#        'Classic Espresso Drinks', 'Classic Espresso Drinks',
#        'Classic Espresso Drinks',
#        ...
#        'Frappuccino® Blended Crème', 'Frappuccino® Blended Crème',
#        'Frappuccino® Blended Crème', 'Frappuccino® Blended Crème',
#        'Frappuccino® Blended Crème', 'Frappuccino® Blended Crème',
#        'Frappuccino® Blended Crème', 'Frappuccino® Blended Crème',
#        'Frappuccino® Blended Crème', 'Frappuccino® Blended Crème'],
#       dtype='object', name='Beverage_category', length=241)

# %%
grams = clean_data

# %%
grams[['Total_Fat(mg)','Trans_Fat (mg)', 'Saturated_Fat(mg)', 'Sodium(mg)',
              'Total_Carbohydrates(mg)', 'Cholesterol(mg)', 'Dietary_Fibre(mg)',
              'Sugars(mg)', 'Protein(mg)', 'Caffeine (mg)']] = grams[['Total_Fat(mg)','Trans_Fat (mg)', 'Saturated_Fat(mg)', 'Sodium(mg)',
              'Total_Carbohydrates(mg)', 'Cholesterol(mg)', 'Dietary_Fibre(mg)',
              'Sugars(mg)', 'Protein(mg)','Caffeine (mg)']]/1000

# %%
grams.columns = ['Calories', 'Total_Fat(g)', 'Trans_Fat (g)', 'Saturated_Fat(g)','Sodium(g)',
                               'Total_Carbohydrates(g)', 'Cholesterol(g)','Dietary_Fibre(g)', 'Sugars(g)', 
                               'Protein(g)', 'VitaminA(% DV)','VitaminC(% DV)', 'Calcium(% DV)', 
                               'Iron(% DV)', 'Caffeine (g)']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-167-94a838d4a3d4> in <module>
# ----> 1 grams.columns = ['Calories', 'Total_Fat(g)', 'Trans_Fat (g)', 'Saturated_Fat(g)','Sodium(g)',
#       2                                'Total_Carbohydrates(g)', 'Cholesterol(g)','Dietary_Fibre(g)', 'Sugars(g)',
#       3                                'Protein(g)', 'VitaminA(% DV)','VitaminC(% DV)', 'Calcium(% DV)',
#       4                                'Iron(% DV)', 'Caffeine (g)']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 17 elements, new values have 15 elements

# %%
df
# Out:
#                                                       Calories  Total_Fat(mg)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks               170.0           6.00
#                    Shaken Iced Beverages                 120.0           1.50
#                    Signature Espresso Drinks             265.0           7.50
#                    Smoothies                             290.0           2.00
#                    Tazo® Tea Drinks                      190.0           4.00
# Doppio             Classic Espresso Drinks                10.0           0.00
# Grande             Classic Espresso Drinks                15.0           0.00
#                    Coffee                                  5.0           0.10
#                    Shaken Iced Beverages                  90.0           0.00
#                    Signature Espresso Drinks             280.0           0.00
#                    Tazo® Tea Drinks                        0.0           0.00
# Grande Nonfat Milk Classic Espresso Drinks               130.0           0.30
#                    Frappuccino® Blended Coffee           270.0           0.55
#                    Frappuccino® Blended Crème            235.0           0.15
#                    Frappuccino® Light Blended Coffee     150.0           0.55
#                    Shaken Iced Beverages                 110.0           0.10
#                    Signature Espresso Drinks             240.0           2.50
#                    Smoothies                             280.0           1.00
#                    Tazo® Tea Drinks                      180.0           0.20
# Short              Classic Espresso Drinks                 5.0           0.00
#                    Coffee                                  3.0           0.10
#                    Signature Espresso Drinks             140.0           0.00
#                    Tazo® Tea Drinks                        0.0           0.00
# Short Nonfat Milk  Classic Espresso Drinks                70.0           0.10
#                    Signature Espresso Drinks             130.0           1.50
#                    Tazo® Tea Drinks                       90.0           0.10
# Solo               Classic Espresso Drinks                 5.0           0.00
# Soymilk            Classic Espresso Drinks               135.0           4.50
#                    Frappuccino® Blended Coffee           260.0           2.50
#                    Frappuccino® Blended Crème            180.0           1.50
#                    Shaken Iced Beverages                 110.0           1.00
#                    Signature Espresso Drinks             225.0           6.50
#                    Smoothies                             290.0           2.00
#                    Tazo® Tea Drinks                      170.0           3.50
# Tall               Classic Espresso Drinks                10.0           0.00
#                    Coffee                                  4.0           0.10
#                    Shaken Iced Beverages                  60.0           0.00
#                    Signature Espresso Drinks             210.0           0.00
#                    Tazo® Tea Drinks                        0.0           0.00
# Tall Nonfat Milk   Classic Espresso Drinks               100.0           0.20
#                    Frappuccino® Blended Coffee           180.0           0.30
#                    Frappuccino® Blended Crème            170.0           0.10
#                    Frappuccino® Light Blended Coffee     105.0           0.30
#                    Shaken Iced Beverages                  80.0           0.10
#                    Signature Espresso Drinks             190.0           2.00
#                    Tazo® Tea Drinks                      140.0           0.15
# Venti              Classic Espresso Drinks                25.0           0.00
#                    Coffee                                  5.0           0.10
#                    Shaken Iced Beverages                 130.0           0.00
#                    Signature Espresso Drinks             360.0           0.00
#                    Tazo® Tea Drinks                        0.0           0.00
# Venti Nonfat Milk  Classic Espresso Drinks               170.0           0.30
#                    Frappuccino® Blended Coffee           335.0           0.55
#                    Frappuccino® Blended Crème            310.0           0.20
#                    Frappuccino® Light Blended Coffee     205.0           0.55
#                    Shaken Iced Beverages                 160.0           0.10
#                    Signature Espresso Drinks             320.0           3.00
#                    Tazo® Tea Drinks                      225.0           0.25
# Whole Milk         Frappuccino® Blended Coffee           285.0           4.50
#                    Frappuccino® Blended Crème            230.0           3.75
#
#                                                       Trans_Fat (mg)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks                    3000.0
#                    Shaken Iced Beverages                       500.0
#                    Signature Espresso Drinks                  4000.0
#                    Smoothies                                  1000.0
#                    Tazo® Tea Drinks                           2000.0
# Doppio             Classic Espresso Drinks                       0.0
# Grande             Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Grande Nonfat Milk Classic Espresso Drinks                     200.0
#                    Frappuccino® Blended Coffee                 300.0
#                    Frappuccino® Blended Crème                  100.0
#                    Frappuccino® Light Blended Coffee           300.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                  1500.0
#                    Smoothies                                   300.0
#                    Tazo® Tea Drinks                            100.0
# Short              Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Short Nonfat Milk  Classic Espresso Drinks                     100.0
#                    Signature Espresso Drinks                  1000.0
#                    Tazo® Tea Drinks                            100.0
# Solo               Classic Espresso Drinks                       0.0
# Soymilk            Classic Espresso Drinks                     500.0
#                    Frappuccino® Blended Coffee                 400.0
#                    Frappuccino® Blended Crème                  200.0
#                    Shaken Iced Beverages                       100.0
#                    Signature Espresso Drinks                  1750.0
#                    Smoothies                                   400.0
#                    Tazo® Tea Drinks                            400.0
# Tall               Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Tall Nonfat Milk   Classic Espresso Drinks                     100.0
#                    Frappuccino® Blended Coffee                 200.0
#                    Frappuccino® Blended Crème                  100.0
#                    Frappuccino® Light Blended Coffee           200.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                  1000.0
#                    Tazo® Tea Drinks                            100.0
# Venti              Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Venti Nonfat Milk  Classic Espresso Drinks                     200.0
#                    Frappuccino® Blended Coffee                 300.0
#                    Frappuccino® Blended Crème                  100.0
#                    Frappuccino® Light Blended Coffee           300.0
#                    Shaken Iced Beverages                       100.0
#                    Signature Espresso Drinks                  2000.0
#                    Tazo® Tea Drinks                            150.0
# Whole Milk         Frappuccino® Blended Coffee                2750.0
#                    Frappuccino® Blended Crème                 2000.0
#
#                                                       Saturated_Fat(mg)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks                        200.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                      200.0
#                    Smoothies                                        0.0
#                    Tazo® Tea Drinks                               100.0
# Doppio             Classic Espresso Drinks                          0.0
# Grande             Classic Espresso Drinks                          0.0
#                    Coffee                                           0.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Grande Nonfat Milk Classic Espresso Drinks                          0.0
#                    Frappuccino® Blended Coffee                      0.0
#                    Frappuccino® Blended Crème                       0.0
#                    Frappuccino® Light Blended Coffee                0.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Smoothies                                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Short              Classic Espresso Drinks                          0.0
#                    Coffee                                           0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Short Nonfat Milk  Classic Espresso Drinks                          0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Solo               Classic Espresso Drinks                          0.0
# Soymilk            Classic Espresso Drinks                          0.0
#                    Frappuccino® Blended Coffee                      0.0
#                    Frappuccino® Blended Crème                       0.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Smoothies                                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Tall               Classic Espresso Drinks                          0.0
#                    Coffee                                           0.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Tall Nonfat Milk   Classic Espresso Drinks                          0.0
#                    Frappuccino® Blended Coffee                      0.0
#                    Frappuccino® Blended Crème                       0.0
#                    Frappuccino® Light Blended Coffee                0.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Venti              Classic Espresso Drinks                          0.0
#                    Coffee                                           0.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Venti Nonfat Milk  Classic Espresso Drinks                          0.0
#                    Frappuccino® Blended Coffee                      0.0
#                    Frappuccino® Blended Crème                       0.0
#                    Frappuccino® Light Blended Coffee                0.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Whole Milk         Frappuccino® Blended Coffee                    100.0
#                    Frappuccino® Blended Crème                     100.0
#
#                                                       Sodium(mg)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks                  22.5
#                    Shaken Iced Beverages                     5.0
#                    Signature Espresso Drinks                22.5
#                    Smoothies                                 5.0
#                    Tazo® Tea Drinks                         15.0
# Doppio             Classic Espresso Drinks                   0.0
# Grande             Classic Espresso Drinks                   0.0
#                    Coffee                                    0.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                 0.0
#                    Tazo® Tea Drinks                          0.0
# Grande Nonfat Milk Classic Espresso Drinks                   5.0
#                    Frappuccino® Blended Coffee               0.0
#                    Frappuccino® Blended Crème                2.5
#                    Frappuccino® Light Blended Coffee         0.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                10.0
#                    Smoothies                                 5.0
#                    Tazo® Tea Drinks                          5.0
# Short              Classic Espresso Drinks                   0.0
#                    Coffee                                    0.0
#                    Signature Espresso Drinks                 0.0
#                    Tazo® Tea Drinks                          0.0
# Short Nonfat Milk  Classic Espresso Drinks                   5.0
#                    Signature Espresso Drinks                 5.0
#                    Tazo® Tea Drinks                          0.0
# Solo               Classic Espresso Drinks                   0.0
# Soymilk            Classic Espresso Drinks                   0.0
#                    Frappuccino® Blended Coffee               0.0
#                    Frappuccino® Blended Crème                0.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                 0.0
#                    Smoothies                                 5.0
#                    Tazo® Tea Drinks                          0.0
# Tall               Classic Espresso Drinks                   0.0
#                    Coffee                                    0.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                 0.0
#                    Tazo® Tea Drinks                          0.0
# Tall Nonfat Milk   Classic Espresso Drinks                   5.0
#                    Frappuccino® Blended Coffee               0.0
#                    Frappuccino® Blended Crème                0.0
#                    Frappuccino® Light Blended Coffee         0.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                 5.0
#                    Tazo® Tea Drinks                          5.0
# Venti              Classic Espresso Drinks                   0.0
#                    Coffee                                    0.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                 0.0
#                    Tazo® Tea Drinks                          0.0
# Venti Nonfat Milk  Classic Espresso Drinks                  10.0
#                    Frappuccino® Blended Coffee               5.0
#                    Frappuccino® Blended Crème                5.0
#                    Frappuccino® Light Blended Coffee         5.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                10.0
#                    Tazo® Tea Drinks                          5.0
# Whole Milk         Frappuccino® Blended Coffee              10.0
#                    Frappuccino® Blended Crème               10.0
#
#                                                       Total_Carbohydrates(mg)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks                           130000.0
#                    Shaken Iced Beverages                              35000.0
#                    Signature Espresso Drinks                         155000.0
#                    Smoothies                                         125000.0
#                    Tazo® Tea Drinks                                   95000.0
# Doppio             Classic Espresso Drinks                             1000.0
# Grande             Classic Espresso Drinks                            15000.0
#                    Coffee                                             10000.0
#                    Shaken Iced Beverages                                  0.0
#                    Signature Espresso Drinks                          20000.0
#                    Tazo® Tea Drinks                                       0.0
# Grande Nonfat Milk Classic Espresso Drinks                           140000.0
#                    Frappuccino® Blended Coffee                       220000.0
#                    Frappuccino® Blended Crème                        210000.0
#                    Frappuccino® Light Blended Coffee                 205000.0
#                    Shaken Iced Beverages                              30000.0
#                    Signature Espresso Drinks                         140000.0
#                    Smoothies                                         125000.0
#                    Tazo® Tea Drinks                                   95000.0
# Short              Classic Espresso Drinks                             5000.0
#                    Coffee                                              5000.0
#                    Signature Espresso Drinks                          10000.0
#                    Tazo® Tea Drinks                                       0.0
# Short Nonfat Milk  Classic Espresso Drinks                            70000.0
#                    Signature Espresso Drinks                          70000.0
#                    Tazo® Tea Drinks                                   47500.0
# Solo               Classic Espresso Drinks                                0.0
# Soymilk            Classic Espresso Drinks                           100000.0
#                    Frappuccino® Blended Coffee                       220000.0
#                    Frappuccino® Blended Crème                        160000.0
#                    Shaken Iced Beverages                              30000.0
#                    Signature Espresso Drinks                         120000.0
#                    Smoothies                                         120000.0
#                    Tazo® Tea Drinks                                   80000.0
# Tall               Classic Espresso Drinks                            10000.0
#                    Coffee                                             10000.0
#                    Shaken Iced Beverages                                  0.0
#                    Signature Espresso Drinks                          15000.0
#                    Tazo® Tea Drinks                                       0.0
# Tall Nonfat Milk   Classic Espresso Drinks                           110000.0
#                    Frappuccino® Blended Coffee                       160000.0
#                    Frappuccino® Blended Crème                        150000.0
#                    Frappuccino® Light Blended Coffee                 155000.0
#                    Shaken Iced Beverages                              25000.0
#                    Signature Espresso Drinks                         110000.0
#                    Tazo® Tea Drinks                                   72500.0
# Venti              Classic Espresso Drinks                            15000.0
#                    Coffee                                             10000.0
#                    Shaken Iced Beverages                                  0.0
#                    Signature Espresso Drinks                          25000.0
#                    Tazo® Tea Drinks                                       0.0
# Venti Nonfat Milk  Classic Espresso Drinks                           180000.0
#                    Frappuccino® Blended Coffee                       300000.0
#                    Frappuccino® Blended Crème                        260000.0
#                    Frappuccino® Light Blended Coffee                 275000.0
#                    Shaken Iced Beverages                              50000.0
#                    Signature Espresso Drinks                         180000.0
#                    Tazo® Tea Drinks                                  122500.0
# Whole Milk         Frappuccino® Blended Coffee                       220000.0
#                    Frappuccino® Blended Crème                        175000.0
#
#                                                       Cholesterol(mg)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks                       20.0
#                    Shaken Iced Beverages                         24.0
#                    Signature Espresso Drinks                     40.0
#                    Smoothies                                     53.0
#                    Tazo® Tea Drinks                              32.5
# Doppio             Classic Espresso Drinks                        2.0
# Grande             Classic Espresso Drinks                        3.0
#                    Coffee                                         0.0
#                    Shaken Iced Beverages                         21.0
#                    Signature Espresso Drinks                     70.0
#                    Tazo® Tea Drinks                               0.0
# Grande Nonfat Milk Classic Espresso Drinks                       19.0
#                    Frappuccino® Blended Coffee                   60.5
#                    Frappuccino® Blended Crème                    54.5
#                    Frappuccino® Light Blended Coffee             33.0
#                    Shaken Iced Beverages                         24.0
#                    Signature Espresso Drinks                     48.0
#                    Smoothies                                     54.0
#                    Tazo® Tea Drinks                              38.0
# Short              Classic Espresso Drinks                        1.0
#                    Coffee                                         0.0
#                    Signature Espresso Drinks                     35.0
#                    Tazo® Tea Drinks                               0.0
# Short Nonfat Milk  Classic Espresso Drinks                       10.0
#                    Signature Espresso Drinks                     26.0
#                    Tazo® Tea Drinks                              19.0
# Solo               Classic Espresso Drinks                        1.0
# Soymilk            Classic Espresso Drinks                       16.0
#                    Frappuccino® Blended Coffee                   58.5
#                    Frappuccino® Blended Crème                    37.0
#                    Shaken Iced Beverages                         23.0
#                    Signature Espresso Drinks                     34.0
#                    Smoothies                                     53.0
#                    Tazo® Tea Drinks                              29.0
# Tall               Classic Espresso Drinks                        2.0
#                    Coffee                                         0.0
#                    Shaken Iced Beverages                         15.0
#                    Signature Espresso Drinks                     53.0
#                    Tazo® Tea Drinks                               0.0
# Tall Nonfat Milk   Classic Espresso Drinks                       15.0
#                    Frappuccino® Blended Coffee                   42.0
#                    Frappuccino® Blended Crème                    39.0
#                    Frappuccino® Light Blended Coffee             23.5
#                    Shaken Iced Beverages                         18.0
#                    Signature Espresso Drinks                     37.0
#                    Tazo® Tea Drinks                              28.5
# Venti              Classic Espresso Drinks                        4.0
#                    Coffee                                         0.0
#                    Shaken Iced Beverages                         31.0
#                    Signature Espresso Drinks                     89.0
#                    Tazo® Tea Drinks                               0.0
# Venti Nonfat Milk  Classic Espresso Drinks                       25.0
#                    Frappuccino® Blended Coffee                   79.0
#                    Frappuccino® Blended Crème                    70.0
#                    Frappuccino® Light Blended Coffee             45.0
#                    Shaken Iced Beverages                         36.0
#                    Signature Espresso Drinks                     63.0
#                    Tazo® Tea Drinks                              48.0
# Whole Milk         Frappuccino® Blended Coffee                   60.5
#                    Frappuccino® Blended Crème                    46.0
#
#                                                       Dietary_Fibre(mg)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks                          0.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Smoothies                                     7000.0
#                    Tazo® Tea Drinks                                 0.0
# Doppio             Classic Espresso Drinks                          0.0
# Grande             Classic Espresso Drinks                          0.0
#                    Coffee                                           0.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Grande Nonfat Milk Classic Espresso Drinks                          0.0
#                    Frappuccino® Blended Coffee                    500.0
#                    Frappuccino® Blended Crème                       0.0
#                    Frappuccino® Light Blended Coffee              500.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Smoothies                                     7000.0
#                    Tazo® Tea Drinks                                 0.0
# Short              Classic Espresso Drinks                          0.0
#                    Coffee                                           0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Short Nonfat Milk  Classic Espresso Drinks                          0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Solo               Classic Espresso Drinks                          0.0
# Soymilk            Classic Espresso Drinks                       1000.0
#                    Frappuccino® Blended Coffee                   1000.0
#                    Frappuccino® Blended Crème                    1000.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                     1000.0
#                    Smoothies                                     7000.0
#                    Tazo® Tea Drinks                              1000.0
# Tall               Classic Espresso Drinks                          0.0
#                    Coffee                                           0.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Tall Nonfat Milk   Classic Espresso Drinks                          0.0
#                    Frappuccino® Blended Coffee                    500.0
#                    Frappuccino® Blended Crème                       0.0
#                    Frappuccino® Light Blended Coffee              500.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Venti              Classic Espresso Drinks                          0.0
#                    Coffee                                           0.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Venti Nonfat Milk  Classic Espresso Drinks                          0.0
#                    Frappuccino® Blended Coffee                    500.0
#                    Frappuccino® Blended Crème                       0.0
#                    Frappuccino® Light Blended Coffee              500.0
#                    Shaken Iced Beverages                            0.0
#                    Signature Espresso Drinks                        0.0
#                    Tazo® Tea Drinks                                 0.0
# Whole Milk         Frappuccino® Blended Coffee                    500.0
#                    Frappuccino® Blended Crème                       0.0
#
#                                                       Sugars(mg)  Protein(mg)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks               17000.0      10000.0
#                    Shaken Iced Beverages                 24000.0       2000.0
#                    Signature Espresso Drinks             36000.0      10500.0
#                    Smoothies                             37000.0      16000.0
#                    Tazo® Tea Drinks                      31000.0       7000.0
# Doppio             Classic Espresso Drinks                   0.0       1000.0
# Grande             Classic Espresso Drinks                   0.0       1000.0
#                    Coffee                                    0.0       1000.0
#                    Shaken Iced Beverages                 21000.0        100.0
#                    Signature Espresso Drinks             65000.0          0.0
#                    Tazo® Tea Drinks                          0.0          0.0
# Grande Nonfat Milk Classic Espresso Drinks               18000.0      12000.0
#                    Frappuccino® Blended Coffee           58500.0       4000.0
#                    Frappuccino® Blended Crème            53500.0       4500.0
#                    Frappuccino® Light Blended Coffee     31000.0       3500.0
#                    Shaken Iced Beverages                 24000.0       2000.0
#                    Signature Espresso Drinks             41000.0      14000.0
#                    Smoothies                             37000.0      16000.0
#                    Tazo® Tea Drinks                      37000.0       7500.0
# Short              Classic Espresso Drinks                   0.0        400.0
#                    Coffee                                    0.0        300.0
#                    Signature Espresso Drinks             33000.0          0.0
#                    Tazo® Tea Drinks                          0.0          0.0
# Short Nonfat Milk  Classic Espresso Drinks                9000.0       6000.0
#                    Signature Espresso Drinks             23000.0       7000.0
#                    Tazo® Tea Drinks                      18500.0       4000.0
# Solo               Classic Espresso Drinks                   0.0        400.0
# Soymilk            Classic Espresso Drinks               12000.0       8500.0
#                    Frappuccino® Blended Coffee           55500.0       3500.0
#                    Frappuccino® Blended Crème            35000.0       3000.0
#                    Shaken Iced Beverages                 22000.0       2000.0
#                    Signature Espresso Drinks             28000.0       9500.0
#                    Smoothies                             36000.0      16000.0
#                    Tazo® Tea Drinks                      26500.0       6000.0
# Tall               Classic Espresso Drinks                   0.0       1000.0
#                    Coffee                                    0.0        500.0
#                    Shaken Iced Beverages                 15000.0        100.0
#                    Signature Espresso Drinks             49000.0          0.0
#                    Tazo® Tea Drinks                          0.0          0.0
# Tall Nonfat Milk   Classic Espresso Drinks               14000.0       9000.0
#                    Frappuccino® Blended Coffee           40500.0       3000.0
#                    Frappuccino® Blended Crème            38000.0       3500.0
#                    Frappuccino® Light Blended Coffee     23000.0       3000.0
#                    Shaken Iced Beverages                 18000.0       2000.0
#                    Signature Espresso Drinks             32000.0      11000.0
#                    Tazo® Tea Drinks                      27500.0       5500.0
# Venti              Classic Espresso Drinks                   0.0       1000.0
#                    Coffee                                    0.0       1000.0
#                    Shaken Iced Beverages                 31000.0        100.0
#                    Signature Espresso Drinks             83000.0          0.0
#                    Tazo® Tea Drinks                          0.0          0.0
# Venti Nonfat Milk  Classic Espresso Drinks               23000.0      15000.0
#                    Frappuccino® Blended Coffee           76500.0       6500.0
#                    Frappuccino® Blended Crème            69000.0       6000.0
#                    Frappuccino® Light Blended Coffee     42500.0       5500.0
#                    Shaken Iced Beverages                 36000.0       4000.0
#                    Signature Espresso Drinks             55000.0      18000.0
#                    Tazo® Tea Drinks                      46500.0       9500.0
# Whole Milk         Frappuccino® Blended Coffee           58500.0       4000.0
#                    Frappuccino® Blended Crème            45000.0       3500.0
#
#                                                       VitaminA(% DV)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks                      15.0
#                    Shaken Iced Beverages                         4.0
#                    Signature Espresso Drinks                    15.0
#                    Smoothies                                     8.0
#                    Tazo® Tea Drinks                             10.0
# Doppio             Classic Espresso Drinks                       0.0
# Grande             Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Grande Nonfat Milk Classic Espresso Drinks                      20.0
#                    Frappuccino® Blended Coffee                   6.0
#                    Frappuccino® Blended Crème                    8.0
#                    Frappuccino® Light Blended Coffee             6.0
#                    Shaken Iced Beverages                         4.0
#                    Signature Espresso Drinks                    20.0
#                    Smoothies                                    10.0
#                    Tazo® Tea Drinks                             15.0
# Short              Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Short Nonfat Milk  Classic Espresso Drinks                      10.0
#                    Signature Espresso Drinks                    10.0
#                    Tazo® Tea Drinks                              6.0
# Solo               Classic Espresso Drinks                       0.0
# Soymilk            Classic Espresso Drinks                      10.0
#                    Frappuccino® Blended Coffee                   4.0
#                    Frappuccino® Blended Crème                    4.0
#                    Shaken Iced Beverages                         2.0
#                    Signature Espresso Drinks                    10.0
#                    Smoothies                                     6.0
#                    Tazo® Tea Drinks                              8.0
# Tall               Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Tall Nonfat Milk   Classic Espresso Drinks                      15.0
#                    Frappuccino® Blended Coffee                   4.0
#                    Frappuccino® Blended Crème                    6.0
#                    Frappuccino® Light Blended Coffee             4.0
#                    Shaken Iced Beverages                         2.0
#                    Signature Espresso Drinks                    15.0
#                    Tazo® Tea Drinks                             10.0
# Venti              Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Venti Nonfat Milk  Classic Espresso Drinks                      25.0
#                    Frappuccino® Blended Coffee                  10.0
#                    Frappuccino® Blended Crème                   10.0
#                    Frappuccino® Light Blended Coffee             8.0
#                    Shaken Iced Beverages                         6.0
#                    Signature Espresso Drinks                    25.0
#                    Tazo® Tea Drinks                             15.0
# Whole Milk         Frappuccino® Blended Coffee                   4.0
#                    Frappuccino® Blended Crème                    6.0
#
#                                                       VitaminC(% DV)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks                       0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     2.0
#                    Smoothies                                    80.0
#                    Tazo® Tea Drinks                              0.0
# Doppio             Classic Espresso Drinks                       0.0
# Grande             Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Grande Nonfat Milk Classic Espresso Drinks                       0.0
#                    Frappuccino® Blended Coffee                   0.0
#                    Frappuccino® Blended Crème                    3.0
#                    Frappuccino® Light Blended Coffee             0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Smoothies                                    80.0
#                    Tazo® Tea Drinks                              0.0
# Short              Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Short Nonfat Milk  Classic Espresso Drinks                       0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Solo               Classic Espresso Drinks                       0.0
# Soymilk            Classic Espresso Drinks                       0.0
#                    Frappuccino® Blended Coffee                   0.0
#                    Frappuccino® Blended Crème                    6.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Smoothies                                    80.0
#                    Tazo® Tea Drinks                              0.0
# Tall               Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Tall Nonfat Milk   Classic Espresso Drinks                       0.0
#                    Frappuccino® Blended Coffee                   0.0
#                    Frappuccino® Blended Crème                    3.0
#                    Frappuccino® Light Blended Coffee             0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Venti              Classic Espresso Drinks                       0.0
#                    Coffee                                        0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Venti Nonfat Milk  Classic Espresso Drinks                       0.0
#                    Frappuccino® Blended Coffee                   0.0
#                    Frappuccino® Blended Crème                    8.0
#                    Frappuccino® Light Blended Coffee             0.0
#                    Shaken Iced Beverages                         0.0
#                    Signature Espresso Drinks                     0.0
#                    Tazo® Tea Drinks                              0.0
# Whole Milk         Frappuccino® Blended Coffee                   0.0
#                    Frappuccino® Blended Crème                    6.0
#
#                                                       Calcium(% DV)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks                     30.0
#                    Shaken Iced Beverages                        8.0
#                    Signature Espresso Drinks                   32.5
#                    Smoothies                                   10.0
#                    Tazo® Tea Drinks                            25.0
# Doppio             Classic Espresso Drinks                      0.0
# Grande             Classic Espresso Drinks                      2.0
#                    Coffee                                       0.0
#                    Shaken Iced Beverages                        0.0
#                    Signature Espresso Drinks                    0.0
#                    Tazo® Tea Drinks                             0.0
# Grande Nonfat Milk Classic Espresso Drinks                     35.0
#                    Frappuccino® Blended Coffee                 10.0
#                    Frappuccino® Blended Crème                  15.0
#                    Frappuccino® Light Blended Coffee           10.0
#                    Shaken Iced Beverages                        8.0
#                    Signature Espresso Drinks                   40.0
#                    Smoothies                                   10.0
#                    Tazo® Tea Drinks                            25.0
# Short              Classic Espresso Drinks                      0.0
#                    Coffee                                       0.0
#                    Signature Espresso Drinks                    0.0
#                    Tazo® Tea Drinks                             0.0
# Short Nonfat Milk  Classic Espresso Drinks                     20.0
#                    Signature Espresso Drinks                   20.0
#                    Tazo® Tea Drinks                            10.0
# Solo               Classic Espresso Drinks                      0.0
# Soymilk            Classic Espresso Drinks                     30.0
#                    Frappuccino® Blended Coffee                 10.0
#                    Frappuccino® Blended Crème                  10.0
#                    Shaken Iced Beverages                        8.0
#                    Signature Espresso Drinks                   35.0
#                    Smoothies                                   10.0
#                    Tazo® Tea Drinks                            25.0
# Tall               Classic Espresso Drinks                      2.0
#                    Coffee                                       0.0
#                    Shaken Iced Beverages                        0.0
#                    Signature Espresso Drinks                    0.0
#                    Tazo® Tea Drinks                             0.0
# Tall Nonfat Milk   Classic Espresso Drinks                     30.0
#                    Frappuccino® Blended Coffee                 10.0
#                    Frappuccino® Blended Crème                  10.0
#                    Frappuccino® Light Blended Coffee            9.0
#                    Shaken Iced Beverages                        6.0
#                    Signature Espresso Drinks                   30.0
#                    Tazo® Tea Drinks                            20.0
# Venti              Classic Espresso Drinks                      2.0
#                    Coffee                                       2.0
#                    Shaken Iced Beverages                        0.0
#                    Signature Espresso Drinks                    0.0
#                    Tazo® Tea Drinks                             0.0
# Venti Nonfat Milk  Classic Espresso Drinks                     50.0
#                    Frappuccino® Blended Coffee                 17.5
#                    Frappuccino® Blended Crème                  20.0
#                    Frappuccino® Light Blended Coffee           15.0
#                    Shaken Iced Beverages                       10.0
#                    Signature Espresso Drinks                   50.0
#                    Tazo® Tea Drinks                            32.5
# Whole Milk         Frappuccino® Blended Coffee                 10.0
#                    Frappuccino® Blended Crème                  12.5
#
#                                                       Iron(% DV)  \
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks                   0.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                 0.0
#                    Smoothies                                 8.0
#                    Tazo® Tea Drinks                          0.0
# Doppio             Classic Espresso Drinks                   0.0
# Grande             Classic Espresso Drinks                   0.0
#                    Coffee                                    0.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                 0.0
#                    Tazo® Tea Drinks                          0.0
# Grande Nonfat Milk Classic Espresso Drinks                   0.0
#                    Frappuccino® Blended Coffee               6.0
#                    Frappuccino® Blended Crème                2.0
#                    Frappuccino® Light Blended Coffee         4.0
#                    Shaken Iced Beverages                     2.0
#                    Signature Espresso Drinks                 2.0
#                    Smoothies                                 8.0
#                    Tazo® Tea Drinks                          1.0
# Short              Classic Espresso Drinks                   0.0
#                    Coffee                                    0.0
#                    Signature Espresso Drinks                 0.0
#                    Tazo® Tea Drinks                          0.0
# Short Nonfat Milk  Classic Espresso Drinks                   0.0
#                    Signature Espresso Drinks                 0.0
#                    Tazo® Tea Drinks                          0.0
# Solo               Classic Espresso Drinks                   0.0
# Soymilk            Classic Espresso Drinks                  15.0
#                    Frappuccino® Blended Coffee               9.0
#                    Frappuccino® Blended Crème                6.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                17.5
#                    Smoothies                                 8.0
#                    Tazo® Tea Drinks                         10.0
# Tall               Classic Espresso Drinks                   0.0
#                    Coffee                                    0.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                 0.0
#                    Tazo® Tea Drinks                          0.0
# Tall Nonfat Milk   Classic Espresso Drinks                   0.0
#                    Frappuccino® Blended Coffee               9.0
#                    Frappuccino® Blended Crème                1.0
#                    Frappuccino® Light Blended Coffee         3.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                 0.0
#                    Tazo® Tea Drinks                          1.0
# Venti              Classic Espresso Drinks                   0.0
#                    Coffee                                    0.0
#                    Shaken Iced Beverages                     0.0
#                    Signature Espresso Drinks                 0.0
#                    Tazo® Tea Drinks                          0.0
# Venti Nonfat Milk  Classic Espresso Drinks                   0.0
#                    Frappuccino® Blended Coffee               8.0
#                    Frappuccino® Blended Crème                4.0
#                    Frappuccino® Light Blended Coffee         6.0
#                    Shaken Iced Beverages                     4.0
#                    Signature Espresso Drinks                 2.0
#                    Tazo® Tea Drinks                          1.0
# Whole Milk         Frappuccino® Blended Coffee               4.0
#                    Frappuccino® Blended Crème                3.0
#
#                                                       Caffeine (mg)
# Beverage_prep      Beverage_category
# 2% Milk            Classic Espresso Drinks               122.500000
#                    Shaken Iced Beverages                 125.000000
#                    Signature Espresso Drinks              75.000000
#                    Smoothies                               0.000000
#                    Tazo® Tea Drinks                       75.000000
# Doppio             Classic Espresso Drinks               150.000000
# Grande             Classic Espresso Drinks               225.000000
#                    Coffee                                330.000000
#                    Shaken Iced Beverages                  89.931193
#                    Signature Espresso Drinks               0.000000
#                    Tazo® Tea Drinks                       89.931193
# Grande Nonfat Milk Classic Espresso Drinks               150.000000
#                    Frappuccino® Blended Coffee           105.000000
#                    Frappuccino® Blended Crème              0.000000
#                    Frappuccino® Light Blended Coffee      95.000000
#                    Shaken Iced Beverages                  90.000000
#                    Signature Espresso Drinks             150.000000
#                    Smoothies                              15.000000
#                    Tazo® Tea Drinks                       84.965596
# Short              Classic Espresso Drinks                75.000000
#                    Coffee                                175.000000
#                    Signature Espresso Drinks               0.000000
#                    Tazo® Tea Drinks                       89.931193
# Short Nonfat Milk  Classic Espresso Drinks                75.000000
#                    Signature Espresso Drinks              75.000000
#                    Tazo® Tea Drinks                       37.500000
# Solo               Classic Espresso Drinks                75.000000
# Soymilk            Classic Espresso Drinks               122.500000
#                    Frappuccino® Blended Coffee           105.000000
#                    Frappuccino® Blended Crème              0.000000
#                    Shaken Iced Beverages                 125.000000
#                    Signature Espresso Drinks              75.000000
#                    Smoothies                               0.000000
#                    Tazo® Tea Drinks                       75.000000
# Tall               Classic Espresso Drinks               150.000000
#                    Coffee                                260.000000
#                    Shaken Iced Beverages                 120.000000
#                    Signature Espresso Drinks               0.000000
#                    Tazo® Tea Drinks                       89.931193
# Tall Nonfat Milk   Classic Espresso Drinks                75.000000
#                    Frappuccino® Blended Coffee            72.500000
#                    Frappuccino® Blended Crème              0.000000
#                    Frappuccino® Light Blended Coffee      70.000000
#                    Shaken Iced Beverages                  90.000000
#                    Signature Espresso Drinks              75.000000
#                    Tazo® Tea Drinks                       62.500000
# Venti              Classic Espresso Drinks               300.000000
#                    Coffee                                410.000000
#                    Shaken Iced Beverages                  89.931193
#                    Signature Espresso Drinks               0.000000
#                    Tazo® Tea Drinks                       89.931193
# Venti Nonfat Milk  Classic Espresso Drinks               150.000000
#                    Frappuccino® Blended Coffee           135.000000
#                    Frappuccino® Blended Crème              0.000000
#                    Frappuccino® Light Blended Coffee     125.000000
#                    Shaken Iced Beverages                 125.000000
#                    Signature Espresso Drinks             150.000000
#                    Tazo® Tea Drinks                       99.965596
# Whole Milk         Frappuccino® Blended Coffee           105.000000
#                    Frappuccino® Blended Crème              0.000000

# %%
_ = plt.figure(figsize=(10,6))
_ = df.loc['2% Milk'].plot(kind='barh', stacked=True)
_ = plt.legend(bbox_to_anchor=[1,1])
_ = plt.xticks(np.arange(0))

# %%
df['']
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])
