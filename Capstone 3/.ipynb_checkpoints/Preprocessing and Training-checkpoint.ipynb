# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import spacy

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, matthews_corrcoef
from sklearn.naive_bayes import MultinomialNB

# %%
data = pd.read_csv('processed_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  target                                               text  \
# 0        7299       1  footage strong san bernardino county working t...
# 1         810       0  locksmithingart respecting elaboration blight ...
# 2         188       0                          nissan medical assistance
# 3        3745       0                                asshole stcoyfoghgt
# 4        5160       0                            obliterate shadow realm
#
#                                               tokens  \
# 0  ['footage', 'strong', 'san', 'bernardino', 'co...
# 1  ['locksmithingart', 'respecting', 'elaboration...
# 2                ['nissan', 'medical', 'assistance']
# 3                         ['asshole', 'stcoyfoghgt']
# 4                  ['obliterate', 'shadow', 'realm']
#
#                                               lemmas  num_chars  num_words  \
# 0  ['footage', 'strong', 'san', 'bernardino', 'co...        137         21
# 1  ['locksmithingart', 'respecting', 'elaboration...         64          7
# 2                ['nissan', 'medical', 'assistance']        121         21
# 3                         ['asshole', 'stcoyfoghgt']         46          6
# 4                  ['obliterate', 'shadow', 'realm']         53          8
#
#    mean_word_length  num_hashtags  mentions  emojis  num_proper_nouns  \
# 0          5.571429             0         0       0                 5
# 1          8.285714             0         0       0                 0
# 2          4.809524             0         2       0                 1
# 3          6.666667             0         0       0                 0
# 4          5.750000             0         1       0                 1
#
#    num_nouns
# 0          3
# 1          4
# 2          4
# 3          4
# 4          2

# %%
X= data.lemmas
y = data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 10)

# %% [markdown]
# ## N_grams

# %% [markdown]
# ## Bag of Words

# %%
vectorizer = CountVectorizer()
embedding = vectorizer.fit_transform(data)
X = data['text'].tolist()
y = data['target'].tolist()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 10)
X_train
# Out:
# ['servicin section lurkin',
#  'tcoxyeuyltx twelve feared killed pakistani helicopter tcougrmdzn',
#  'derailment patna tcoygfcqgr',
#  'hermancranston wired reddit quarantine offensive tcowvngriypq tcoreipuwpu_',
#  'stuart broad prime minister sport seen aussies bless',
#  'outbreak legionnaires disease york killed officials fo tcoevyelwlc',
#  'strict liability context airplane pilot error common component aviation cr tcoczbohrd',
#  'sharing cousins tcolsjowgyvqh',
#  'tribal turned ie madinah',
#  'pick tozlet seat butt leprosy fullblown jerkface syndrome lateral lisp toilet rickets',
#  'sincere',
#  'thank shipping microbes department defense tcozahnewjri',
#  'christian muslims temple mount waving israeli flag pamela geller tcoeydbmdx',
#  'michael jumper',
#  'morgan silver dollar ch gem bu pl blazing ms satin rare proof reu_ tcombyflid tcoddmtguzzs',
#  'colorado spanish word latin origin meaning reddish colored dummies pronouncing wrong',
#  'screamed languages stcoldjettfmk',
#  'canada drought okanagan region issued level rating okanagan columbia trib fishing suspended sep tcoryzhxklw',
#  'tcofhiqbpwfh itinerary dolphins whales stops',
#  'bend office roofers cut gas prompt tcomfeyzoaw',
#  'several reported close dam estate',
#  'presume timeline inundated soggy bottom lashings moist tweets',
#  'libs evil evil reap lord mercy',
#  'such technique stcouplfsqmrc',
#  'victorinox swiss date womens rubber mop tcoyfynkkcoh tcoknehvvohvk',
#  'typhoon soudelor aim taiwan tcoacwuyr',
#  'tcoodvrqsju gun range mayhem',
#  'haha',
#  'burn',
#  'subject amongst saved millions lives yes',
#  'yr pkk suicide bomber detonated turkey trench tcolwdcrpehtn',
#  'suicide bombing location named tcoiikssjgbdn',
#  'screams mother tcogbepdiwzt',
#  'mine dodge wayne bodied window ex libby mt department oriu_ tcomcejzzxgh',
#  'mexico construction bridge killsaeone tcoicfcowb tcojaagcfartw',
#  'internally externally screaming',
#  'ruin awful tcorceejme',
#  'cunt',
#  'low selfimage quiz tcoidspdkruk tconepazwkna',
#  'thinking demo friend joining derby kenosha',
#  'spot combo inch curved cree led light bar x offroad fog lamp reu_ tcoovsotxk tcoixyiejj',
#  'grace shift tired',
#  'charged manslaughter shooting elijah walker yearold appeared wednesday tcogtcffacvam',
#  'teen fat cock tcoxjwsyrqr',
#  'rcmp reporting serious result collision tch near whitbourne',
#  'makes sense paper beats rock paper comes wood wood able obliterate rock',
#  'disregard snap happening speak',
#  'ignition knock sensorsenso standard ks tconxleiijfgs tcoxsgwmzxpd',
#  'reckon dying brain dmt causing relive simulation',
#  'tcousqqqhqvj brand dserialpcilp lava computer pci dual serial board tcolbsjjb',
#  'fyi cadfyi damagenhs piner rdhorndale dr',
#  'step program sex addiction tcoxsxoos',
#  'message boards display updated message beginning slow workers',
#  'superbug biolabs epidemics biosurveillance outbreaks homeland wire tcocvhygwcbzv',
#  'reddits policy effect subreddits banned tcoohbvyvtl tcoymutindr',
#  'criminals lorries buses arrested enugu tcolrturwnf',
#  'wanted paper towns',
#  'consequences spending budget tcokqtlaodh tcozqbxexy',
#  'shark lava third guess feelings',
#  'christian muslims temple mount waving israeli flag pamela geller tconhxserthx',
#  'corii birthday spoil tcolgizrucy tcohgedwxtdjn',
#  'drown walk',
#  'multiple downtown hinton tcopkdhpsp tcowaetkgsza',
#  'listen song positive energy youth stcoliwkjybe',
#  'check lava lamp dude tcotoviqoofv',
#  'hannah hiroshima sounds china oil spill',
#  'slosher goat freaking wait episode splatdown switching splatling gun',
#  'guy idk crush',
#  'elite either better player',
#  'yep considering millions japanese projected downfall',
#  'looking solicitor tcogzaudyha tcopekgcsig',
#  'lizzie drove thru deep flash floodrainstorm repair cost yrs later thnk cars float',
#  'accepts wisconsin response behalf tcopisaivrbr',
#  'parents thinks better tcowpvbhhoq',
#  'count',
#  'unlicensed teen driver among killed nc tcowocakehyx',
#  'juan carlos salvador secret tips points check secret bio',
#  'seems pretty sure',
#  'clip topdown coercion weakness ensuring tcognorijnsva',
#  'lmao crush sooo',
#  'brain twister drop telly structuring cast edcxo',
#  'driver held mall parking lot lmfao',
#  'suicide superpower patrick j buchana tcoemtwirknyq tcomkoazve',
#  'myself',
#  'cracking cuz',
#  'missing families evacuated due bukidnon tcozhsckvysn',
#  'probably idea plug hairdryer wet',
#  'attend rally organized protesting took tcobvckdpdti',
#  'beard visited prison keeps hideous beard electrocute',
#  'pharma overloaded cry siren fucking',
#  'declares typhoondevastated saipan tconyxjndora',
#  'dances likely walk anonymous',
#  'kindermorgan gas',
#  'catalinas kind picture justice stcontawgezjx',
#  'mh aircraft debris la reunion missing malaysia airlines tcomrvxbzywd',
#  'sea electrocute',
#  'thrusts jams cock deep womb pussy thick cum',
#  'text morn route tcouhlakfvsm',
#  'reported runin roadwayproperty statesville rd',
#  'twins tcogmpbdmt',
#  'panic',
#  'beware temper loose tongue dangerous combined lead hellfire',
#  'though serious increased safety standard inferior standard',
#  'drugs turned',
#  'catch minutes finally monwabisi gets shot hlongwane ryt twins r each',
#  'concern panic games games each',
#  'russia killed buses tcoybypievn',
#  'southbound coal creek pkwy collision blocking center lane',
#  'respected job recovery g g led meltdown exactly',
#  'music tv career brooke hogan thanking dad publicityalthough doubt',
#  'bombing kinder stcogvmubpm',
#  'perceive burns faintly sputtering candle vast desolate glacier eternity sister gyrsi',
#  'dart members participating four intensive technical animal tcotlaoder',
#  'cousins hang text saying honestly wish',
#  'currently',
#  'stretcher brought vampiro cut commercial sign',
#  'roof definitely lesson learn',
#  'trouble mental fog consider tests tcoxaermbmvlv',
#  'wreckage conclusively confirmed mh malaysia investigators families tcovazpgftmu',
#  'ipod direction',
#  'bags stcomcxcgzd',
#  'chinas stock gems tcoeatfrodx',
#  'strong thunderstorm affect central halifax county edt halifax va edt tcomjstefggu',
#  'follownflnews michael floyds devalue fantasy stock tcodujgypima',
#  'dying lyme disease case rate nearly tcorgtghodpw',
#  'mood elevator decided noses everytime pressed button',
#  'freak hell',
#  'sa mp steel ferrochrome industry verge put list questions president oral answer',
#  'declares typhoondevastated saipan signs declaration northern marians tcoicrcrqm',
#  'cake lady hipster unfortunately',
#  'reality training falls elevated tracks tcoqzrcinafz',
#  'article russian crematoria provoke outrage amid crisis memories tcohieifhsmc',
#  'airport swallowed minute tcobrctmnybjy',
#  'waves shore anymore tcotdaktglup',
#  'driver salvages banned tomatoes border tcobwfovfk',
#  'occurs fluid builds pressure level optic nerve',
#  'concur spend harm mmk stcodxwfxpwh',
#  'elem pomo helping rocky consider elem center tcodydfvzamj',
#  'suncorp net profit rises billion claims tcocwzlndvk',
#  'carried brothers sisters entered academia',
#  'slow clap pilot dramatic shows plane landing tcocgvuyrcxo',
#  'guns protection unless',
#  'usw abandoning create level uncertaintyeconomic upheaval unrest',
#  'along dignity',
#  'data overload growing demand context structure inundated information tcosctcqjvjx',
#  'ouvindo armageddon',
#  'started writing talk therapy communicate',
#  'destroyd wht tcodlgnuuuuyn vigils tcojvkyzndtja',
#  'beyonce pick tcothoyhrhkfj fan tcowvjabgm',
#  'falling asleep sounds plate fans stadium thunderstorm',
#  'message sent reply message',
#  'rappers sampling start sampling whale song',
#  'turn radios tcogsswam fm blazing hits',
#  'become month wonder pornhub inundated tcogghfxpzmh',
#  'design decision fresh wonderful kindof odd restrospect',
#  'collision nobody solve long division',
#  'savings sewing guatemala savings sewing guatemala seamstress elvia tcojdxoxkik',
#  'yea thatnot vampiro bleeding',
#  'plymouth uletuas obliterate litterua tcogdrssjbhq',
#  'across mineenjoy tcohcyajsacfj',
#  'samel_samel crush tcotbstkvqu',
#  'helphorses sign petition stand voice stcoedllncvu',
#  'drown',
#  'alright exhausted',
#  'raffi_rc sustainourearth oklahoma acts limit earthquake risk oil gas wells scoopit tcoyrunphdrf loving thiu_',
#  'crews passengers gold coast tram powerlines fell across carriage tcohfyrloqyq',
#  'purple vet finds jihad threat mall uiall islamaphobe vets tcohwnyxxkczz',
#  'railways caught unawares mp spot marked vulnerable ofu_ tcocedcugeuws',
#  'inundated images information online deconstruct kerri sackville',
#  'maryland mansion killed caused damaged plug christmas tree report tcoucudwiuan',
#  'facebook meltdown padres fiasco mets welcome',
#  'refugio oil spill costlier bigger projected tcouecmcvpk',
#  nan,
#  'shooting theater crazier glad shooter casualties',
#  'displacedinjuredkilled hey opportunity different restaurants',
#  'photoset hakogaku aei kurd born battlefield raised battlefield gunfire tcoobpwtm',
#  'hollywood miners chile hollywood miners starring tcotyyfgqqvm',
#  'party invited feelin sou_ stcohkxxbbo',
#  'sick criminals parents friends killed officer',
#  'meltdown victory mets',
#  'photographer brian ruebs endures feet climb capture bride groom tcobmwmpoydig',
#  'evacuated cinema mins',
#  'seen president killed sisters plane claimin sent',
#  'wreckage conclusively confirmed mh malaysia investigators families tcoebpybfhd',
#  nan,
#  'episcopal priests trip interracial shares harrowing harassment tcorgjishybs',
#  'openly accuses nema stealing relief materials meant idps internally wom tcoysbcsszys',
#  'incident industry operations underway reportly',
#  'quite interesting minutes system',
#  'nbanews soudelor typhoon soudelor aim taiwan expected landfall friday according joint typhoonu_',
#  'oppressions greatest soon album stcomollvdyd',
#  'tcofnpdjwvwj homeless dog living cardboard box gets heartwarming',
#  'debate highly watched show among progressives hoping spectacular flaming',
#  'solitude solitude wildfire summary lightningcaused tcoesbsaint',
#  'wbre wyou tcojhvigsxjg',
#  'angelriveralibu_ broken laws katrina caused tcojaawuiovdc snowden hu_',
#  'monitoring jihadis poland tcowcofmlub',
#  'hill hill mountain volcano hell mountain hill hil',
#  'win lisowski whitewashes round shanghai masters quals tcomligpuhvoh tcotcscdyy',
#  'waves missing anymore tides eyesss',
#  'riyadh',
#  'louis vuitton monogram sophie limited edition clutch cross bag ebay tcovjgrliaxh tcojrplov',
#  'ca cops illegal immigrant prior arrests charged sex tcoblfwsys',
#  'tcowatsmxytva',
#  'eye space occurred star o involving fleets totaling ships',
#  'gop debate jon stewart obliterate',
#  'trouble trouble',
#  'uae mideast heatwave ncms issues warning thundering visibility tcotkskezm',
#  'careless match start takes box start campfire',
#  'derailed_benchmark paths wonder leaks jobs given resque',
#  'cyclists pandemonium roads carefully',
#  'planted moved bonsai hiroshima nearly tcojidrogb',
#  'remove tconstfnxpa linkury browser tcowkvscbtlp tcotnonrlp',
#  'reddit updates policy promises quarantine uextremely offensiveua communities tcothnexicgqe',
#  'dad driving',
#  'yr pkk suicide bomber detonated tcoksawlyux bestnaijamade bestnaijamade bestnaijamade beu_',
#  'fucking screaming',
#  'giant cranes holding bridge homes tcogskjqwyid',
#  'weird pitched noise siren ofnsixjks',
#  'investigators virgin galactic spaceship caused cou_',
#  'cherokee three sisters wildfire roads closed general tcouorxffnfx',
#  'tcochjecfrv passengers takes',
#  'nside dragons belly ice cave volcano kamchatka photography acopyrightdaniel korzhonov tcothwgoqd',
#  'hey esh',
#  'catastrophic effects hiroshima nagasaki atomic bombings felt tcowcaqxedf',
#  'llf talk record drought states major tcomlirhwgo',
#  'bug fully patched os x comes active exploit bypass password ars technica tcopoooxn',
#  'clears walk',
#  'rocky grown californias destructive wildfire tcohvhowtip tcoicseshbj',
#  'ludest',
#  'forgot add screaming babies',
#  'george panic',
#  'better sean bro admit sean better sean stcoaomqrykmj',
#  nan,
#  'dad bought dvd science doc front impending biblical',
#  'officer suspect killed exchange gunfire tcoqibdvkab ushed',
#  'unfortunately followers stage pics advanced apologies inundationu_ stcouhsrtrxmm',
#  'legion returned stcohksbmijqz',
#  'rss judge orders recognize spouse samesex certificate tcotziolftei',
#  'california gov jerry reporters press conference california experiencing tcoarzemsrfq',
#  'colnharun unconfirmed bang appears neighbours',
#  'demolish todayhave revenge',
#  'signed safer tcoelugblpb',
#  'wait pissed donnie',
#  'reduce gun tcoiladqebxpn',
#  'wish custom rom catastrophic',
#  'germs anthrax mishaps tcomuheyfdo',
#  'vid gtgtgt stcoirjcrqu gtgtgt gtgtgt comin soon',
#  'tennis defending champ svetlana kuznetsova withdraws citi open cites lower leg espn tcoimhdsklq',
#  'idea ignored fadc expect',
#  'eb ms offloading material slower expected closed',
#  'severe weakening moves se towards lubbock area outflow boundary create mph gusts tcokahbjlqvw',
#  'russia stood cold nuke ban ocean superiority unconditional surrender putin match release',
#  'hungry',
#  'homes razed northern california wildfire abc tcojdhb',
#  'debris confirmed mh relatives discovery tcoxrdwrcdvm tcofxtfflaxy',
#  'screaming hell yes ahhhh tcoyxsnvj',
#  'attraction',
#  'lights stagetwo load shedding stagetwo load shedding force between tcovxvfaeeyq',
#  'soooo pumped',
#  'duckvillelol flips table screw grabs dr tcolnwqdje',
#  'investigate robert mueller respond complaints nov meson tcopedhcsni',
#  'legal system forgets',
#  'screamed lungs guys sa promise',
#  'sitting sounds',
#  'naaa bee legit zombie sore stcojfsdpfa',
#  'hat soviet kgb link tcoblardto tcoeinsqstfq',
#  'added playlist tcovxegcmmvbv panic disco collar audio',
#  'walking spin walking rd',
#  'doguas blown kennel yorkshire',
#  'extra',
#  'malaysia airlines flight disappeared months debris south indian ocean tconrhurysypd',
#  'abe pledged effort seek tcocbxnhhzkd',
#  'hey birds submissions wedding wars fantastic sending guys',
#  'preorder film itunes yay tcofvpwnidl tcobwdhibtiks tcoqelrociby',
#  'virtual tour listings fir cannon beach listed dorrie caruana tconfpaytvw',
#  'canoe fastest feed though',
#  'vine explode stcocnxxmffrae',
#  'largest moblins leaving biggest fired strike threat reduced',
#  'drown',
#  'ignition knock sensorsenso standard ks tcodyersdcrh tcomcpmxmurk',
#  'dutch crane collapses demolishes houses dramatic captures dutch crane hoisting tcodyymlnzj',
#  'saves autistic brother nineyearold maine dove pool autistic brother',
#  'play tcosqfpeczi googlemaps mashup calculates effects',
#  'technology designed prevent dangerous chases effort reduce milwaukee policeu_ tcocedjdlpdan',
#  'put ffvii ones weekend pandemonium forget exclamation mark midweek',
#  'bloomberg publish negative try favor',
#  'beaten blown ra al ghul brought escaped',
#  'niggas favorite question single bitch pussy wet nigga',
#  'updated map mandatory areas advisory yellow evac centers stcogzegjoakkw',
#  'excellent porridge seriously orange porridge phenomenal',
#  'welfare force ke appx members har victim ki ke liye tyar hai',
#  'yygb mhtwfnet evacuated taiwan prepares strongest typhoon abc online',
#  'tonto salt horse stcomatijwkzbh',
#  'success built success built built frustration built',
#  'winnipeg seek witnesses arlington william tconbcfmv',
#  'sea wouldelectrocute',
#  'shadow hybrid mix feat mike szuter tcoefbivle',
#  'pair round led driving light offroad atv utv ebay tcodpxdlec tcojddvhfy',
#  'buddys buddys',
#  'parked',
#  'ships falling objects reminds',
#  'bin laden plane avoiding microlight landing runway tcoxmdhocpda',
#  'chelsea utd pedro mill bargain adam driving oregon usa cmon blues',
#  'pandemonium aba delivers tcojbxbiclu',
#  'mortal kombat x excellent fun iuave mortal kombat segas version tcoflofgya',
#  'easy ray rice fiascothat blew',
#  'ended todays staff meeting teacher version tcomcwdiof',
#  'alright hazardwillian shifted easily',
#  'wall noise wall moving mph tconwajlicr blown tcojninyfz',
#  'break noticed though worry',
#  'myanmar heavy monsoon rains month july caused flash landsli tcotgaoqfp',
#  'text niggas bff boyfriend boys niggas hold attention',
#  'fav worlds podcast',
#  'squeeze mans bare hands',
#  'vibrator shaped vape busted',
#  'looking doingu_ahhhu_that',
#  'wee barra absolutely wrecked',
#  'k_matako_bot unconfirmed bang appears neighbours',
#  'nigga cyhi diss meek suppose',
#  'bbc india rail trains madhya pradesh flash tcowmutcdgb',
#  'york activities york breakfast millennium hotel nations plaza lunch tcolayzbayh',
#  'souls punished withaeannihilation tcocqxjweqqu tcozhpsowxry',
#  'goooooooaaaaaal',
#  'dozens trains india',
#  'gas screams street smells gas',
#  'majesty emperor salman khans unstoppable cyclone entertainment humanity bajrangi bhaijaan creating everywhere crosed cr',
#  'advantages apropos favorable regard mississauga ontario pwhvgwax',
#  'complete solution rid tcocntpnqo browser removal guide tcoqdfasaelm',
#  'blew thru open window bong pieces example natures indifference human suffering',
#  'long madara bleeding',
#  'actions fergusons upheaval tcovxuftvtau',
#  'niece asked scared',
#  'families sue legionnaires families affected outbreak legionnaires disea tcomwcywjzy',
#  'barkevious mingo missed browns practice mystery tcodmkgmpji',
#  'metro acting chief jack requa derailed sixcar series rail cars',
#  'perspectives grateful critical writings contributions study tcofmufnumxf tcoaggryhvxkr',
#  nan,
#  'micom contrast candy color bowknot cross tote shoulder bags womengirls micom zip po tcosqmtkkjimj',
#  'investigators virgin galactic spaceship caused copilot tcopnhpljhoe',
#  'bagging bodys begin cuffed',
#  'small colorado tcohdvmhsqxhm',
#  'analysis mullah omars split talibans ranks omars demise certainly lead tcoajkmcuswho',
#  'watched pres hes dick though',
#  'wasp dive',
#  'thankful especially saving response antioch',
#  'tsutomi yamaguchi atomic blasts tcodaalpenzp',
#  'murderous americauas tcoeyugkbyxr',
#  'wow lot traumatised',
#  'eyes smile pretty smile hair miss luhan exo tcoyobyf',
#  'virgin galactic early unlocking brakes triggered irish examiner tcoocmcvfdzkv',
#  'join event start sun sept castle donington community stcognwyju',
#  'passengers evacuated safely derails tcokzbsohtwb',
#  'eve jon stewart leaving show wmata honored letting derailed crippling',
#  'cleared collision fort erie bound approaching hwy vehicles removed ag',
#  'tcolvgcmyiyj sn vabengal zss vs sws captain falcon',
#  'report dangerous activity bags arrival',
#  'drake spokes rep raptorsbeg differ shots rang musik goodlookrunning panic fun',
#  'thinking friend bailed nite showwent alone alone dance front row',
#  'load shedding permanently camp cook etc',
#  'knocking door wearing footed pajamas bathroom',
#  'halsey troye collab',
#  'pandemonium aba delivers tcowrqfuhh',
#  'allow farrakhan challenge males commit miami tcogvwnhbs',
#  'foodborne illness dears tcojsccxkja',
#  'picking bodies rescuers searching hundreds migrants tcobspjttc',
#  'comes',
#  'indeed comes',
#  'declares typhoondevastated saipan signs declaration northern marians tcousvyhdgog',
#  'raining fighter',
#  'oak tcohkyfova',
#  'illegal alien obamadhs charged rape santa maria ca prior offenses tcomqphfgpo',
#  'stony jackson americas leads felons thus rejects o satan tcowbecdmhqo',
#  'load welfare loving spongea blight society tcorrzbzgon',
#  'pasta',
#  'fears missing migrants med rescuers search carrying tcodsxaie',
#  'slamming door lesson learned lover burn',
#  'sign tcoikuayuseqt tcobqbhuyfme',
#  'giant cranes holding bridge homes tcouziwgzryny',
#  'pandemonium aba delivers tcogccapaak tconqjzswkun',
#  'conversation sorry senator electrocute million etc',
#  'yes yes ruin',
#  'probably boring hour pandemonium test',
#  'lies though pays oldest sometimes curfew',
#  'entire roosevelt wash evacuated wildfire tcocmweiojj',
#  'lord start knowledge foolish wisdom teaching amsal',
#  'fittscott minecraft lucky block mod bob wither mod showcase popularmmos tcomuljaeux viu_',
#  'walking michigan ave sunday stcoyrfzwjr',
#  'gusto persist amongst emptypated communication hpssjd',
#  'brain id explode lmao',
#  'km volcano hawaii utc epicenter tcodisrwhqgym',
#  'ladies shoulder tote faux leather hobo purse cross bag tcouoozxaus tcomgbizjfgd enu_',
#  'gary chicago entrances closed due bridge',
#  'crush',
#  'glad xd safe reference near calgary drum heller o',
#  'timelapse map isao hashimoto stcovthiecc',
#  'typhoon soudelor aim taiwan tcobhsuxvqnf',
#  'documents pointing japans wwii atomic program tcommowcmvnj',
#  'piece wreckage flight mh confirmed ricopyrightunion island t tcozvdgiyowf',
#  'major american newspaper series alleged research',
#  'families sue legionnaires families affected outbreak legionnaires disea tcohzkuyze',
#  'defs stops bleeding',
#  'check preview soon stcoipgmfttdx',
#  'cook smokey bear saving stcowtggqsgeh',
#  'listen tcopulaekxcq beth underwood',
#  'cabrillo hwymagellan av mir',
#  'fixing boutta start hurting mf',
#  'c specially modified stadium submitt tconbugsmqlrg',
#  'electrocute yourself',
#  'abes clear grenades',
#  'thda kicks antiblight loan effort memphis tcoxzlrwcpik tcooxlxmkoyq',
#  'organizationsfluctuations disturbances imbalancesare primary sources creativity margaret wheatley',
#  'sounds perfect bread trader joes wknd inundated',
#  'ooooohshit ooohshit screams hell',
#  'central fruit trees escape heavy tcovbffodtpm',
#  'else stephen sounds andy dick gets excited difference stephen',
#  'yea bombing idea',
#  'obliterate sin',
#  'tonto salt horse tcosbrshccj',
#  'houses kaduna tcononmclp',
#  'raining favorite candle cocoa sip nap awesomesauce',
#  'waves missing anymore tides eyes',
#  'officials quarantine alabama ebola case developing symptoms tcorqkkuhey',
#  'greeces tax revenues debt crisis continues tcouxppoqjlb',
#  'stories google dozens gaza near leveled waru_ tcopodz',
#  'reddit quarantine offensive reddit cofounder ceo steve huffman unveiled specif tcotdeukjzzii',
#  'south sac rd ave ofr trfc collisionno inj tcogpxqbyzyu',
#  'families sue legionnaires families affected outbreak legionnaires disea tcomnsyqrbq',
#  'picking bodies rescuers searching hundreds migrants mediterran tcopuezvbd',
#  'haha comparing yourselves brilliant talk arse',
#  'hollywood miners chile hollywood miners starring tcokkcnppzmk',
#  'emotional emmerdale',
#  'unavoidable consequence socialism everywhere tried tcobbdpnjxsx',
#  'families sue legionnaires families affected outbreak legionnaires disea tconqefmf',
#  'billboards chart socialmediadriven music charts tcowvlahjrxe',
#  'chinauas stock sparked interest bargain hunt tcogopkrfzmf',
#  nan,
#  'enugu demolish illegal structures international conference tcodaqszzubub',
#  'todays commute debacle wderailed nonpassenger shows clearly rail mgr ceo',
#  'names mountain units iraq afghanistan deployments deeds tconzflxigvr',
#  'medicine nurse practitioner healthcare recruitment counselors wasilla ak tcolkzcnynxx',
#  'vs self transformation tcopyehwodwun aliens exterminate humans tcopbnnskz',
#  'factory cars musicvideo tcouuzaumdobc',
#  'isai psm conspiracy lifting scattered unto desolation name o f jesus',
#  'homes razed northern california wildfire tconipddx tcoegyfnlaoqv',
#  'wolforth twoout single fourth altamonte springs',
#  'seek warra',
#  'declares typhoondevastated saipan signs declaration northern marians tcoamoejxqya',
#  'chinas stock gems tcojggmkiney',
#  'freed captives speak uii sure tcopkdgvripw tcorzadzursw',
#  'moth held yesterday chilling bathroom windowsill okay',
#  'link reddits policy effect subreddits banned tcocdngawql',
#  'tv arrested lighting',
#  'awwww walter',
#  'ancient mayan tablet hieroglyphics honors lowly king tcoimmxaen',
#  'response addicts develop defensive self decreases vulnerability',
#  'wreckage conclusively confirmed mh malaysia investigators families tconnyfdl',
#  'currently dressed snowstormdespite office ac',
#  'gang walking round nd',
#  'watched episode se monday tcovrpthvpymt tconkkvknbvoz',
#  'amateur actress reprises role siren horrormoviesca tcowcdoffcj',
#  'program worked pool surprise',
#  'pisgah grows acres wsoc charlotte tcodjufkrrtft',
#  'zotar skeleton alchemist atamathon giant golem golem graveyard tcogpwrckzi',
#  'court system truly broken indeed surprise based tcouuwfgm',
#  'art kamon',
#  'former freedom surfspa razed homes tcoexjzqjni',
#  'magic missing ohio focus fbi probe strange tcomynjwbc',
#  'strongly families cock suckers dc',
#  'whao nigerian refugees repatriated cameroon tcohuhwpmrywz',
#  'seven bells tcoekbludwh',
#  'bhavanas mom crushed soul',
#  'ykelquiban unconfirmed bang appears neighbours',
#  'test trailer paul scheer rob huebels comedy special recorded tcoflsamldsn',
#  'paul craig roberts vladimir putin issues major warning late escape tconvfkzvfex',
#  'firework picture tcolrbtvueom',
#  'crush everyday tcoixjqgsxu',
#  'better learn derivative formula rather thinking haha',
#  'bells toll hiroshima japan marks atomic bombing tcoypvvqzjzt',
#  'yes lot harm guardrails starts',
#  'piece wreckage firstever boeing vanished early march along board',
#  'changed determine options financially ongoing treatment',
#  'surely blazing singing name',
#  'alleged east bay serial arsonist arrested tcoojuhfkhvb',
#  'piece wreckage flight mh confirmed ricopyrightunion island t tcoqnvxjpalj',
#  'leitchfield ky bella edward rosalie rescueadoptionlocal foster homessponsorships tcoajaysnplg',
#  'myanmar affected tcolxjjgyva stcouxperxco',
#  'holmgren describing cup lous',
#  'maybe israel sorry pres sold',
#  'pcs cree led light offroad lamp mining wd beam reau_ tcoqtrh tcooqhjbuenl',
#  'britons amid himalaya tcokepznhxhxd',
#  'wrecked',
#  'panic desolation despair everything sow tcoixwcutkc',
#  'dry thunderstorms pinpoint valley forecast tcoidasyjybro tcogdoaolpq',
#  'airport swallowed minute tcobgmcsrbvd',
#  'upheaval winik jay tcoefswpsxz tconbmaaaofs',
#  'tcokgplkedhr wrapup cable tv companies shares crushed disney disappoints tcoqeihvndnq',
#  'currently driving tcosrujzljgl',
#  'display meeting brave firefighters safe',
#  'wtf idk thruuu',
#  'seriously biggest crush blake lively',
#  'better feeling seeing stage ones friendships bagging mics together',
#  'myself oven degrees',
#  'pams barry island wedding meltdown',
#  'hillarymass',
#  'missing exhibitor emails value tcorceprqxle',
#  'learning legacy catastrophic eruption tcopgxfocghqg',
#  'seeks comment rules changes windstormaeinsurer tcofwtobiu',
#  'tried mido macia accused testified tried mido maciauas tcovxvfaeeyq',
#  'investigators virgin galactic spaceship caused copilot tcoimawvmzsa',
#  'navy sidelines newest subs tcoguvtizyche defensenewscomus navy sidelines newest subsd tcosywhxtk',
#  'dem flatliners creativitybalancelongevity truth stand lucifer stcowcfpznsnu',
#  'expansion ideas bard class holy trinity tcoegioxbaboe',
#  'insane california safe stcojslxtqnqs',
#  'trains india victims families rescuers',
#  'zeal volcano peak grass indecisiveness grow',
#  'officer suspect exchanging shots richmond officer suspect killed exchange gunfire',
#  'alive',
#  'declares typhoondevastated saipan signs declaration tcodobzcpitm',
#  'shad forsythe inevitably',
#  'rene ian buff magnitude tcoavjsjfftc',
#  'miss gary buseys son plays dixie electronic fiddle postbattle celebration sequence',
#  'dad panicking weight loss means needs hurry clothes fundwhen reach goal',
#  'starbs degrees metro derailed washington dc',
#  'bbcnews british insurers cost insurers ampmillions numbers reduced blind fat contr',
#  'cigs breath smells ash tray fucking disgusting',
#  'aiii needs chill answer calmly',
#  'avalanche defense match vs louis blues tcovrvcomh',
#  'mom wished mom spilt mayonnaise',
#  'ah awash abstract dustpig tweets explains deluge',
#  'kach belonged baruch goldstein shot killed palestinianu_ tcobxgnqxvb',
#  'rock springs residents living elk street continue issues mondayuas whileu_ tcojfvuqa',
#  'estimated hiroshimasized atomic dropped hometown tcobsrerjbyi',
#  'bug euro tcokgkzqtk',
#  'american girls',
#  'mate posted tweet pandemonium',
#  'crushed',
#  'dragon ball z gods rotten tomatoes tcojddnhmrmmj',
#  'opposite hereuas tcorbxzzhxkm',
#  'rly mp recount horror uiwhen coaches plunging called tcovscpgmsjxy',
#  'california ampmonsteramp contained tcoaptapyxr',
#  'dems blaze covered months agochicago detained americans interrogation facility tcouwitvbsbnc',
#  'marquei como visto thrones x kissed tcocjhhduli',
#  'lucky rn',
#  'maryland mansion killed caused damaged plug christmas tree report tcolkjfabqzb',
#  'finally panicking cable tv tcolcnweadv',
#  'uninvestigated incite indonesia massacre tcoezbtgtrz',
#  'hate awkward ruin',
#  'derailment near cottage grove garfield tcodcdmnvh tcounhqcqbex',
#  'sprinter automatic frontline vehicle choice lez compliant ebay tcokplfaute',
#  'winter sydney snow degree keeps toes sure',
#  'panic enough drugs alcohol wanted buy alone bills',
#  'wrong lethal series yes',
#  'nine inmates charged causing calgary remand tcoosmiuxkhw',
#  'blown amirite',
#  'tcotbxcakdrw gta online collateral gta v online pc',
#  'tough talk gang infested cities mouth fucking wimp',
#  'chinas stock gems tcogqskwqzuul',
#  'crush tcocfxhqhvbvb',
#  'businesses invoices yours stand oup colour shame likely pay pile',
#  'anxious though meet makes uncomfortable ruin',
#  'tweet quoted tcoejvjolc',
#  'evening sun article nno tcocmfnoync',
#  'grounds political crime planned committed individuals',
#  'sadly humanity ursula drool protoshoggoth sort died loved',
#  'reasons constant drake inundation extremely annoying drake lands',
#  'baltimore north mp fort mchenry tunnel bore collision north mp fort mchenry tunnel bore nort',
#  'wreckage mh najib tcoiidkcjsbx',
#  'apollo uidetonateu ft mop lta hreftcownowfvcbms tcojxwojxqndc',
#  'dk travel guide chicago dorling kindersley publishing staffu_ travel books ebay auctions tcotjltpzfw',
#  'significant eyes humor farts creates earthquake',
#  'point return tcoqegmrhsms conditions',
#  'hour rover zombie tcocfetug',
#  'greatest female beat boxer babies outta ya whatevs',
#  'living blaze apt balcony',
#  'yearold charged manslaughter toddler report yearold charged manslaughter sh',
#  'fucking surprised long',
#  'fukushima increased thyroid cancer tcoftunlhddg',
#  'sneak spoiled humble niggas',
#  'quiet enough phandom screaming tyler tweet',
#  'prophet upon yourself hellfire giving date charity',
#  'terrorists spos tcolxmdiseucn',
#  'review dude bro party massacre iii tcofwqlobooy patrick bromleythe title sa tcothpbdpdj',
#  'louis sad cancel show',
#  'point return tcogokjeb tcokrwzyahm',
#  'hiroshima historys examples tcotmogtifb',
#  nan,
#  'looking guys stream guessing cost front',
#  'honest rampage hands feet casualties',
#  'mercury cyclone hood moulding nice core cobra jet cj tcojobvbvkfnz tcoczpmzhtde',
#  'bang flash light pretty sure hell',
#  'course melt steel cause',
#  'alisonannyoung exclusive research specimens pathogens anthrax mishaps',
#  'renison mine sees event tcoieoggoj small earthquake tasmanias renison tin project created temu_',
#  'motorcyclist bicyclist denver collision broadway localu_ tcoacrgdqhj',
#  'ssp east aeg driven young akrams carhot words exchanged firing airbullet tyre',
#  'bigger obstacles front',
#  'earthquake occurred japan speech swallowed tcotjyyftnv',
#  'countless casualties across globe orchestrated corners planet levels tcogbwldqqk',
#  'typhoon passed',
#  'kills displace million pakistan analysis tcomjoujvt',
#  'hello looking mod cold ice site link download maybe share',
#  'romantic dramatic panic original sensei write rhymes attic',
#  'okay sure word applies horrendous none less stcosbrjqqzix',
#  'screamed lyrics wrong lmao',
#  'nah thinking stretcher foreskin',
#  'ridiculous',
#  'screaming tcoxxzdnmbi',
#  'george njenga hero saved friend razing wildfire tcoywkkarag',
#  'british trekkers amid flash himalayas british tr tconsfzkfgznj',
#  'receive orders california',
#  'area deans bridge rd tcoitzzkwfhg',
#  'skinny jeans tcopaqanences',
#  'israeli helicopters civilians gaza completed exercises greece',
#  'cruise industry supports whales islands everything cont tcoafgzfmzh',
#  'bowl thinking blazing long',
#  'ca opening tcohkyfkugzw',
#  'womens flower printed shoulder handbags cross metal chain satchel bags blue tcorjzwcasx tcowtdiavua',
#  'mega mood swing hr schedule occurs',
#  'yo dm',
#  'tension bayelsa patience jonathan apc pdp tcocomlgvdbv',
#  'announces refunds twos extreme tcoppetlkt tcoolmhhpma',
#  'refugio oil spill costlier bigger projected tcojhpdssvhve',
#  'bestseller fossil dawson mini cross bag esu_ tcohhhvkxfaih',
#  'later ferguson sees asks ituas tcohvmmdebdx',
#  'christian muslims temple mount waving israeli flag pamela geller tcomxzyxld',
#  'silence',
#  'major causes lifethreatening closes highway wheeler suv thenu_ tcoajtxuafoem',
#  'apparently screams emotionally attached cheat',
#  'grubbing kikes cluei telekinesis',
#  'relentless af feels humidity relentless drought dominicana worse places',
#  'space obliteration imminent tcoxjbdcaahf',
#  'standuser killer queen',
#  'california battling scariest wildfire rocky tcosptkfaq',
#  'wellknown fact valentines massacre avoided oompahperiod tom waits',
#  'different moral systems mine rejects innocents yours explicitly endorses such behavior stcoqadrkejzt',
#  'curfew helps',
#  nan,
#  'nah panicking brothers wife debbie hospital stressed',
#  'bitch blew',
#  'massacre',
#  'song siren john frusciante tcocyvxeff',
#  'suicide bomber kills saudi site mosque tcoetyzygba',
#  'womens buckle casual stylish shoulder handbags pockets cross bags tcomwzqcjhzpb',
#  'roger goodells mistake tom brady innocent tcoucnckrnlow',
#  'houses kaduna reportedly killed houses ut tcojixscpmdud',
#  'south airlift maybe interstate completely blocked',
#  'kurtkamka desolation coyotes lizards sun tcozpvjvdpf',
#  'tracy blight thank following',
#  'suicide bombing location named tcoiikssjgbdn',
#  'seriously websites tcoxwtffhg looking seriously simple program tconzzfmi',
#  'beach earrings beach jewelry vacation earrings calm beach earrings flattened tcorjebpibrz',
#  'shipping germs wxiatv tcozqqjrqsbjm',
#  'telltales walking characters ampstory gameplay performance issues',
#  'stockton investigating driveby shooting north stockton tcojxdoyr',
#  nan,
#  'direction pick tcoywvqkgbbi fan tcosffcomp',
#  'salem shut electrical circuit pump tcookcaz tcotgdonttkty',
#  'kessler syndrome name catastrophic exponential proliferation space debris satellites',
#  'queer sultry rosenbergs york',
#  'put alarms accidently different trial exams happening kidding',
#  'sometimes logic gets emotion surface point',
#  'skies tcouvqikx',
#  'jack closed sketchbook biting lip mask',
#  'spot fixingmatch fixing pak sl wi rsa bd sham team',
#  'small bag bottom hero shakes senzu bean falls gohanuas surprised shakes pouch once',
#  'twister tickets chance vip experience shania click tcodkrwwe',
#  'decided break emotional tangled desolation smaug',
#  'wfp wfp delivers bangladesh victims tropical cyclone komen dhaka uothe na tcofukbbedfgx',
#  'atomic leaving major tcoowgexynbh',
#  'ave streets hottest youngins',
#  'reddit quarantine offensive tcowosypvqufi tcoxwsdstjp',
#  'tcoinkuvdntx retro tcocvegtizog',
#  'marley brinx gives striptease spreads legs pussy pounding tcoqewcmxd download',
#  'alot weed kidneys put dutch',
#  'map typhoon soudelors predicted path approaches taiwan expected landfall southern china su_ tcoxcbyeqmw',
#  nan,
#  'childhood',
#  'months curfew smfh',
#  'reddit quarantine offensive tconasipmvh',
#  'backty exactly',
#  'bitches walking bed bugs',
#  'ignition knock sensorsenso standard ks tcowadpplwj tcoyjthnabv',
#  'earthquake drill atm',
#  'bts song jimin screams',
#  'factory december',
#  'nyc legionnaires disease toll rises tconqlajmiv tcoxqfmuge',
#  'salty scared drought',
#  'held',
#  'team client outage contact vet design tcounjpork',
#  'tconcjlkqasuk mortal kombat x pc gameplay fatalitiesxrays mkx',
#  'slashandburn blamed western thomas tcodjchjfzp',
#  'cover lethal',
#  'ignition knock sensorsenso beckarnley tcoodmxwdhm tcogaheujruju',
#  'awesome collection amiibos path',
#  'potus strategy refugees idp internally horror etc stcorqwuoyfm',
#  'stuart broad takes eight joe root runs aussies stuart broad took careerbest figures tcozgsjwxdrcm',
#  'tcobageflfgt killed madhya pradesh twin derailment tcobvxqakfrx',
#  'wreckage conclusively confirmed missing flight mh',
#  'code prohibits grills decks condos apartment check tcokezsnaml',
#  'maailiss diaporama sixpenceee karymsky lake crater lake located karymsky volcanoaeinaerussia au_ tcoofmhn',
#  'burns apartment blows manchester tcobgcwezb',
#  'airport swallowed minute tcobbttdvjwe',
#  'south africa traumatised sick different ways course messed',
#  'dare turn streets citizens',
#  'factors consider hiring company noxdv',
#  'reacts aussie tcoizqlkpuz',
#  'madhya pradesh derailment village youth saved lives',
#  'link reddits policy effect subreddits banned tcooxvtlpmf',
#  'warfighting robots reduce civilian casualties calling ban premature tcolzffptaz',
#  'suspected serial arsonist arrested calif tcopzotpdgaki',
#  'niiiice',
#  'fashion ladies gold waterproof weiqin famous brand michel quartz de lujo cau_ tcojgsioujas tcotzeyhfn',
#  'split',
#  'choose happy rest tcotamrcwfygd review kick push',
#  'lyf needs quality certain sense trust stress emotional upheaval',
#  'aps bets register boylesports casino tcozildpvknxp tcoydbspf',
#  'malaysia confirms plane debris washed reunion island flight mh tcobmxsndxg',
#  'piece putting ambition check voted seek',
#  'hiroshima prepares dropped tcoojhcgzxlst',
#  'yes especially clients walk wart',
#  nan,
#  'once upon fact decided university',
#  'meltdown noticed',
#  'tcogkyegjtk advice',
#  'yr pkk suicide bomber detonated turkey trench tcomgzslzzwf',
#  'wce lie tho stand crush',
#  nan,
#  'performance chip fuelgas saver chevy tahoeblazeravalanches tcoicrzitqc tcoonxhkfhna',
#  'ohgod xd mean xd',
#  'lebanon sad expect long delays',
#  'gostei de um vi_deo de tcobwekjcept sleeping postcards polaroids acoustic cover',
#  'husband posting crush mondays',
#  'iof murdered palestinian gaza massacre zionist moralityzionism evil',
#  'currently uncontrollable meltdown number',
#  'unpredictable disconnected social favorites',
#  'cat utica ny pleasant holland aveblack cat paws average size grass north side',
#  'satans daughter shadow warrior ft aka transgender mode ps nyc fold extra extra center',
#  'squad obliteration',
#  'learning legacy catastrophic eruption yorker tcovmwtouyohm',
#  'question interpretation sign called stcomyquwijn',
#  'kenny holland crush da vida',
#  'tt kettlebell upheaval blueprint chris lopez hindsight jhmnye',
#  'retirement check instruction tcolnmywrmq',
#  'ui dog thinks tcomglpgrrmu',
#  'scrolling didbut seems exact starting point deep',
#  'referring mr modi zeros',
#  'fashionable mountaineering electronic waterresistant couples leisure tabu_ tcoucawgulj tcoenqdfbjump',
#  'murderous americauas tcojmawrlthb',
#  'added playlist tcokbzuatuks dan arin demolish giant gummy bear grumpout',
#  'afloat pension start tcoceeuzwhvf',
#  'bought medium hey endorsement starting expensive',
#  'giant cranes holding bridge homes tcooqpsvrgbjc',
#  'sibling abuse join tree tcolqdwefpqd tcoggnbvzohwu',
#  'ignition knock sensorknock sensor delphi tcolmrkgporcf tcowadnmstov',
#  'noooooooo proceeds',
#  'realized honestly glasses',
#  'finish tcoqqcoaojp',
#  'panic patient alabama tests negative ebola tcocyciuuc',
#  'fizzy sitting regular seats knows',
#  nan,
#  'morgan silver dollar gem bu dmpl cameo rev blazing ms grade tcomkbqwior tcowrjrfks',
#  'electric vs gas brewing wanting electrocute myself question tcooofcl',
#  'spread conflict sparked increase destroying throughout tcoznmdsrvp',
#  'slayer reflects low mayhem festival attendance king diamond jeff hannemans passing tcongcejiy',
#  'nda written ability offer future prolly anyway',
#  'ae ae join tcoljomctuzfy stcozgvsloxp',
#  'mh aircraft debris la reunion missing malaysia airlines tcozxcorqaa',
#  'saddle accountable information tips pro preferable financial brass tawfmcaw',
#  'uribe ball',
#  'thinking gets wrecked',
#  'shootas hungry bodies burner',
#  'start jail mfs shidddd',
#  'homes razed northern california wildfire abc tcozbzcgl',
#  'began prior decision indictment sense pointu_',
#  'sevenfigz crush tcobpnqxmd',
#  'russian crematoria provoke outrage amid crisis memories russian society recal tcojerzbmjqd',
#  'marketforce perth named winner round iinet nbn buffering cat shark radio spot tcoggperglvki',
#  'remove softenza softenza anthelmintic nature book drawing sea',
#  'ui caption needed freshman tcokughvaifumy nigga stacey bagging niggas',
#  'idm burn gotham bcs laugh panicking',
#  'policy responsibility repeat same',
#  'thank missy suited blazing summertime yeehaw',
#  'repped fantastic laura milne liguistic needs tongue twister tweets',
#  'imagine flattened kurt zouma',
#  'dangerous favors tcomiubkzm',
#  'travelling aberystwythshrewsbury incident halt shrews scene',
#  'felt namekians felt played died planet',
#  'radio stations broadcasting address upcoming cyclone tcoiovrymlkp',
#  'nuke target hilversum meters below surface',
#  'ashley harbor friday tcoscefpfvaeu',
#  'california spring oil spill estimate grows documents wednesday disclosed oil sp tcozqihnhdwpv',
#  'sick',
#  'girls notice started lose alot weight hmmm thin tf',
#  'lil x chance',
#  'crushed tcocrpodkwv',
#  'uci architect disasteruc',
#  'jammu soft target',
#  'honestly wonder wrong lose',
#  'shipwreck rescuers trying hundreds migrants tcotxoybrn',
#  'wish victorias secret front',
#  'biggest lead england nail guys stcoxzvmzqusx',
#  'stuns probably aw stuns',
#  'balanced balance mercy',
#  'dl patch fix error symantec computer ergo stopped wireless exchange technology',
#  'problems ruin faith',
#  'pete pass mid month frisco scouts canoe trip okla',
#  'hank williams jr boys music stcoyouwnxvs',
#  'meatloving feminists grill arrived tcoskaausjpo oliviamiles',
#  'added playlist tcovyxurnep survival hug guest roblox',
#  'aftershock stcoxmwodfmtui',
#  'exploring worlds three moments china miicopyrightville tcootrwztsp tcoxvlkfcvfx',
#  'imagine room walls lava lamps',
#  'aftershock stcojvppkhjy',
#  'rt_america rt_com eye super typhoon soudelor seen space timelapse stcofcbxrthpg tcobiukowglz',
#  'testimony promote conflicts tactics corruption infiltration groups stcocyuzxwoh',
#  'vantage backups eastbound low visibility due miles east bridge',
#  'lava dan',
#  'internet basics defective intertissue soul mate milk trench host guabxfv tcouzsqzycbx',
#  'jax issues outlook hwo tcofucoqhclad',
#  'bug fully patched os x comes active exploit macs tcosbgirvqvzb',
#  'angel propelled future winds progress leaves piles wb',
#  'british name though',
#  'slipper putting boot tcobbxeruep',
#  'point return tcocgffpmr conditions ihhen msf refugees',
#  'cute livin zoom ones meme seen gates hell',
#  'looking repair recent rap partnerships tcohxchkd',
#  'heysundowns previous meeting celticindeed improvement',
#  'screamed signed fucking',
#  'mourning notices stabbing victims stir upolitics griefua israel tcokkbxiblah',
#  'dangerous rest stcoyldkftb',
#  'strikers phalaborwa striking chinese jobs strikers attacking cars tcolngclzsj',
#  'hold webinar mitigation et tcoxmsvohkccp',
#  'syd oil spill bankstown stacey wattle tcotzyhdbwf',
#  'complaining phoenix mode emblem turns ray gigant difficulty option',
#  'chinas stock gems tcolohzwjpz',
#  'wonder upheaval team affecting different players',
#  'chance ffa foodstand fairgrounds finishing appreciated',
#  'learned economics south dakota college hubert humphrey',
#  'learn gained access secrets earners explode business tcodhambpya',
#  'died wings airplane tcoxdxdprcpns',
#  'chief assured crowd officerrelated shooting investigated tcokmxzhotfm tcoalbvdnwjtg',
#  'feeling youuave realise g',
#  'pushleft talkecologyamphuman rtsampdemocracy afghetcleft humanitarian bombing',
#  'outbid tcokrnwwxhe pcs mm ab resin flower flatback rhinestone wedding decoration fa',
#  'monster racer catches fair',
#  'dvbbs borgeous arceen festival trap remix stcojoqazrt',
#  'panic disco te amo',
#  'opening regular master packs sou_ sunku_ mil credits light sideu_ pullu_oneu_you sure odds',
#  'chinas stock gems chinauas stock su tcokabktcjnl',
#  'yes apparently report cow sadly',
#  'infected ear piercings fun',
#  'lying clinton donald trump singing stcozvchjclf',
#  'looooooooooool hell stcojrkgylte',
#  'killed simultaneous rail acute trains tcobzwiqptu',
#  'bedrooms baths sale palms ca tcoqmsrressd youtube tcozlajcssq',
#  'womens tote faux leather handbags shoulder cross handle bags rose tcogyzpisbiu tcomsdntkwyaf',
#  'links show better might electrocute',
#  'governor allows parole california tcofzytwqkwv',
#  'ways stretcher',
#  'committed',
#  'gained followers stats grow tcotiyulifc',
#  'miss chris myths obscuring crime yrs month tcodlpkpktk',
#  'brunette beauty stretches victorian sofa tcoqewcmxd download',
#  'desolation tcoaxvqldtehc tu_',
#  'yr pkk suicide bomber detonated turkey trench tcoaawzxykles tcorsmvgdxriv',
#  'win mini uhc blown creeper kicked flying salty rn',
#  'square booty org write xv sure fine',
#  'trouble understanding rotations within leftleaning tree class currently learni tcowgllubnw',
#  'box alarm derailment calumet struck orders',
#  'tries electrocute self cord',
#  'bengal cm mamata banerjee blames dvc bjp claims failed economic t tcobozlwrz',
#  'listen',
#  'inundated',
#  'missing bridge central mexico fox latino tcolunaflyy',
#  'kissed disasters soul rather cracks pour amazing',
#  'drown entering lungs alive caused pussy',
#  'tcoyioivkx sn vabengal zss vs sws captain falcon',
#  'reddits policy effect subreddits banned tcogixgaynxz tcopsrfhx',
#  'deluge such awesome word idea',
#  'desolation smaug spanish hell drug',
#  'seven angels stream tcodlyruusqk',
#  'sir cousin pow brutally treated talked bombing justified stcosudkkweez',
#  'satan teemo skin tcotytpbcgwi',
#  'shantae smash wii tcozztbvjypn',
#  'grill fkn pleb',
#  'fucking mfs fucking',
#  'reading list famous musicians oppose powerwow powerful evidence lot risks',
#  'owner chicagoarea gay bar admits scheme tcoydnpvtg stcoxuldcosh',
#  'grenade effect impossible hoes careers',
#  'bombedout britain tcoracaivffq',
#  'site leads near krefeld germany crews scene avoid area',
#  'method meditation youp ampgot deluge divine blessing happy peaceful tcovmflnxvzc',
#  'refugees camped south redcliffe village aidan',
#  'leicester_merc icymi australia trent bridge reau_ tcohqewmreyso tcoyyfcljed',
#  'apollo ft mop stconljvpvfyz',
#  'vehicles lock lansdowne sts emerg crews',
#  'absolute athens bound',
#  'forecast longest streak tripledigit happens tcoxxoupfynq tcoabjabhqhe',
#  'slow report mediterranean sea shame',
#  'demi moores swimming pool tcooctnpyueei',
#  'picking bodies rescuers searching hundreds migrants mediterran tcogeuhcsz',
#  'county overload prompts july celebrations tcohxtuprabc tcodqxkjibbky',
#  'richmond',
#  'dakota skye gets horny porn gets juicy pussy pounded tcoqewcmxd download',
#  'nankana sahib correspondent nankana sahib youth electr tcowerkqibvv',
#  'satellite spies super typhoon soudelor space tcovbhutwgb',
#  'caution breathing',
#  'worried curfew',
#  'chewing rubber',
#  'hollywood miners chile tcoxeeefzfh',
#  'sunset looked erupting volcano initial pixar short lava tcogschqfest',
#  'waves darkness',
#  'sydney oil spill bankstown stacey wattle',
#  'specs fan lore',
#  'severe statement issued cdt nws severe thunderstorm warn tcoeofwxnpj',
#  'currency transgress paydayprison ward sinkingfund payment unsecured loan jbumzqpk',
#  'september defeater epicentre hell yeaahh',
#  'charged near dubbo refused bail tcohdbmfovutz',
#  'sunflower walk tcovlnmklwwby tcopeofj',
#  'check parking lot johns tcohpvodudip',
#  'forever avoided join gtgtgt tcofyjwjdkmi',
#  'navy sidelines newest subs tcookamsczbwg',
#  'lot celebrities treat harm',
#  'finally spring sat vacant justu_ saddlebrooke tcovcjcykqb',
#  'loved episode bang season caroline bigsby took supermarket',
#  'funtenna computers data waves hat tcomisrjxuir',
#  'meaningless might play cod search',
#  'nearly long enough',
#  'interview actor randy irwin ask harm tcokqchwkp',
#  'twister fun stcoqctfbwon',
#  'fraction vital break tcozsqmihek',
#  'panicking submitting form usually',
#  'remembering marlene menahem moshav safsufa murdered hamas terrorists suicide bombing egged',
#  'martyrs kept udhampur terrorists bay averted massacre youngu_ tconuxxfpvd spsa',
#  'puckflattened ball',
#  'waves shall ripple collide tide',
#  'hello wud kindly consider following bak trouble',
#  'pressure abandon construct ukuas tcoedlkfdw',
#  'trust dopey ones',
#  'brooo',
#  'dialyses grandpa lord makes light headed',
#  'obliteration ancient canaanites tconckogwjq',
#  'california rage sounds alarm rising wildfire costs tcotqwrwjqwo',
#  'enter extreme diving stories volga tcodmtzmgyrik',
#  'obviously aware countries lot fleeing conflict',
#  'mile marker south mooresville iredell vehicle ramp closed',
#  'ferry crack open knocking',
#  'evacuating area confirmation',
#  'c specially modified stadium tcoflqxdqpy',
#  'mens cross canvas waist packs solid letter print sports zipper bags coffee tcoscxfcwit tcogxotohsj',
#  'siren forney warning',
#  'afghan talks doubt mullah omars financial',
#  'sign pull five ambulances bay wompppp friday',
#  'tcojwivwywf osage beach releases name',
#  'justifying quarrel obliteration remains pakistan stcozijktkyk',
#  'yes bleeding liberal',
#  'three israeli soldiers west bank rworldnews tcosuzvwadj',
#  'clearedincident injuryi inner loop exit md georgia ave silver spring',
#  'bowl cereal kelloggs sugar stays crunchy milk',
#  'laugh bang theory',
#  'crushed gym crushed butterfinger flurry clearly priorities straight',
#  'diretube information egypt cyprus greece agreed fightaeterrorism tcovijxccdi tcoysxhfwmgod',
#  'val suing',
#  'better means awaits heroes',
#  'evansville residents limit usage due construction evansville residents haveu_ tcosjnyfszcu',
#  'downtown center hiring counselor intern apply tcoskqpwsnoin',
#  nan,
#  'four hundred wrecked cars costing apiece purchased film tcodtdidinqyf',
#  'guy hat',
#  'playing darude radio edit tcodudairbbpo tcopadosfyxnm',
#  'havnt',
#  'rly mp recount horror uiwhen coaches plunging wa tcoeyorbmfo',
#  'yelp bolsters reviews investigative journalism sick patients local er t tcoeaegofdy',
#  'means progress flint michigan fate american metropolis highsmith stcozvobmdxhgp',
#  'er indoors rip arfur',
#  'trafford film fans odeon cinema evacuated following false alarm users tcodzlensegw',
#  'yearold charged manslaughter toddler report yearold charged manslaughter sh',
#  'different fnaf fanfiction trixie_drowned pageshi awesome proxies tconhtgtz',
#  'results metal mayhem title match bully ray career comes tcogmonvnpsu',
#  'remorse',
#  nan,
#  'teaching obedience obliterate trials trying sell jesuss blows theory',
#  'wugliness due ugly frats bioterrorismim id tolewantg',
#  'rly mp recount horror uiwhen coaches plunging called tcoxhonup',
#  'patrick kane cab driver',
#  'rob embarrassing ruining nation',
#  'jacksonville bands together memorial planned tcotilgurkvz',
#  'relief carrying derailed janta express reaches mumbai tcocznxhutasx',
#  'odai bucharest romania dogs dyingthey hungry eat each tcopjigxpvpl',
#  'palestinian teen killed amid protests tcookvsimogic',
#  'leaking sewage opens housing estate irish independent aug',
#  'urgent salt supposed protect tcowhpjjc',
#  'studio nowhere becoming epicentre communication tcoicrgseagya tcokpvymhmub',
#  'exporting solve africans poverty solving tribal wars stcouttanbigrx',
#  'reverse situation civilian specifically utilized political',
#  'zombies tcohuthxlkyxy',
#  'supposed normal sports manga wit triangle c',
#  'seeing fbi cia grade equipment evil',
#  'firefighters connecticut headed california tcoqwpuxpywbf tcojlxzfkxy',
#  ...]

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# ## Naive Bayes Classifier

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ## KNN

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ## Gradient Boosting

# %% [markdown]
# ## XGBoost
