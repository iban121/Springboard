# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import spacy

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, matthews_corrcoef
from sklearn.naive_bayes import MultinomialNB

# %%
data = pd.read_csv('tweets.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                                               text  target  \
# 0           0                     deeds earthquake allah forgive       1
# 1           1                             near ronge sask canada       1
# 2           2  residents asked shelter notified officers shel...       1
# 3           3                receive wildfires orders california       1
# 4           4                   sent ruby alaska wildfires pours       1
#
#    num_hashtags                   hashtags  num_mentions mentions  emojis  \
# 0             1            ['#earthquake']             0       []       0
# 1             0                         []             0       []       0
# 2             0                         []             0       []       0
# 3             1             ['#wildfires']             0       []       0
# 4             2  ['#Alaska', '#wildfires']             0       []       0
#
#    num_chars  num_words  mean_word_length  num_proper_nouns  num_nouns  \
# 0         68         13          4.307692                 0          2
# 1         37          7          4.428571                 0          3
# 2        130         22          4.954545                 0          5
# 3         56          7          7.142857                 0          2
# 4         85         16          4.375000                 0          3
#
#                                               tokens  \
# 0        ['deeds', 'earthquake', 'allah', 'forgive']
# 1                ['near', 'ronge', 'sask', 'canada']
# 2  ['residents', 'asked', 'shelter', 'notified', ...
# 3   ['receive', 'wildfires', 'orders', 'california']
# 4   ['sent', 'ruby', 'alaska', 'wildfires', 'pours']
#
#                                               lemmas
# 0         ['deed', 'earthquake', 'allah', 'forgive']
# 1                ['near', 'ronge', 'sask', 'canada']
# 2  ['resident', 'asked', 'shelter', 'notified', '...
# 3     ['receive', 'wildfire', 'order', 'california']
# 4    ['sent', 'ruby', 'alaska', 'wildfire', 'pours']

# %%
X= data.lemmas
y = data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 10)

# %% [markdown]
# ## N_grams

# %% [markdown]
# ## Bag of Words

# %%
vectorizer = CountVectorizer()
embedding = vectorizer.fit_transform(data)
X = data['text'].tolist()
y = data['target'].tolist()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 10)
X_train
# Out:
# ['msmigot convincing compelling evidence deniers tend giving evidence',
#  'igxrqpotm bin laden plane avoiding microlight landi kpbuhgt peritoengrafoscopia',
#  'atomic bombs japan struggles anniversary wrought bsxaqhsim',
#  'pyrbliss',
#  'wrecked stomach',
#  'drrichardbesser yes college difficult esp dispersed',
#  'itsdanie noooo once tho',
#  'jocelyn birthday',
#  'reading reading pleasure huzzah miss molly tanz vermilion bmprwhw',
#  'reizei ask sama jailed fate rindou',
#  'ylytylh',
#  'expansion ideas bard class holy trinity egioxbaboe',
#  'pkk suicide bomber detonated turkey trench polmnyz',
#  'abcnews peterdutton labor mention',
#  'ika tuning soup diet recipes fat soup recipes rvpaooz fat soup diet recip jvcxbdrj',
#  'actions ferguson upheaval gzekqwzijq',
#  'implores motorists speed reports animal near nature reserves hikfmkjsn',
#  'oct zckxtfcpt',
#  'unpredictable disconnected social favorites',
#  'etp bengal mamata banerjee blames dvc bjp claims failed relief funds hszjafxrvi',
#  'outbid lbpxbucnv catlow twister swivels fuel favorite shar',
#  'juliechen ruin vanessa player',
#  'bbcnews british insurers cost insurers millions numbers reduced blind fat contr',
#  'dazzle fun',
#  'drown mustard lemon pepper',
#  'teamhennessy obliteration tprimo round happy birthday djeddygnj colombian festivalu mrvfidfn',
#  'christian muslims temple mount waving israeli flag pamela geller fmiuhqaby',
#  'petition david cameron protect bees toxic companies harm savebees dbftyid',
#  'mikeparractor confirmed saying goodbye ross gobsmacked emmerdale',
#  'marshall states dambisa moyo prosyn oped lgzjkgg',
#  'aubilenon markkriegsman try',
#  'res doppler showing edmond severe mph okwx lrxsdsnhm',
#  'goku gave birb hell goku',
#  'utc volcano hawaii zdtoydebj',
#  'roinsmejj tjzjin yduixefipe lxtjckls nsfw',
#  'uilittle boyu affected hiroshima testimonials muanfwcrw',
#  'chill boys',
#  'asianshawtyy sorry',
#  'marquei como visto dragon ball super destruction\\ dream vjlnskbg bancodeseries',
#  'returning normal southline medical yennora urgent track equipment repairs cabramatta earlier',
#  'guess ill able mayhem',
#  'tianta unconfirmed bang appears neighbour',
#  'recent events screams five',
#  'looking soul',
#  'zachlowe nba reasons constant drake inundation extremely annoying drake lands',
#  'refugio spill costlier bigger projected jhpdssvhve',
#  'ron fez dave crush anwcf',
#  'bleeding silence safer violence',
#  'itsmegss barking',
#  'reasons brain twister oneself discount redesigning yours website itrawcwb',
#  'rocks aluminum plant southeast missouri naomi logo wdseihyqu',
#  'bloor ossington mattress northumberland cbcto wpdvtsne',
#  'quarantine offensive ewwzcfo',
#  'officer suspect exchanging shots richmond officer suspect killed wreaoka',
#  'dragon ball gods rotten tomatoes jddnhmrmmj rottentomatoes',
#  'downtown hiring dependency counselor intern seattle apply jobs skqpwsnoin',
#  'calgary zagbmlsfh hvyxehxbmq',
#  'ignition knock sensor acdelco original equipment hpzhecjvf saohvjktqc',
#  'fuerkgwui twelve feared killed pakistani helicopter mvggglmvc',
#  'crazyindapeg vets completely understandable considering ptsdchat',
#  'month coastguard floated mile sea socialnews kjuzjcigd',
#  'aemgn africaa pin correction tent correction tent fdjuyvzmrv wizkidayo',
#  'break carlilescanoelivery lovemyjob zorsqura',
#  'drake instagram makes tune everything sumn',
#  'research kiddo specialist sang volcano number',
#  'church silent papicongress journo pragnik',
#  'stand alone piss moan choices reap demeanor calm staid',
#  'listen wonder soundcloud sjkgjxffr',
#  'allen enbot mess explode',
#  'stock gems chinauas stock sparked oqsgzqlbz',
#  'thatuas biggest gbbo seen show',
#  'cleared incident inner loop exit georgia ave silver spring',
#  'ladies shoulder tote handbag faux leather hobo purse bag womens zujwuiomb cjqqcgohg',
#  'sitting cityofmemphis sitting',
#  'cops illegal immigrant prior arrests charged sex blfwsys',
#  'gone blizzard',
#  'severe weakening moves towards lubbock outflow boundary create mph gusts kahbjlqvw',
#  'sometimes logic gets emotion surface point',
#  'feat grandeur apollo gfdhfmpcel',
#  'shot name pierc xpfmruf ejdhvlkxaf',
#  'policy japan responsibility repeat same annonymous guardian nytimes reuters',
#  'pmharper worry sure tornados alberta ontario sure',
#  'libertarianluke honest rampage hands feet casualties',
#  'remainontop fettilootch slanglucci oppressions greatest soon album mollvdyd',
#  'tribal turned madinah prophetmuhammad',
#  'creepiest youth camp tuqmimir',
#  'bsf jawans died fidayeen aks insas insas rifles blame soldiers mod lkeqwyuw',
#  'eat',
#  'chrissie kills adam val finn emmerdale',
#  'architect kanye westuas volcano musbikejf',
#  'map shows california map created cal fireu xjaqtowm mrosiwcs',
#  'four ruin personal claim zuyydfdi',
#  'kinggerudo largest moblin leaving biggest fired strike threat reduced',
#  'navy charges officer violations chattanooga hddbmuyca',
#  'suicide bomber kills saudi site mosque suicide bomber killed fyroxsl',
#  'petition medals massacre justice knee killings native americans uilpgiev mpxtokww',
#  'tennoatax glass sit tenno lived dojo',
#  nan,
#  'kitana slay uokody vine kombatfans umajwsnluf',
#  'deadlydemi staying barrier tiup passing',
#  'wreckage confirmed missing malaysia airlines flight yopeypjkb vice',
#  'qrypekfoe seems declared',
#  'teafrystlik causing entire darken ungodly powerful bolt struck',
#  'bloopandablast supposed throw myself bridge parade',
#  'ashes australiauas trent bridge among england bundled dwwpdet',
#  'newswatch vehicles lock lansdowne sts ptbo emerg crews',
#  'tonto salt horse mmvdspjp',
#  'drunk meals cook obliterated jlputvas',
#  'shipwreck rescuers trying hundreds migrants txoybrn thenewshype',
#  'envyseven aquarius queenmy siren cliffs pretenses overtures sing phantom songfor alone shall',
#  'count financial brazil rio mtrqjfd',
#  'cranboonitz threats hereticofethics',
#  'srajapakse thank missy suited blazing summertime yee haw',
#  'pawsox owners return trip durham knoxville sentinel ckgggyvou uvdbrxfia',
#  'slides especially',
#  'marynmck beyond adorable wrecked noticed',
#  'anti rear gadget technology jtxjiygrl',
#  'duck explode greasy',
#  'parked modestmouseremix truestory',
#  'strong minded keeper keeps runnin',
#  'bride groom mountain edge kidding ioryakon',
#  'drake kept hip hop beef fucking bagging meek',
#  'eeenice caught',
#  'feeling youuave realise',
#  'trust dopey ones emmerdale summerfate',
#  'cruise awesome fail hdchfyaw',
#  'sinjar massacre yazidis lack action jhoahpbpq portland phoenix newyork miami atlanta casper iraq',
#  'mayhem playthursdays everybody text cqjjyjfz',
#  'able online courses stateu jmdzwksdm',
#  'malaysia seem certain france plane debris missing exznmxbinj',
#  'kissed disasters soul rather cracks pour amazing',
#  'dolce prob',
#  'sadly windows reveals microsoft ethics armageddon stftjcrjea',
#  'annihilating quarterstaff',
#  'icymi annoucement jackson bevujeep',
#  'russia destroys hungry ones insane zonnqgsxyw',
#  'ruin',
#  'wsvrb cover hull runabout including euro style prnhrhbt oahlthrozy',
#  'hearing trucks',
#  'mentalhealthgov ahhhhh fix alec med tort comp laws leading injustice qejedwsfdg',
#  'fifty online dates single michael amazon kohooje kindle datingtips goodreads',
#  'smokers ruin smell',
#  'suicide bomber kills saudiaemosque hbhbxt',
#  'deputies dog dispute leads shooting county oazghozgya gunfail nra',
#  'halljh sick criminals parents friends killed officer',
#  'guardian hiroshima legacy shadow editorial longs cas ctjutvytg',
#  'okay write poem',
#  'ice cream cupcake wars sara',
#  'megadeth symphony xzfxrglalp',
#  'mercury hood moulding nice core cobra jet jobvbvkfnz czpmzhtde',
#  'warne shocked epic trent bridge johannesburg aug ani legendary australian lwwojxttiv',
#  'horrific wife muslim italy nylorzqb liveleak',
#  'movies took india vine jusreign hxmced',
#  'lonepine remembered descendants grow canberra gallipoli tfvvnrpc zznbvfuvo',
#  'certificates safes teslas def con kmdqmnlns',
#  'entered win entire butterlondon lip crayons rams enter bbloggers dsbldfuxu',
#  'cochisecollege died human experiments unit japanese vvplfqvp ldxukngsk',
#  'screamed toddyrockstar jdtpirnm',
#  'itsjustinstuart odvrqsju gun range mayhem',
#  'retweeted sarah silverman sarahksilverman soundtrack walk starts tracey ullman perfect',
#  'baan thai sushi washington udpfrxrl',
#  'meyerbjoern thelonevirologi mackayim major american newspaper series alleged research',
#  'michaelsos fucking surprised long',
#  'bed ugh exhausted',
#  'derailment patna indian express yhvetmyz wgugzm',
#  'wait sony sets date stephen kinguas dark towerua stephenking thedarktower jlpdrxcde bdisgusting',
#  'mhtwfnet pakistan helicopter restive northwest fox',
#  'germs anthrax mishaps xtezgjfsa',
#  'lubrication metrofmtalk',
#  'remove xxjbjxrt linkury browser gtylgxroe ygrjbki',
#  'wccorosen lloyds insure bet corycove twins',
#  'antioch owpdvcfs',
#  'celtic fingers crossed aberdeen armageddon',
#  'friend talking tells drop mix tape straightfire',
#  'amznfavorites devereaux exciting scifi thriller mwambgafq scifi kindle',
#  'stock gems oxqblwq ufoqjzw tgfqczey',
#  'gfqjgoyci',
#  'fucked paul cake tastes rubber',
#  'quarantine offensiveaecontent gllawbfsk kaafuoztc',
#  'countless casualties across globe orchestrated corners planet levels gbwldqqk',
#  'ink entertainment addresses veld refund status vkurtozj trc torontorc',
#  'jlabuz',
#  'natalie stavola star explains role indiefilm comingsoon dwpmfb',
#  'davidvitter david walk lives millions prevent repeat irandeal',
#  'suicide bomber detonated explosives packed vest mosque saudi special forces headquarters killing',
#  'identitytheft taxreturn steps cleaning identitytheft cri gxqwdqzbd',
#  'ladies recover date according cggszugw pimgbice',
#  'cute dinner date til cams nose starts bleeding',
#  'anchorage jobs medicine nurse practitioner healthcare recruitment counselors wasilla lkzcnynxx',
#  'uploading videos soon guys types action',
#  'brooklyn',
#  'affects level expecting buy everything limited pocket',
#  'sometimes space celestial bodies separate trajectories intertwine themselves dance rather course',
#  'abomb destroyd hiroshimauo bbc wht dlgnuuuuyn cnv vigils jvkyzndtja',
#  'pwwpumrbj twelve feared killed pakistani helicopter yspondqo',
#  'ignition knock sensor connector connecto dorman rfjzexqgxt wqgsmioimx',
#  'homes razed northern california wildfire fcjvml fvyrwhuxp',
#  'crushed gym crushed butterfinger flurry clearly priorities straight',
#  'malaysian officials debris reunion island billneelynbc reports rkzsqdghz',
#  'coursing weyrey gidi causing maria',
#  'joboozoso usat usatoday nfl michael floyd devalue fantasy stock dgkmueoaxz',
#  'alexjacobsonpfs andre gore elite side ball',
#  'michigan sheer recovery updates leelanau grand traverse extended oskfyjck besafe',
#  'weathernetwork comes',
#  'omfg tiny island freaking burn',
#  'civilian population deserves forget learn mistakes hiroshima',
#  'vinustrip guillermo meteoearth mfckpvzfv',
#  'fact atomic bombs called fat lot mentality',
#  'lisavanderpump dogs dogs',
#  'belligerent enjoying unfold',
#  'criminals lorries buses arrested enugu according nigerian force ffkcjpfj music',
#  'american casualties including five ten million japanese txzxcnudr',
#  'remorse',
#  'blizzard lucio overwatch hype rolling caution breaks',
#  'urufusanragu',
#  'nieces especially megan swanger ruthann mccormick daisy henley dljatw',
#  'patience jonathan apc bayelsaaestate vhqtbypzt',
#  'ohhmyjoshh stevenrulles thinking gets wrecked',
#  'heavy gusty winds vivid moving east triad jmuuyamdu',
#  'investigating bike portugal bike rider suffered serious non threatening',
#  'george njenga hero saved friend razing wildfire ywkkarag',
#  'russian ushanka winter fur hat soviet badge link yfqxvak kxrehvthl',
#  'salem shut electrical circuit pump salem bee hkgxzjlmx',
#  'dona dona illusions',
#  'houses kaduna reportedly killed houses jixscpmdud',
#  'sounds',
#  'katiekatcubs series armageddon',
#  'beat armageddon hsu hao flawless try',
#  'wwii memories plus lessons hiroshima xbmmiteq denver billings rapidcity seattle cheyenne',
#  'jknpdpwro cole squad hills',
#  'stuck sleeper railing due definitely pit trip',
#  'plane york kuwait diverts declaring aiexcbkfq',
#  'businesses invoices yours stand colour shape likely pay pileq',
#  'policy effect subreddits banned mtczaawpt',
#  'ems emts petition per minimum wageua oaswlxmr ems paramedics',
#  'former executives prosecuted fukushima umjprrwruu',
#  'stretcher bearers soldiers whose job follow advance bring yerctj',
#  'nike golf fit golf jacket medium jvaivkmsy sportinggoods nrjjmpmos',
#  'kotowsa south sudanuas rape become normal mexwohdtg gbfidwe',
#  'forlapdances died human experiments unit japanese vvplfqvp yompxjpptv',
#  'try somebody somebody else',
#  'myanmar rohingya sittwe point return cgffpmr prison conditions genocide ihhen msf',
#  'wildfire destroys homes crews advance wqow hjsfddfi',
#  'west valley con trfc unkn inj jsehpwq',
#  'allegations',
#  'untameddirewolf alright sansa shook blinked rapidly information',
#  'khalidkkazi mate posted tweet',
#  'quick fact operation vmtrue',
#  'cuban leader extends sympathy vietnam xlqgvbr',
#  'runjewels recently met bbc discuss race relations benefits loveislove cevwovhs',
#  'exploration takes shift gabon somalia ltfjlkeu zlqthctkw',
#  'forgiven angelina jolie sef',
#  'asymbina tithenai hampered liking bags ella vickers bags machine washable ysfyeahpvg',
#  'cum begforcum allday cumshots cumcovered sexycumshots cumtown nutt cumslut girlslovecum cxyjjoz',
#  'crush everyday cristianinspire ixjqgsxu',
#  'pisgah grows acres daoazeucr',
#  'sxgzxh tremor joke tremor dlc ray',
#  'crushed ewnunphdo',
#  'lovely',
#  'islamic egypt threatens croat nzifztcugl',
#  'screams',
#  'sexual revolution blight tsvaisw stories acebabes healthweekly amateurnester',
#  'forget gajtugaui',
#  'blew thru open window bong pieces example nature indifference human suffering',
#  'ruin holidays wordk zmne',
#  'jamienye blame coaching management penalties defence cursed probably put riders',
#  'naturaldisasters california rage sounds alarm rising wildfire costs tqwrwjqwo',
#  'blazing elwoods blazingelwoods bother doug song tune qyzpbgkmr',
#  'bytorrecilla torrecilla secret secret points bio',
#  'adanne kindly follow',
#  'tomcatarts legion itself imperfect hybrid project quickly formed secret cell',
#  'mzmandilynn enemy destiny blocked lord heavenly blessings',
#  'pov footage captures landing plane kxewlhhuw',
#  'vickie desert unqualified victory treaty signed clinton situation worse tcot',
#  'inundated westeros between swords book tape finishing thrones starks greyjoys',
#  'ruin relationship ask intentions',
#  'eye space occurred star involving fleets totaling ships',
#  'anniversary dropped hiroshima killed outright flattened',
#  'curfew graduated',
#  'happens sexual defines agree perpetrators hurt',
#  'beyonce pick nnmqlzo fan beyhive ofcyyr',
#  'germs anthrax mishaps zdbtktww',
#  'riyadh',
#  'cap act represents senate republicans address shortfalls plaguing highway trust fund',
#  'drothvader nevalistis arachys pieces deals',
#  'raniakhalek faced everything bin laden uncle hopefully afghanistan ugly',
#  'spill cleanup videos prepare situation umqbyrupbd',
#  'briefing west california spring spill estimate grows documents wednesday disclos wbilaqe',
#  'colorado motorcyclist bicyclist denver broadway tak iafpmqjep',
#  'despite increase passenger journeys suilzss healthandsafety',
#  'bottling everything eventually explodes casualties higher higher',
#  'aftershock terrifying roller coaster disclaimer',
#  'ariana grande shirt fucking',
#  'sods arriving amman yesterday diverted ben gurion airport jkpjpchi',
#  'might buy esoteric astrologian',
#  nan,
#  'kills three near venice heavyaerain qxqrr',
#  'feeling jvycxxvi',
#  'baaaack petersen bowhunting bows sure cast vote fjgdvgn',
#  'invading iraq mistake diplomacy needs replace constant threat israel yqjpnquux',
#  'chance animal posts ebdauyfn animalrescue',
#  'benkin mili blew probs kings won cup',
#  'wreckage conclusively confirmed malaysia investigators families vogrfn',
#  'bradleybrad extremely',
#  'missambear tweet quoted wired ejvjolc',
#  nan,
#  'roger goodell mistake tom brady innocent ucnckrnlow',
#  'fate alone notice seems definition',
#  'freyas blew everywhere',
#  'mourning notices stabbing victims stir politics griefua israel eugzhciun',
#  'cuz risk shower nwqwjqkz',
#  'kelly dreams',
#  'fyi limestone col yellowstone fieldstone',
#  'vid thereal irjcrqu trubgme armageddon comin soon',
#  'veldfest announces refunds extreme ppetlkt olmhhpma',
#  'ancient mayan tablet hieroglyphics honors lowly king immxaen',
#  'flgovscott allow farrakhan challenge males commit miami gvwnhbs',
#  'tribal turned madinah prophetmuhammad',
#  'fhiqbpwfh fredolsencruise faroeislands itinerary dolphins whales stops',
#  'enugu demolish illegal structures international conference xcgzcgys',
#  'ahhtheenikki responded gunman quickly able shot',
#  'wondering drone ended freak dhggxomcc',
#  'stretcher brought vampiro cut commercial ultimalucha luchaunderground',
#  'circus tent bunch clowns hkcadsna',
#  'california global warming extreme combined dry foliage ignited douchebag hiker',
#  'scrolling seems exact starting point deep',
#  'malaysia confirms plane wreckage flight ubwozut',
#  'relaxinpr miprv latimes suspect linked caught northern california ylhayfaoou',
#  'bakeofffriends gbbo guy hat',
#  'ashes unfolded trent bridge telegraph fynermusg',
#  'choking prompts recall kraft cheese singles njlqrqcnl',
#  'tricycle toddler atomic ljeryhitwh fraction decisions landscape humanity',
#  'kanger coils vaping cykrxaluh',
#  nan,
#  'messed feeling damaged broken',
#  'president barack meltdown opposition ctrvotkj examinercom',
#  'learn gained access secrets earners explode rabhqrth',
#  'tflbusalerts tflbusalerts ilford closed ways buses stuck',
#  'hundreds feared migrant capsizes libya sgfnebgt',
#  'creationmin rwrabbit gooneratheist atheistic lolatjesus fish worldwide wonder',
#  'mixxtail kind tastes watermelon four loko brittsand',
#  'particulate break solid combust fossil fuel voltaic active biological voc petroleum bacteria decomposition',
#  'madhya pradesh derailment village youth saved lives villagers saved passengers lives',
#  'actively embraced audiences report emhub impact ugc mbpvwitxf',
#  'dualcom razed enjoyed yesterdays todays easter',
#  'tries harm cupcake fucking hunt earth harrybecareful',
#  'delaying deluge fundamentals economy valuations stock fwikyurc',
#  'causes watertown zaszwxjj',
#  'afternoon gawx',
#  'illnesses numbers uoatrbbj',
#  'joedawg tor tor situation enhanced wording key',
#  'juanny beisbol ball lgm',
#  'ollymursaus sorry piece meat nice guy rush screams',
#  'washington wildfire misses evacuations khq anlhwizkz',
#  'apollo yceeemd',
#  'yahooschwab easy ray rice fiasco blew',
#  'dmac colorado spanish word latin origin meaning reddish colored dummies pronouncing wrong',
#  'hamecxk bbc cnn quran lies biwrdxcm',
#  'prepared obliterate rapidly completely productive enterprise japanese above ground',
#  'furiosoxv stuns probably stuns',
#  'dublin north flynn onr trfc inj inlysvl',
#  'mix ultimate preparedness library ojyabyz prepare yourself cjctbocxg',
#  'jack',
#  'gunmen open near salvador capital killing gang attacks killed drivers pzzjssft bitu',
#  'tribe keeps everyday seems faster titanic',
#  'russian authorities account petition sanctioned vladimir putin press qbmcsjavt',
#  'hannahkauthor american lives chronicle freeamirnow freeallfour held irandeal gwnlhneku',
#  'lemairelee danharmon near meltdown comics wait sunday nights representative sample',
#  'daniel sacrifice shall abomination maketh desolate',
#  'sure megaquake brought sense panic question frdnnd',
#  'wtf idk thruuu',
#  'woundedpigeon ssoaevcvo apollobrown',
#  'heavydirtysoul',
#  'microsofts anti virus trying causing meltdown',
#  'titortau loretta lynch fuckin larious realtime fact checking ombudsmanship',
#  'ddnt english reign coco inundated ostentatious woke',
#  'tbxcakdrw gta online collateral gta online',
#  'doves greatest denier electric proms xjtpvoydl',
#  'chief nah young cook gone cut haha',
#  'weird pitched noise siren ofnsixjks',
#  'dude antioch',
#  'calestous tanzania elephant population declined five census reveals zynfxt itzmasbvz',
#  'perfect evening outdoor happenings featured huzrhgmksy eventspalmbeach',
#  'california monster contained aptapyxr',
#  'spacex founder musk took falcon lvizocssr',
#  'battlefield forgotten secret',
#  'thank richarkkirkarch ausinstarchitect words warning queenswharf brisbane jmkywhvmp financialreview',
#  'skinny jeans socialnews ltmaxqxpx',
#  'susinesses invoices yours stlnd colour shape likely pay pile',
#  'mic controllers working',
#  'inundated employee holiday request paperwork cloud based software hronlinetweets simplify staffing logistics',
#  'enter extreme diving stories volga dmtzmgyrik',
#  'womens buckle casual stylish shoulder handbags pockets bags jqsofyzp fxnplios',
#  'hwy east hwy cambridge single vehicle blocking lane opp enroute',
#  'blizzard draco lonewolffur link',
#  'grateful mnpdnashville nashvillefd acted swiftly countless lives',
#  'result heavy rains bangladeshaffected lands inundated waters rivers tide bangladeshflood',
#  'lightening torrential cut',
#  'smash',
#  nan,
#  'justintrudeau respected job recovery led meltdown exactly',
#  'kshllcenterpri progressohio mean burnt churches',
#  'camila follow spree screaming happiness',
#  'happening across street',
#  'tweet selfie pretty sweet ask knomgpfiz',
#  'behindashield wars goddess sweet lord knees buckle',
#  'robertmeyer example prices farmers broke means simple capitalism failed feed',
#  'hungerarticles nepal rebuilding lives livelihoods quake lrouwjmbix',
#  'ruin mood',
#  'rly screams vibrates handle',
#  'australiauas burger tetdlyimn newscomauhq',
#  'quoted cnn purported threatens croatian swvuzxigt',
#  'cocktail list diablo mas verde mezcal yellow chartreuse honey cucumber hellfire bitters reuosjekm',
#  'program worked pool surprise jimmyfallon worstsummerjob',
#  'downtown hiring dependency counselor intern seattle apply jobs hhtwaytyo',
#  'louis vuitton monogram sophie limited edition clutch bag ebay gggfvopb nlfrtxqm',
#  'kca votejktid fired damaged housed near osborn extinguished',
#  'exploration takes shift gabon somalia kltitas',
#  'losdelsonido declares typhoon saipan signs declaration northern ivanberroa',
#  'standardized tests harm color idrlets parentsacrossam billgates',
#  'electrocute turn',
#  'untangle yourself requiring partner fill needs besttalkradio listen jzutxwt',
#  'kills displace million pakistan analysis kkoovbkndp',
#  'massive typhoon heads toward taiwan naeyvsg',
#  'alexeivolkov mcfaul equal spirit roskomnadzor ridiculously politicized illegal',
#  'hundreds migrants await disembarkment irish naval vessel palermo italy tconnellyru aimcyhly',
#  'access extensive sources threat information box easily add internal intelligence bhusa',
#  'loudest goal screamed higuain offside goal germany',
#  'taylor cara aka mother chucker scenes vote tfbkqolx vmas fqqpfjvx',
#  'pkk suicide bomber detonated turkey trench fvxhopdfw',
#  'kenya several reported close dam estate langata',
#  'screams mother gbepdiwzt',
#  'add items everyday eating habits research bloodu lnpscadaxr',
#  'stock gems oonsjhcsd tcot',
#  'uirichmond coaches driver chance sittingu jam yyhbbhkf',
#  'lane blocked manchester eddy delay mins',
#  'bang earlier dad floor chair sitting broke unijrvrrq',
#  'booktubeathon dying supernatural likely',
#  'tkyonlyfmk unconfirmed bang appears neighbour',
#  'desolate mirad clgtotvsf',
#  'snap tools baseball hat cap silver gray embroidered logo reu uwaoasfg hchzswsi',
#  'louis tomlinson incredible screaming dancing ashes',
#  'sundays football seasonfrom log onshit complete',
#  'former township philippines langley imilsfxntf filipino',
#  'islamic threatens muslim womenua arenuat zgynebn',
#  'wired quarantine offensive zlagvuza',
#  'students collide fri sat register pwjjimrfly nlccollide wpxfyyri',
#  'rightways integrity problems inspections repair vzirhnmm rightwaystan',
#  'beastin tapas evening folk funtimes jxuepkmkrh',
#  'trillion crosses field wide instant',
#  'michaelgbaron scott rice shot holding lefties average',
#  'radioactive box israeluas ashdod port evacuated teams discovered radiation emittin swqlmydka',
#  'gaza strip kills four unknown gopsicpbm reuters',
#  'thank california cogotiwn',
#  'blue bell close return listeria theneeds recipes fvampt',
#  'torro loco conversation sorry senator electrocute million etc',
#  'driver rams israeli soldiers driver rammed israeli soldi obszybaj',
#  'bbc forced retract false claims pam cihcnrch wordpressdotcom',
#  'excited football xqvgzzmmn',
#  'vine explode cnxxmffrae',
#  'musician kalle mattson recreates classic album covers clever music avalanche ydjpophdw',
#  'firefighter david ruhl died frog modoc temporarily reassigned',
#  'risk giant wildfire kcrw agmkxww',
#  'rising follower graph followers stats ulxfdqns',
#  'finally panicking cable ranefihbuk mflrvbhqa',
#  'elisagxrcia epicentre haha',
#  'wrongdejavu traumatised',
#  'fascinating pics north korea propaganda living edbcpwdu',
#  'tumbles todayi side twister sweeps bitch runs distance',
#  nan,
#  'caught',
#  'bay district coaches learn cpr medical course panama athlete field coaches kfkaoshkh',
#  'patio table umbrella chairs flipped suspect foul play suspense writer',
#  'selfies brooklyn sel oyymgwhn hinterestin funny',
#  'squibby',
#  'wwi wwii japanese navy japan leather mido ebay qumcewty ktkgsdhhl',
#  'jays rocking mlb joeybats rogers play offs ahead bluejays bell moseby barfield',
#  'anyway mateo exist hes mirage pointless addition generation human sorry',
#  nan,
#  'guns protection unless',
#  nan,
#  'jacksonville engine awesome jade ybdsljwc',
#  'luka everything alois trancy',
#  'mtr issues outlook hwo tglkuusz',
#  'mood elevator decided noses everytime pressed button',
#  'aircraft debris island malaysia confirms xrcchkago',
#  'happily',
#  'omfg expect drag song pandora played omfg screamed coworker scared vzcvadkcqp',
#  'buy bag',
#  'demi stans sold million copies',
#  'taaylordarr thank',
#  'hlportal hello looking mod cold ice site link download maybe share',
#  'load welfare loving sponge blight society rrzbzgon',
#  'close mental long',
#  'childhood',
#  'setting option',
#  'radar widespread showers storms moving same areas minor hunwx eljqjhu',
#  'pakistan disowned kasab disowns naved denial naved captured alive anu hgdrksn',
#  'shape shoes amazon foot adjust shape shoe mini shoe tree stretcher shaper width extender adjustable cpczxohb',
#  'alexandrapullin indeed comes',
#  'mechamacgyver bet blamed huh',
#  'hashtagteaclub pars defender andy tod uniform instant utter mayhem ensued',
#  'zouma absolutely flattened guy',
#  'wackos michelebachman predict soon obliterated firey inferno accept globalwarming hello',
#  'cyclist runner roanoke greenway wins civil verdict wgasoencwc roanoketimes',
#  'cjbanning sake argsuppose pre born attained individl rights generally courtof law forbids killing unless',
#  'incident pascoe vale south outbound tullamarine fwy citylink near moreland vehicles lane delays',
#  'candidates frank grimes level meltdown voters trump matter pbegof',
#  'equally scared somehow started heal fill once permanent',
#  'lately pressure put niqqa stretcher',
#  'tonto salt horse matijwkzbh',
#  'womens buckle casual stylish shoulder handbags pockets bags mwzqcjhzpb',
#  'udhampur terror militants spos suspected militants fphfesemyj',
#  'shirt company animal better start seeing changes wildlife',
#  'curls pretty finished shooting twister',
#  'max screenshots show lovely combat magnum opus cmaqfns',
#  'prone waterways westchester county eligible millions aid newyork xsrvujyiz',
#  'coastal german shepherd shared link ecstatic racco tqdzvgwx animalrescue',
#  'explanation request provided job constantly',
#  'thetimepast saalon childhood resolved theirs actual fricken babies',
#  'vehicle fowlers corners hwy frank hill blocking opp minor occupants',
#  'julian knight scvsupremecourt dismisses attempt increase prisoner pay challenged quantum increase',
#  'sometimesi breathe anxietyproblems',
#  'potus drown entering lungs alive caused pussy',
#  'imagine entire aisle dedicated serbian director foods clothing section',
#  'texansdc kylekrenek zepp frobeus fun saving shooting teddy bear',
#  'schools western uganda strikes strikes western uganda lit',
#  'rly recount horror uiwhen coaches plunging called zkgqspwyj',
#  'brace yourself samaritans sunday evening inundated calls depressed arsenal hexpcotn',
#  'tasmania trained horse urjwsvr jfreteii',
#  'savs contact fell convinced guage eyeball panic caused',
#  'abbswinston zionist kidnapped palestinians overnight terror palestinian villages jmkcbkcov',
#  'broke nail fake hurts ideas treat pretty',
#  'connor franta okay dan howell murdered street',
#  'late mcdonalds friends hilarious although wrecked steak pastie industrial estate',
#  'berlin wall daubt generation chubychux vdjhjnwv',
#  nan,
#  'quarantine offensiveu wjwyjbncat onlinecommunities amageddon freespeech erisqkt',
#  'omgbethersss bethanymota haha',
#  'words charlie daniels mountain boys fzhaej',
#  'mortal kombat meat predator iggfnbixt',
#  'tryouts minus fact stopped quickly short ball toenail',
#  'rai sends message condolence vietnam following bgytmqjoo',
#  'wmata metro text morn route uhlakfvsm sms',
#  'seeks comment rules changes insurer xqiadghw ypeelmjdzy',
#  'martynwaites known fact valentine massacre avoided oompah period tom waits',
#  'truckcrash overturns fortworth interstate rsljqfp click lduniywk',
#  'awful artist ruin',
#  'wisdomwed bonus minute habits improve lifehacks tbmfqbcw',
#  'blakeshelton fart follow jeez',
#  'feeling youuave realise',
#  'killed barrington hills hoffman estates killed single wednesday afte bnphxorzg',
#  'nashville theater gun grabbers demand uihatchet oyogiiyh',
#  'king naruto long madara bleeding',
#  'jordan coated eastuas largest refugee camp layer grit hvjmuualxv tnzhzz',
#  'sarah palin obliterate planned parenthood targeting minority bbsp dmuupqgwy',
#  'nasa announced massive solar headed straight cmumiol',
#  'investigators virgin galactic spaceship caused cou',
#  'err',
#  'homes razed northern california wildfire york kbrzzmfc tafs',
#  'smp ignition knock sensor apvlhhjo ljntejgmb',
#  'infographic turkish officials killed pkk terror attacks suruc suicide bombing uvaojzcycz',
#  'itss selenaluna',
#  'spot combo inch curved cree led bar offroad fog lamp reu ovsotxk ixyiejj',
#  'imagine flattened kurt zouma',
#  'ixiybapqa homes razed northern california wildfire lynchburg advance zepzqydby',
#  'canceling warships france agrees repay russia nytimes fgwxeprak',
#  'beforeitsnews hundreds feared libyan migrant capsizes mjoeebdlxn fvenexps',
#  'feeling society implode hero play',
#  'hey concept quarantine makes sense wander whenever',
#  'wreckage conclusively confirmed malaysia investigators families sfrgnwo',
#  'gears preview member chat welcome sdgzdxnt',
#  'worked joint poured burnt sink trap fallontonight worstsummerjob',
#  'campers evacuated california wildfire blazes officials wwgadpffkw',
#  'fully hahah',
#  'ahh forgot headphones supposed music ayhhhhhdjjfjrjjrdjjeks',
#  'turnedonfetaboo hsjb rockin preview claytonbryant soon ewrvyzfkv artistsunited',
#  nan,
#  'montgomery blazing stds rejected slogan',
#  'charlesdagnall salt rub',
#  'finnish plant ahead financing secured dawxokke',
#  'jake adavis cuddling',
#  'ezralevant soccer moms blown put daughter bedroom walls',
#  'autoames hoped join ventilated marines trying bandolier dogs fort dix',
#  'oso washington response interview sbfglqjzfs',
#  'luck soon sleeping schedule wrecked beyond repair',
#  'christian muslims temple mount waving israeli flag pamela geller nhxserthx',
#  'usatoday frontpage faced secret sanctions rickperry cut foxnewu ukohksob',
#  'stankyboy',
#  'trouble caaaaaall',
#  'mageavexis',
#  'airport swallowed minute qrbtdcqcj',
#  'meltdown victory mets',
#  'offers glcvcp deluxe toilet safety bathroom elderly vihdoksccc',
#  'general audience families zenit seen rome hfvnyftc',
#  'kimkardashian share petition horses arizona tssxphufe',
#  'max blew shots fired catfishmtv',
#  'completely cech paul keegan alive',
#  'starbs degrees metro washington',
#  'pool raisinfingers',
#  'thebriankrause leos metaphorically blown piperwearsthepants charmed',
#  'accused judge jrtfdtx khqa',
#  'imagine doctor treating ebola patient placing himself harm dlizfkky',
#  'hiroshima human forget jlujqsu',
#  'omron hem automatic pressure monitor standard cuffs gjbainqwn jphgplcx',
#  'russia killed buses ybypievn',
#  'funnynews collapses chunks onto lcipljx',
#  'slamming door lesson learned lover burn',
#  'pounds north deep bruise chest cries pain tough short',
#  'actionmoviestaughtus explode bang space',
#  'gates bagging nobody niggas',
#  'paul rudd emile hirsch david gordon prince avalanche filmmakers google eqonkzndz entretenimento',
#  'confirmed sanchez bolasie rest season ctneptl',
#  'iafflocal lives except charged protecting',
#  'families sue legionnaires families affected outbreak legionnaires disea zaaxfjsvb',
#  'beyond stressed beyond hysteria grey misty indifference complete shutdown brain',
#  'bagged lac drake bagging meek',
#  'serious increased japanjapan safety standard inferior standard anonymous nytimes',
#  'absolute athens bound',
#  'chrisdanielshow nearly pee san francisco tvlfrhmm',
#  'debris reunion island comes malaysian fqwyeeec',
#  'pics packed temp dropped winds picked',
#  'tattoo allowed donate receive',
#  'californians living africa sahel desert finding chore ysgvsrtg',
#  'hfqlwokmy mini earnings letdown equals meltdown leidwvllq amazon',
#  'advisory effect thursday increasing humidity lawx usykowvwv',
#  'dangdaddy telling turn qaqqrjvgu',
#  'declares typhoon saipan signs declaration northern marians icuovl',
#  'footage strong san bernardino county working qcyqhvnha',
#  'trains derailment freakiest freak accidents indian express yytwhd',
#  'watched honey blew economy recommend conservative shoppe horrors harperanetflixshow elxn stopharper',
#  'scottdpierce billharris harrisgle beezersun forfeiting fantasy football pool win kicked',
#  'stuart broad takes eight joe root runs aussies stuart broad took career figures zgsjwxdrcm',
#  'charged manslaughter toddler report charged manslaughter',
#  'awful painting agree landscape oils paints',
#  'nowplaying north east unsigned radio listen qymalttvzp',
#  'ngx mhtwfnet michael jordan absolutely meme baiting camper foxsportscom',
#  'listening blowers tuffers aussie batting trent bridge reminds bbctms wonderful stuff engvaus',
#  'picture mail',
#  'baileysmsteach looking doingu ahhhu perrychat',
#  'dog pugprobs',
#  'germs anthrax mishaps qzqcwwwcn usatoday',
#  'accionempresa chinauas stock sparked interest bargain hunt gopkrfzmf gerenciatodos',
#  'tsutomi yamaguchi atomic blasts hiroshima nagasaki otd daalpenzp',
#  'boots hearts social inundation starting',
#  'message sent reply message',
#  'presume timeline inundated soggy bottom lashings moist tweets',
#  'starts put stfmnr',
#  'fylppfn',
#  'hellfire silentmind bookofdaniel fkqjyezyg',
#  'bhavana mom crushed soul',
#  'direction concert otrametlife ptyhrcuzh',
#  'migrants capsizes libya pmggavtokp',
#  'families sue legionnaires families affected outbreak legionnaires zfyqsawvrk',
#  'rcmp reporting serious result tch near whitbourne',
#  'lava dragon breeder bred lava dragon dragonvale visit qgumxheos',
#  'photoset hakogaku aei kurd born battlefield raised battlefield gunfire obpwtm',
#  'masterfsloths crush szxvbbjf',
#  'uptown jorge nose bleeding',
#  'clogs canyon jrdwyyax',
#  'baseballquotes inch dynasty',
#  'robot vacancies castle fantasy football team join ituas fun',
#  'schoolboyuas account hiroshima pqdmhqr',
#  'batfanuk enjoyed show fun non interesting',
#  'funtenna computers data waves hat aattamnmd',
#  'britney spears vegas missed canuat wait show pieceofme mjywpcf',
#  'item phantasmal cummerbund qrhjeigrq warcraft',
#  'hibernating pbx irrespective pitch careerism pan crbzfz',
#  'nigerian boxer sessions klitschko becomes famous jszzqstxs',
#  'officially skipping fantasticfour fantstic whatever hashtag reviews bummer',
#  'pixeljanosz angelheartnight british name',
#  'funtenna computers data waves hat cxaupnemu',
#  'viralspell spend wedding feeding syrian ivpkqyag tygavnuk',
#  'scissor alexhammerstone kttape ktfounder remymarcel frofrofrou bzvitd',
#  'paint planning forever',
#  'seconds pick jwseptxga fan sosfam qwgiwcwz',
#  'young forced flee burundi violence vice jojnqoopi dskuimmgl',
#  'businesses affected reopen jyapul',
#  'chaosmagician awesome bleeding pretty',
#  'yea demolish boundaries seem unconsciously myself negative thoughts',
#  'physical sense helps preserve memories triple ajw xjgkjvma jishin minamisoma',
#  nan,
#  'atomic bombs japan struggles anniversary wrought vfctrzaok',
#  'balanced balance allah mercy',
#  'waiting chocolate lava cakes',
#  'swansea plot transfer southampton target virgil van dijkua pvmrlnva',
#  'ignition knock sensor acdelco original equipment ojdtbrwa jfxqiyivf',
#  'milwaukee indyfest cars long siren woke nap',
#  'widda gone relax wife wrecked cake goner mind whoops',
#  'epilepsy claims common challenge treat superhero toddler rare epilepsy dravet drowns vbotjndps',
#  'hse releases annual workplace facilities data husheekxm jnhnxoisn',
#  'potus maybe israel sorry pres sold',
#  'anxious meet makes uncomfortable ruin',
#  'whippenz horses petition stand voice gilbert edllncvu',
#  'aphl responds germs anthrax mishaps cgdjdrso',
#  'optichcz askhcz jealous wanted elgato bday record videos',
#  'california gov drought wildfires mkqsvpeg',
#  'salt horses wvobvvtxkg',
#  'csaresu american sdmrzgeryx',
#  'transportation panel showing pileup wheelers uimake amssummer',
#  'complaining phoenix mode emblem turns ray gigant difficulty option',
#  'awesome profile swimming robot reactors hrcoxquik innovation wnptvbmt',
#  'motorcyclist bicyclist denver broadway zlojdaju',
#  'jon mclaughlin such song',
#  'wanted gritty pasta thursdays amico tag amicospizzato seeyouatamicos mzvqxbkts',
#  'janenelson stephenscifi adaptation charlie human optioned sciencefiction',
#  'gas screams street smells gas',
#  'slew updated posts hosting fixed unfml deluge',
#  'seven seas giannis hitting submerged reef theu gnwhnsfib fwpoftwoc',
#  'damnaarielle timeline blew',
#  'weekend stockholm sweden aug copperfields unxcsve',
#  'scriptettesar katiecool btw began september marks',
#  'missing families evacuated due bukidnon zhsckvysn',
#  'maailiss diaporama sixpenceee karymsky lake crater lake located karymsky volcanoaeinaerussia ofmhn',
#  'asked monkey fist feet long panic snap pictured yibbbxfe',
#  'wreckage conclusively confirmed malaysia investigators families ljylxzfbi',
#  'priority severe thunderstorm ended issued lethbridge updated aug mdt yqyiwjnez',
#  'putin western masse causing backlash fajbxzkar',
#  'cop pulls drunk driver safety seconds thrhkhogcuae tzszmfqxe viralspell',
#  'hey birds submissions wedding wars fantastic sending guys',
#  'bae soak backroom thisiswhywecanthavenicethings kgxnwziuxd',
#  'chambered speakingfromexperience',
#  'deeeznvtzzz bring bags tho',
#  'local lmfao',
#  'crushed mile awesome',
#  'howardu blks whts colluded wht usagov auth blk lgl org idis hers',
#  'weak distinct rotation fully condenses near villa ridge near mcv sub fddzspugk',
#  'secrets vortex catcher book oiywrzlz',
#  'ribbon hits passlefec offtrackhorse',
#  'prepare hazmat training qzixcie',
#  'cartoon bears qave knowlddge toilet paper',
#  'debris reunion island flight mystery plane disappearance better novel',
#  'kaotix blaze craving',
#  'namjoon fantastic bye',
#  'japan thursday marks anniversary atomic bombing hiroshima senior washington scheduleu',
#  'sismo detectado japi report okinawa island region depth maximum intensity jst',
#  'siren joining foot vvorm',
#  'japan marks anniversary hiroshima atomic bombing qreinwggs',
#  'rgj trailer catches reno kafwdrmtn',
#  'salem shut electrical circuit pump okcaz tgdonttkty',
#  'rationing become necessary such terror',
#  'young dancer moves youth attendance gmmbc youth saturday inspiring tmmorvxswz',
#  'grenade effect impossible hoes careers',
#  'soundcloud profile shall offer mixes obliterated byebyesoundcloud',
#  'recover typhoon',
#  'apply dilawri shop manager vancouver jobs vgjnahiw kshsgwghfj',
#  'quarantine offensive ubkqtxhr',
#  'lowkey drown acmrmzq',
#  'grace levels style taiwan typhoon ratings categories defined odydtqpk',
#  'investigators virgin galactic spaceship caused pilot unlocked braking system',
#  'assholes ruin',
#  'officer suspect exchanging shots brelgmnc abc',
#  'nflexpertpicks michael floyd devalue fantasy stock michael floyd damaged digits won',
#  'wired quarantine offensive founder ceo steve huffman unveiled abyhrgsss',
#  'declares typhoon saipan caneyttwev international',
#  'crushed',
#  'fel lord zakuun hellfire wod xonvdux',
#  'nick williams crushed',
#  'lomasvisto hipsters feared giant devours brooklyn intersectio qwtkbfmc cadenadeseguidores',
#  'boyhaus heaven sent jakeae uiafter warm montanauas madison early evening fidzxs',
#  'extent obliteration privilege reduce unfair favoritism',
#  'pennlive families mechanicsburg blaze ohydhhcpe',
#  'scotrail seen turn blind eye bloke drinking smoking curfew cos worth hassle',
#  'legna correct sides maybe friends rep feed inundated false claims',
#  'bbc forced retract false claims pam tbbobvcotj wordpressdotcom',
#  'atomic bombs japan struggles anniversary wrought ltvvpflsg',
#  'india shud evidence pak share terrorists share oth contries qiopbtiuvu',
#  'added playlist vyxurnep survival hug guest roblox',
#  'escape parley canyon crews investigating fxdhubq yzhvobgocq',
#  'earthquake brenas puerto rico utc atu sdzrrfzhmy',
#  'saving babies soaking cake tonne alcohol mat gbbo',
#  'officer suspect exchanging shots',
#  'homes razed northern california wildfire wildfires california andu kehtreny',
#  'nowplaying strike snow patrol hundred million suns grzchkdf',
#  'dems blaze covered months detained americans interrogation facility uwitvbsbnc',
#  'noches bestia alexis sanchez happy teammates training goodnight gunners ucjjhvgr',
#  'pressure meds probably roof long ppact broke involved animal',
#  'weekend nathan birthday weekend drown yourself beer reckless potentially hmu',
#  'severe thunderstorm warning including midwest del choctaw cdt ogxsygwd',
#  'princessduck wanted sense blown james win target gone soon',
#  'former township philippines langley ldcpvzu philippines',
#  'union debris surely flight officials york vfbwnyol',
#  'prices drivers reap benefits qltwhojqya',
#  'tweet niall thx electrocute myself tweet scared jinx',
#  'worry covered plenty ipa squeeze radler anmdkdrv',
#  'evildead civilization spfkekqu',
#  'drought fuels jamaica zdtdqqbahc psqcnsvfgp jamaicaobserver cnewslive zgefjbm',
#  'truediagnosis per physician error dutyzqrpae avoid oznsxxvxu',
#  'pizza drought anymore',
#  'trent bridge reminds england caribbean',
#  'joe landolina gel bleeding instantly btniwagt arizona realestate hhzyoqela',
#  'specially modified stadium jkdctiiw lajnned',
#  'aftershock protect yourself profit global financial meltdown david wiedemer wztzhgmvq',
#  'skippygaming mxhrextrkh minecraft lava door tutorial xbox',
#  'aiginsurance ceo divestitures losses temper results ywzkfrm',
#  'bringing tornadoes bringing plaguing farrakhan quote',
#  'pair round led driving atv utv ebay dpxdlec jddvhfy',
#  'pakistan helicopter restive northwest killing qvrmzij',
#  'recycling using non chemicals holland continually strives maintain eco friendly existence',
#  'tweetinglew tersestuff notley flattened harper heartland harper imported tens tfw slaves cost albertans jobs',
#  'emotional desolation effect alcoholism addiction tgtlzya forgiving crcoemwf',
#  'class tgirl scene iwcudgia',
#  'reblogged picture self harm scars',
#  'businesses invoices urs stand colour shape likely pay pile',
#  'alton livestream butter touched plate soon nut joke gvdfcxiz',
#  'debris confirmed relatives discovery site rlftjmhhvt reuters',
#  'naayf turning onto chandanee magu near mma taxi rammed halfway turned confu',
#  'petition heartless owner whipped horse animal act efcbiczm',
#  'documents pointing japan wwii atomic program iucpcsfbmt',
#  'bat',
#  'skynews scum alive obliterate cancer',
#  'gregorysanders usdot stat auto applies vehicle guess lightrail better adult',
#  'theboyofmasks letting manor blown anyways buddy',
#  'hollywood miners chile',
#  'brought beginning universe matches mentioned versethe heaven earth thus universe',
#  'squad backpack antioch tenn theater gunman officials tennessean ebiieiwn',
#  'root canal tookitlikeaman lovemydentist sore',
#  'visible tucson mountains caused steep rocky terrain mountainsu zrtrplqv',
#  'punk bands original music ghostoftheav montroseband wdvxjsqwic',
#  'haji hunter middleeasteye maybe muzzies spontaneously combust allah suicide bombing payback',
#  'sea electrocute',
#  'policy effect subreddits banned ngkrzpza',
#  'optic scumper sexy',
#  'katunews remains closed brush burns acres qposkpmwj liveonk mtqjsvupwy',
#  'coppednews haunting memories drawn wxdgez',
#  'josh salyers blair hall families jenna friends prayers soon rip bdnfdpdaz',
#  'stiiilo',
#  'inundated images information online deconstruct kerri sackville tms',
#  'bigrigradio awareness',
#  'suicide bomber kills dozen saudi mosque saudi arabia started experiencing pioyof',
#  'dozens trains india www informationng com',
#  'technology designed prevent dangerous chases effort reduce milwaukee policeu cedjdlpdan',
#  'effects hiroshima nagasaki atomic bombings felt tzxeggokd',
#  'friendly reminder civilians qrepylluk',
#  'ssssnell agree shock factor ropes show angers',
#  'owen four ferrell ten bullet rapidly lethal kerricktrial twcnewsclt nnbexhklhr',
#  'kelby tomlinson mild mannered baseman metropolitan team fights ending hits rbi sfgiants',
#  'break homebuyer miscalculation mwjcdk',
#  'rescuers recover calgary lake near vulcan gaehrbhek',
#  'chikislizeth anymore',
#  'effects hiroshima nagasaki atomic bombings felt tgcrvofj',
#  'seanpeconi jason floyd lynchonsports criscyborg risk losing nose flattened lot',
#  'david cameron upsetting bee listen science companies savebees ndjjado lbjsqyo',
#  'anellatulip theory makes sense dwarves actual origin blight',
#  'joe reince presssec joe smart president perfect american assholes win',
#  'alerts glimpses hyderabad heavy rainfall',
#  'self quiz xspqdoriqj cqyvfrucy',
#  'wendell berry speaking spill gulf mexico ituas birthday tnaxxmbb',
#  'such architecture nyc escape routes newyorku fwptaelgv',
#  'palestinian toddler israel cracks jewish',
#  'direction pick qeblokeve fan directioners encmhzy',
#  'boston yesterday intense hailstorm cityporn exuhrbkh qonudd',
#  'trafford odeon cinema evacuated following false alarm gldwxda',
#  'izjkkpwiz',
#  'father three overtaking bathandnortheastsomerset fafcnln',
#  'dmoneydemi meltdown yesterday miss forsure dtb watchout',
#  'biggest regret hearthstone vcirnmdv',
#  'uribe ball',
#  'bbcwomanshour setsuko thurlow hiroshima cvjymlkrm fphueiiu',
#  'kurtkamka desolation coyotes lizards sun phoenix arizu zpvjvdpf',
#  'modiministry railway minister prabhu calls derailment calamity tlolpakz',
#  'steel ferrochrome industry verge put list questions president oral answer',
#  'jetstar virgin forced cancel bali flights ash mount raung volcano jtjofltms',
#  'screams different languages',
#  'pkk suicide bomber detonated turkey trench aawzxykles rsmvgdxriv',
#  'families sue legionnaires families affected outbreak legionnaires disease edinburgh',
#  'gorpuazikinak tongue cum puddle covered',
#  'quarantine offensive lodormtfsq',
#  'settingsuccess bells toll hiroshima japan marks atomic bombing smallbusiness entrepreneur',
#  'dating meet sex teen fat cock xjwsyrqr',
#  'gfrost jeffpalmer mlb bluejays salty scared drought',
#  'mourning notices stabbing victims stir politics griefua israel gbluhrrlto',
#  'senator alarmed reports families harassed senator wednesday alarmed byu sbilayqjq',
#  'twilightfairy flattened frog',
#  'lizzie cstsmith drove thru deep flash repair cost yrs later thnk cars float',
#  'couples less sex internet movies books saying sex ought cxhizprad',
#  'thehighfessions friend blasted asked pancakes iowa highu',
#  'chillimik hushlegs haha comparing yourselves brilliant talk arse',
#  'legionnaires disease deadly outbreak outbreak legio ubgwfyge losangeles',
#  'tin tesco dog prompted complaint chelsea dogs pets dogs animals puppy qzvkpahsq',
#  'kiddie pool ploppy',
#  'hollywood miners chile ajisa hugomatz',
#  'majesty emperor salman khan unstoppable entertainment humanity bajrangi bhaijaan creating everywhere crosed',
#  'newswatch vehicles lock lansdowne sts ptbo emerg crews',
#  'church leaders kenya forward comment issue disciplinary measures arrestpastornganga',
#  'wonder wrecked trying stare furious',
#  'cowboys george woes took claiborne round trying stick giqbvlys',
#  'drmartyfox libs evil evil reap lord mercy',
#  'josh lado tweeting driving joshua typos',
#  'fucking saying uia notheru sounds fucking stupid fucking mean uia otheru fucking tongue twister',
#  'rly recount horror uiwhen coaches plunging called xtljzbjgl',
#  'shayoly yes',
#  'lionx',
#  'grace bicycles fences trees fly idiots swollen rivers',
#  'build share custom applications within threatconnect exchange hrlxnjk infosec dfir threatintel',
#  'dorman ignition knock sensor connector wxceszte pygkssscfr',
#  'mapleridge lougheed hwy closed between dewdney trunk eto between',
#  'scourge europe whedonesque fanged four qjhdculy',
#  'courtuas reputation prestige lower prosser served court hnydbzov',
#  'self quiz wplrhbfhee eelexssvf',
#  'ember aware lzmlxbnh',
#  'music siren chills',
#  'kendall jenner nick jonas dating might quite explode pfvzvpxqgr',
#  'abcnews scandal caused major upheaval parliamentary expenses subsequent sackings prison waiting',
#  'ebolatrends alabama ebola case ihvmtmzxne jliemrsnnj',
#  'aftershock kick thank',
#  'gards dare harm harry otrametlife',
#  'jax issues outlook hwo fucoqhclad',
#  'quarrels seek adventures dlvzaayqr',
#  'wfaaweather pete pass mid month frisco scouts canoe trip okla',
#  'itsjustinstuart mnkajiqn gun range mayhem',
#  'etkdunn cleveland heights shaker heights blight door lrelvrmw',
#  'clears walk',
#  'arianagrande lickin donuts jail',
#  'audio owners share differently utqezfde',
#  'horror films incredibly creative artists interviewed depth anatomy jmpdsxlk',
#  'eden hockey rbbnjkoqud',
#  'zayn malik perrie edwards engagement sheuas devastatedua gedoxsppl aczruorytd',
#  'nasahurricane eastern pacific satellite sees formation eastern pacific tropical hilda thu ksxtonknl',
#  'lord',
#  'lmao skin guy blew talking ugly kid',
#  'trump xyzoei pollster realdonaldtrump',
#  'michelleellle shut freshman curfew sleep spend',
#  'feat bts kallemattson incredible music avalanche wseatuv',
#  'beginning mom curfew wonders',
#  'picking bodies rescuers searching hundreds migrants mediterranean carryi',
#  'passengers evacuated safely derails kzbsohtwb',
#  'watched trailed died colin perfect goodness',
#  'hellfire donuat mention letuas leads',
#  'hellfire gargoyle hoof coil iibrcnx',
#  'confirmed sundayuas ffnzitkgn',
#  nan,
#  'illinois slipped radar officials zhguyebj',
#  'usgs volcano hawaii utc rrghtewp earthquake',
#  'happens fucking fly metlife beat crap tries harm boys otratmetlife',
#  'thingsihate total able',
#  'skarletan swell emotions',
#  'kamkasteiiano bluntedjayt fucking screaming',
#  'vnugmgkt canada radiation fishing closures',
#  'scalpium screaming',
#  'scary probably falcon scary',
#  'vwuqqiy marvel avengers',
#  'mini lalaloopsy dolls seed sunburst june seashore sweater autumn spice reu nytyfcqo hyypspnyq',
#  'japan marks yrs cities killing worry fcixkxqh',
#  'neighbor stopped play disney lava song uke journey believing kidsthesedays',
#  'christians israel cufi jews convert soon armageddon arwwrzpsr mkjqyfmp',
#  'twister toosoon',
#  'sirensicebreaker fantasy diverse heroine hpljurobo',
#  'scene derailment cta prairie zzudilrea',
#  'civilian casualties afghanistan reach record rptvfuhx npckktleq',
#  'replacing unknown curiosity open ourselves tou qrhngkjc',
#  'officials alabama rbsjmlej',
#  'stylishly unique houses might zombie audbcinf bovjrft',
#  'jannet fell concrete bleeding',
#  'meg issues outlook hwo ggnmtl',
#  'keegan',
#  'rules break once becomes easier hgbmcirk ysxghcgz',
#  'question anybody else circle epicentre dspwshjw',
#  'pone cantar crying',
#  'greenbuildermag nfpa hold webinar wildfire mitigation xmsvohkccp firewise michele nfpa',
#  'chiasson sens coloradoavalanche avalanche bklagma bkdgcfsuiq',
#  'ashes unfolded trent bridge dqddgvgbf cricket',
#  'orders lifted roosevelt highway ehltyyfak koinnews pmxezuoay',
#  'tried mido macia accused testified tried mido maciauas vxvfaeeyq',
#  'zel kno',
#  'wfp wfp delivers bangladesh victims tropical komen dhaka uothe fukbbedfgx',
#  'mallelis gotten desolate planet below mason dixon style electro violin playing',
#  'able touch penneys',
#  'welovela nhlducks avalanche defense match louis blues vrvcomh sportsroadhouse',
#  'flattened thee striker',
#  'alil twister tha nah',
#  'recap pkk suicide bomber detonated turkey trench jzcedayrg',
#  'waves darkness',
#  'opening scene harry potter phoenix remind else twister okay',
#  'awadgolf gop capitalist win biggest voted dems elect',
#  'tales trees deep loving lake tahoe xuhmjlq',
#  'client meeting emotions tubestrike',
#  'myanmar rohingya sittwe point return qegmrhsms prison conditions genocide ihhen msf',
#  'joel book acts rgpemtqej',
#  'mariah thick shoulders',
#  'erdogan gambit july suicide bombing turkey took lives socialists surui zxauidrxu shareaholic',
#  'joked wood working innings often cubstalk',
#  'duty obliterate superstition society swami agnivesh',
#  'thank california frautrapani',
#  'foxnews beard visited prison keeps hideous beard electrocute uglypeople',
#  'cousins hang text saying honestly wish',
#  'dry thunderstorms pinpoint valley forecast idasyjybro gdoaolpq',
#  'ituas cat saturday aug cats oqbdasmvy newbeginningsanimalrescue',
#  'hollywood miners chile fkvyhqlk newsdict chile',
#  'hello book bloggers interviews regarding book formed ineedexposure',
#  'hellfire surrounded desires careful donuat desires afterlife',
#  'ukfloods british trekkers amid flash himalayas british nsfzkfgznj',
#  'intervene southampton vitesse arnhem supporters clash clash buildup skvnmtzgeg',
#  'nobody remembers charles schulz',
#  'stallion kbeastx genisys agreed',
#  'walk blowin dey lock cus dope gay',
#  'attended romford londonfire thankfully iyjejopwi',
#  'thunderstorm woken yesterday street dark yhvjy',
#  'reuters charged inevitable contributing lies',
#  'reuters rocky grown california qwrrfdgxcc newsintweets sstjbepqn',
#  ...]

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# ## Naive Bayes Classifier

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ## KNN

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ## Gradient Boosting

# %% [markdown]
# ## XGBoost
